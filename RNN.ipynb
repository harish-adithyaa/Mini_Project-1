# %%
import keras
from keras import backend as K
from keras import optimizers
import tensorflow
from keras.models import Sequential, Model
from keras.layers import Lambda, Activation, Input, Dense, Dropout, SimpleRNN, Flatten, \
    LSTM, GRU, Bidirectional, Layer, Permute, Reshape, Multiply, RepeatVector, Dot, Concatenate

import pandas as pd
import numpy as np
import math
from math import sqrt
import os
import csv
from keras.models import Sequential, Model
from keras.layers import Lambda, Activation, Input, Dense, Dropout, SimpleRNN, Flatten, \
    LSTM, GRU, Bidirectional, Layer, Permute, Reshape, Multiply, RepeatVector, Dot, Concatenate

from keras import optimizers
import keras.backend as K
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.vector_ar.var_model import VAR
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import tensorflow as tf
import numpy.linalg as la
import time
import matplotlib.dates as mdates
font1 = {'family': 'Microsoft YaHei',
         'weight': 'normal',
         'size': 13}
plt.style.use('default')
tensorflow.random.set_seed(2)
exchanges = ["binance", "coinbase", "huobi", "kraken", "kucoin"]
beginDates = ['2021-01-30', '2021-11-05', '2020-11-03', '2020-06-25', '2021-02-15']
endDates = ['2021-12-23', '2021-12-24', '2021-09-15', '2021-09-15', '2021-12-24']

li = [] #Save the location of outliers detected using LSTM
li.append([95, 110, 111, 115, 116, 238])
li.append([30])
li.append([153, 190, 241])
li.append([313, 327, 329])
li.append([216, 256, 275, 295])

# class Attention(Layer):
#
#     def __init__(self, units=128, **kwargs):
#         self.units = units
#         super().__init__(**kwargs)
#
#     def __call__(self, inputs):
#         """
#         Many-to-one attention mechanism for Keras.
#         @param inputs: 3D tensor with shape (batch_size, time_steps, input_dim).
#         @return: 2D tensor with shape (batch_size, 128)
#         @author: felixhao28, philipperemy.
#         """
#         hidden_states = inputs
#         hidden_size = int(hidden_states.shape[2])
#         # Inside dense layer
#         #              hidden_states            dot               W            =>           score_first_part
#         # (batch_size, time_steps, hidden_size) dot (hidden_size, hidden_size) => (batch_size, time_steps, hidden_size)
#         # W is the trainable weight matrix of attention Luong's multiplicative style score
#         score_first_part = Dense(hidden_size, use_bias=False, name='attention_score_vec')(hidden_states)
#         #            score_first_part           dot        last_hidden_state     => attention_weights
#         # (batch_size, time_steps, hidden_size) dot   (batch_size, hidden_size)  => (batch_size, time_steps)
#         h_t = Lambda(lambda x: x[:, -1, :], output_shape=(hidden_size,), name='last_hidden_state')(hidden_states)
#         score = Dot(axes=[1, 2], name='attention_score')([h_t, score_first_part])
#         attention_weights = Activation('softmax', name='attention_weight')(score)
#         # (batch_size, time_steps, hidden_size) dot (batch_size, time_steps) => (batch_size, hidden_size)
#         context_vector = Dot(axes=[1, 1], name='context_vector')([hidden_states, attention_weights])
#         pre_activation = Concatenate(name='attention_output')([context_vector, h_t])
#         attention_vector = Dense(self.units, use_bias=False, activation='tanh', name='attention_vector')(pre_activation)
#         return attention_vector
#
#     def get_config(self):
#         return {'units': self.units}
#
#     @classmethod
#     def from_config(cls, config):
#         return cls(**config)

class attention(Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")
        super(attention, self).build(input_shape)

    def call(self, x):
        et = tensorflow.squeeze(keras.activations.sigmoid(tf.matmul(x, self.W) + self.b), axis=-1)

        at = at = tf.keras.activations.softmax(et)

        at = tf.expand_dims(at, axis=-1)
        output = x * at
        return tf.reduce_sum(output, axis=1)


    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()


def model_lstm_att(time_steps, input_dim, n_units, method="LSTM"):
    K.clear_session()  
    model_input = Input(shape=(time_steps, input_dim))
    if method == "LSTM":
        x = LSTM(n_units, return_sequences=True)(model_input)
    elif method == "GRU":
        x = GRU(n_units, return_sequences=True)(model_input)
    elif method == "RNN":
        x = SimpleRNN(n_units, return_sequences=True)(model_input)
    x = attention()(x)
    x = Dense(1)(x)
    model = Model(model_input, x)
    return model
def model_lstm(seq_len, n_features, n_units):
    model = Sequential()
    model.add(LSTM(n_units, activation="relu", input_shape=(seq_len, n_features)))
    model.add(Dense(1))
    return model

def evaluation(real, pre):
    rmse = mean_squared_error(real, pre, squared=False)
    mae = mean_absolute_error(real, pre)
    mape = mean_absolute_percentage_error(real, pre)
    r2 = r2_score(real, pre)
    var = 1-(np.var(real - pre))/np.var(real)
    F_norm = la.norm(real-pre)/la.norm(real)

    return rmse, mae, mape, r2, var, 1-F_norm

def min_max_scaler(li):
    min_ = min(li)
    max_ = max(li)
    ret = [(i - min_) / (max_ - min_) for i in li]
    return ret, min_, max_

def data_split(data, train_rate, seq_len, pre_len=1):
    time_len, n_feature = data.shape
    train_size = int(time_len * train_rate)
    train_data = data[0:train_size]
    trainX, trainY, testX, testY = [], [], [], []
    for i in range(train_size-seq_len-pre_len):
        a = train_data[i: i + seq_len + pre_len]
        trainX.append(a[0: seq_len])
        trainY.append(a[seq_len: seq_len + pre_len, 0])
    for i in range(train_size-seq_len-pre_len, time_len-pre_len-seq_len):
        b = data[i: i+seq_len+pre_len,:]
        testX.append(b[0:seq_len])
        testY.append(b[seq_len:seq_len+pre_len, 0])
    trainX1 = np.array(trainX)
    trainY1 = np.array(trainY)
    testX1 = np.array(testX)
    testY1 = np.array(testY)
    return trainX1, trainY1, testX1, testY1

def lstm(n_units=64, seq_len=10, batch_size=64, method="LSTM"):
    error_list = []
    rmse_list = []
    mae_list = []
    mape_list = []
    for i in range(len(exchanges)):
        exchange = exchanges[i]
        important = True
        if important:
            file = open("E:\\MiniProject\\exchange_anomaly_detection-main\\exchange\\feature\\" + exchange + '_ft.csv')
        else:
            file = open("E:\\MiniProject\\exchange_anomaly_detection-main\\exchange\\feature\\" + exchange + '_ft_not_important.csv')
        df = pd.read_csv(file)

        data = df.values
        print("type data")
        print(type(data))
        time_len, n_features = data.shape
        train_rate = 0.8
        train_size = int(time_len*train_rate)
        trainX, trainY, testX, testY = data_split(data, train_rate=train_rate, seq_len=seq_len)
        scaled_data = data.copy()
        #Normalize the features of each column
        scaler = []
        for j in range(n_features):
            temp_scaler = MinMaxScaler(feature_range=(0, 1))
            temp = temp_scaler.fit_transform(np.array(scaled_data[:, j]).reshape(-1,1))
            scaler.append(temp_scaler)
            temp = temp.reshape(-1)
            scaled_data[:, j] = temp
        trainX1, trainY1, testX1, testY1 = data_split(scaled_data, train_rate=train_rate, seq_len=seq_len)

        #model_name = method+"_attention"
        model_name=method

        if model_name=="LSTM_attention" or model_name=="GRU_attention" or model_name=="RNN":
            model = model_lstm_att(seq_len, n_features, n_units, method=method)
        if model_name=="LSTM":
            model = model_lstm(seq_len, n_features, n_units)

        opt = optimizers.Adam()
        model.compile(optimizer=opt, loss='mse')
        history = model.fit(trainX1, trainY1, epochs=50, batch_size=batch_size, validation_data=(testX1, testY1), verbose=2, shuffle=False)
        if True:
            plt.figure(figsize=(10, 5))
            plt.grid(linestyle="--")
            plt.plot(history.history['loss'], label='train')
            plt.plot(history.history['val_loss'], label='test')
            plt.legend()
            plt.title(exchange)
            plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure/lstm_prediction" + exchange + '_' + model_name + '_loss.png')
            plt.show()
        prediction_val = model.predict(testX1)
        print(type(prediction_val))
        print(prediction_val)

        rmse, mae, mape, r2, var, _ = evaluation(testY1, prediction_val)
        print("rmse = {}\nmae = {}\nmape = {}".format(rmse, mae, mape))
        error_list.append("rmse = {}\nmae = {}\nmape = {}\n".format(rmse, mae, mape))

        rmse_list.append(rmse)
        mae_list.append(mae)
        mape_list.append(mape)

        prediction_val = np.array(scaled_data[0:train_size, 0].tolist()+prediction_val[:, 0].tolist())
        prediction_val = prediction_val.reshape(-1,1)
        prediction_val = scaler[0].inverse_transform(prediction_val)
        prediction_val = prediction_val[train_size:,0]
        print("testY")
        testY = testY[:,0]
        print("testY.shape")
        print(testY.shape)
        print(type(testY))
        print("prediction_val")
        print(prediction_val.shape)
        print(type(prediction_val))

        if True:
            # plt.figure(figsize=(10, 4))
            # plt.grid(linestyle="--")
            # plt.plot(range(time_len-train_size), testY)
            # plt.plot(range(time_len-train_size), np.array(prediction_val))
            upper_bound = [it + 3 * np.std(testY) for it in prediction_val]
            lower_bound = [it - 3 * np.std(testY) for it in prediction_val]

            fig, ax = plt.subplots(figsize=(10, 4),dpi=300)
            beginDate = beginDates[i]
            endDate = endDates[i]

            x = np.arange(mdates.datestr2num(beginDate), mdates.datestr2num(endDate))
            x_range = [np.datetime64(int(c), 'D') for c in x]
            # plt.figure(figsize=(10, 4))
            # plt.grid(linestyle="--")

            abnormal_x = []
            abnormal_y = []
            for j in range(len(upper_bound)):
                if testY[j] > upper_bound[j]:
                    abnormal_x.append(x_range[j])
                    abnormal_y.append(testY[j])

            miss_x = []
            miss_y = []
            for j in range(len(li[i])):
                if x_range[li[i][j]] not in abnormal_x:
                    miss_x.append(x_range[li[i][j]])
                    miss_y.append(testY[li[i][j]])

            fmt_half_year = mdates.MonthLocator(interval=1)
            ax.xaxis.set_major_locator(fmt_half_year)

            fmt_month = mdates.MonthLocator() 
            ax.xaxis.set_minor_locator(fmt_month)

            ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))

            datemin = np.datetime64(x_range[0], 'M')
            # datemax = np.datetime64(x_range[-1], 'Y') + np.timedelta64(1, 'Y')
            datemax = np.datetime64(x_range[-1], 'M') + np.timedelta64(1, 'M')
            ax.set_xlim(datemin, datemax)

            ax.format_xdata = mdates.DateFormatter('%Y-%m')
            ax.format_ydata = lambda x: f'$x:.2f$'
            ax.grid(True)
            fig.autofmt_xdate()

            ax.plot(x_range, testY)
            ax.plot(x_range, np.array(prediction_val))
            ax.plot(x_range, upper_bound, "--")
            ax.plot(x_range, lower_bound, "--")
            ax.scatter(abnormal_x, abnormal_y, c="r", marker="o")
            ax.scatter(miss_x, miss_y, c="dimgrey", marker="o")
            if method=="LSTM":
                plt.legend(("Real", model_name, "Upper bound", "Lower bound", "Anomaly detected"), loc=2)
            else:
                plt.legend(("Real", model_name, "Upper bound", "Lower bound", "Anomaly detected", "Anomaly missed"), loc=2)

            plt.title(exchange.title())
            plt.xlabel("time", font1)
            # plt.ylabel("Transaction Amount(USD)")
            plt.ylabel("Trading volume (USD）", font1)
            plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure"+str.lower(method)+'_prediction_' + exchange + '_' + model_name + '_prediction.png')
            plt.show()
    for i in range(len(exchanges)):
        print(exchanges[i])
        print(error_list[i])
    return rmse_list, mae_list, mape_list

def parameter_sensitivity(parameter, para_range):
    rmse_list = [[] for i in range(len(exchanges))]
    mae_list = [[] for i in range(len(exchanges))]
    mape_list = [[] for i in range(len(exchanges))]
    for it in para_range:
        if parameter=="Number of hidden units":
            temp_rmse, temp_mae, temp_mape = lstm(n_units=it)
        if parameter=="Sequence length":
            temp_rmse, temp_mae, temp_mape = lstm(seq_len=it)
        if parameter == "Batch size":
            temp_rmse, temp_mae, temp_mape = lstm(batch_size=it)
        for jj in range(len(temp_rmse)):
            rmse_list[jj].append(temp_rmse[jj])
            mae_list[jj].append(temp_mae[jj])
            mape_list[jj].append(temp_mape[jj])
    for i in range(len(exchanges)):
        exchange = exchanges[i]
        rmse_list[i],_,_ = min_max_scaler(rmse_list[i])
        mae_list[i],_,_ = min_max_scaler(mae_list[i])
        mape_list[i],_,_ = min_max_scaler(mape_list[i])
        plt.figure(figsize=(5, 4))

        plt.grid(linestyle="--")
        plt.plot(para_range, rmse_list[i])
        plt.plot(para_range, mae_list[i])
        plt.plot(para_range, mape_list[i])
        if i==0:
            plt.legend(("RMSE", "MAE", "MAPE"), loc='lower right')
        else:
            plt.legend(("RMSE", "MAE", "MAPE"))
        plt.xlabel(parameter)
        plt.ylabel("normalized value",font1)
        plt.title(exchange.title())
        plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure\para_" + parameter + '_' + exchange + '.png')
        plt.show()

def cal_date():
    li = []
    li.append([1400, 1415, 1416, 1420, 1421, 1543])
    li.append([222])
    li.append([1413, 1450, 1501])
    li.append([2097, 2111, 2113])
    li.append([1463, 1503, 1522, 1542])
    start_time = [1499212800, 1619481600, 1495497600, 1438905600, 1505606400]
    for i in range(len(li)):
        print(exchanges[i])
        for j in range(len(li[i])):
            temp_time = start_time[i] + li[i][j]*86400
            timeArray = time.localtime(temp_time)
            otherStyleTime = time.strftime("%Y-%m-%d %H:%M:%S", timeArray)
            print(otherStyleTime)
if __name__=='__main__':
    lstm(method="RNN") #method = LSTM, RNN, GRU
    # lstm(106, 6, 74)
    # parameter_sensitivity("Batch size", [16,32,64,128,256,512])
    # parameter_sensitivity("Number of hidden units", [16,32,64,128])
    # parameter_sensitivity("Sequence length", [5,10,20,40,80])
    # cal_date()
# Out:
# type data
# <class 'numpy.ndarray'>
# WARNING:tensorflow:From C:\Users\kskis\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:73: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/50
# 21/21 - 4s - 174ms/step - loss: 0.0012 - val_loss: 0.0180
# Epoch 2/50
# 21/21 - 0s - 13ms/step - loss: 7.5375e-04 - val_loss: 0.0164
# Epoch 3/50
# 21/21 - 0s - 13ms/step - loss: 0.0049 - val_loss: 0.0390
# Epoch 4/50
# 21/21 - 0s - 14ms/step - loss: 0.0050 - val_loss: 0.0356
# Epoch 5/50
# 21/21 - 0s - 13ms/step - loss: 0.0023 - val_loss: 0.0726
# Epoch 6/50
# 21/21 - 0s - 13ms/step - loss: 0.0057 - val_loss: 0.0309
# Epoch 7/50
# 21/21 - 0s - 18ms/step - loss: 0.0035 - val_loss: 0.0247
# Epoch 8/50
# 21/21 - 0s - 16ms/step - loss: 0.0015 - val_loss: 0.0451
# Epoch 9/50
# 21/21 - 0s - 13ms/step - loss: 0.0015 - val_loss: 0.0204
# Epoch 10/50
# 21/21 - 0s - 16ms/step - loss: 0.0011 - val_loss: 0.0135
# Epoch 11/50
# 21/21 - 0s - 10ms/step - loss: 6.4855e-04 - val_loss: 0.0185
# Epoch 12/50
# 21/21 - 0s - 11ms/step - loss: 5.1143e-04 - val_loss: 0.0124
# Epoch 13/50
# 21/21 - 0s - 11ms/step - loss: 4.7942e-04 - val_loss: 0.0117
# Epoch 14/50
# 21/21 - 0s - 12ms/step - loss: 2.9847e-04 - val_loss: 0.0126
# Epoch 15/50
# 21/21 - 0s - 12ms/step - loss: 2.7944e-04 - val_loss: 0.0107
# Epoch 45/50
# 21/21 - 0s - 13ms/step - loss: 5.7419e-04 - val_loss: 0.0094
# Epoch 46/50
# 21/21 - 0s - 13ms/step - loss: 2.9807e-04 - val_loss: 0.0096
# Epoch 47/50
# 21/21 - 0s - 13ms/step - loss: 4.1673e-04 - val_loss: 0.0096
# Epoch 48/50
# 21/21 - 0s - 14ms/step - loss: 3.5322e-04 - val_loss: 0.0094
# Epoch 49/50
# 21/21 - 0s - 13ms/step - loss: 3.2240e-04 - val_loss: 0.0095
# Epoch 50/50
# 21/21 - 0s - 13ms/step - loss: 3.2889e-04 - val_loss: 0.0094
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# <class 'numpy.ndarray'>
# [[0.10797216]
#  [0.11969675]
#  [0.10757768]
#  [0.11361444]
#  [0.1333722 ]
#  [0.13618669]
#  [0.14096439]
#  [0.14636688]
#  [0.15885323]
#  [0.1566404 ]
#  [0.16374585]
#  [0.17250606]
#  [0.17026408]
#  [0.17758557]
#  [0.18361661]
#  [0.1877491 ]
#  [0.18214965]
#  [0.17546697]
#  [0.17998764]
#  [0.18322606]
#  [0.18273428]
#  [0.17783546]
#  [0.18098333]
#  [0.18798797]
#  [0.18343094]
#  [0.20042717]
#  [0.20846157]
#  [0.19437999]
#  [0.1872578 ]
#  [0.17467187]
#  [0.17057219]
#  [0.1617159 ]
#  [0.16665536]
#  [0.15889499]
#  [0.14737074]
#  [0.14245507]
#  [0.1387041 ]
#  [0.13022251]
#  [0.13951406]
#  [0.14271174]
#  [0.14642972]
#  [0.1484537 ]
#  [0.15040275]
#  [0.1566622 ]
#  [0.14690423]
#  [0.14756428]
#  [0.1534805 ]
#  [0.16306014]
#  [0.15469441]
#  [0.16018301]
#  [0.16915415]
#  [0.16183907]
#  [0.16157159]
#  [0.16485304]
#  [0.15782456]
#  [0.15888725]
#  [0.1597727 ]
#  [0.14289188]
#  [0.13719837]
#  [0.14892204]
#  [0.15617418]
#  [0.14994808]
#  [0.15947266]
#  [0.16151524]
#  [0.18659845]
#  [0.1707803 ]
#  [0.1486574 ]
#  [0.17129707]
#  [0.18879992]
#  [0.19290656]
#  [0.17885819]
#  [0.17521378]
#  [0.18401259]
#  [0.18699063]
#  [0.1960703 ]
#  [0.20493694]
#  [0.20034096]
#  [0.18270579]
#  [0.19797766]
#  [0.1925498 ]
#  [0.21399324]
#  [0.21000046]
#  [0.20936629]
#  [0.22621995]
#  [0.24690875]
#  [0.24802485]
#  [0.20671937]
#  [0.19961652]
#  [0.22579677]
#  [0.23068756]
#  [0.20957212]
#  [0.19561407]
#  [0.18503553]
#  [0.18705055]
#  [0.19138962]
#  [0.21124746]
#  [0.22346097]
#  [0.22611618]
#  [0.22916977]
#  [0.25334978]
#  [0.2707664 ]
#  [0.2673972 ]
#  [0.3033518 ]
#  [0.30405483]
#  [0.32026374]
#  [0.32858828]
#  [0.31124574]
#  [0.30253586]
#  [0.28838426]
#  [0.29024112]
#  [0.2922628 ]
#  [0.29753485]
#  [0.17813984]
#  [0.18279466]
#  [0.19585775]
#  [0.19392155]
#  [0.1643412 ]
#  [0.1772593 ]
#  [0.16501236]
#  [0.17693119]
#  [0.1776331 ]
#  [0.16731529]
#  [0.16080794]
#  [0.18119907]
#  [0.18863626]
#  [0.17806564]
#  [0.18881544]
#  [0.18841252]
#  [0.19496459]
#  [0.18614325]
#  [0.18720725]
#  [0.19095452]
#  [0.19507432]
#  [0.20342526]
#  [0.2019161 ]
#  [0.2088463 ]
#  [0.21015589]
#  [0.20314881]
#  [0.2087323 ]
#  [0.22378126]
#  [0.23021126]
#  [0.23005804]
#  [0.23892348]
#  [0.21795532]
#  [0.21201615]
#  [0.21411614]
#  [0.22831403]
#  [0.202223  ]
#  [0.19829312]
#  [0.17429507]
#  [0.19533741]
#  [0.20072831]
#  [0.19425797]
#  [0.18290329]
#  [0.21794596]
#  [0.23887785]
#  [0.2220283 ]
#  [0.1953312 ]
#  [0.20879014]
#  [0.22917166]
#  [0.22662508]
#  [0.21408592]
#  [0.1931899 ]
#  [0.19433023]
#  [0.2101582 ]
#  [0.20316249]
#  [0.20219693]
#  [0.19685085]
#  [0.18771824]
#  [0.18001784]
#  [0.17279688]
#  [0.17116603]
#  [0.16379958]
#  [0.17746139]
#  [0.16567379]
#  [0.16333243]
#  [0.16588217]
#  [0.1748032 ]
#  [0.15749654]
#  [0.15895182]
#  [0.15406832]]
# rmse = 0.10390857969662326
# mae = 0.06372553361999683
# mape = 0.35737833943850345
# testY
# testY.shape
# (327,)
# <class 'numpy.ndarray'>
# prediction_val
# (327,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# 3/3 - 4s - 1s/step - loss: 0.0452 - val_loss: 0.0579
# Epoch 2/50
# 3/3 - 0s - 68ms/step - loss: 0.0352 - val_loss: 0.0290
# Epoch 3/50
# 3/3 - 0s - 42ms/step - loss: 0.0177 - val_loss: 0.0193
# Epoch 4/50
# 3/3 - 0s - 42ms/step - loss: 0.0228 - val_loss: 0.0182
# Epoch 5/50
# 3/3 - 0s - 42ms/step - loss: 0.0177 - val_loss: 0.0220
# Epoch 6/50
# 3/3 - 0s - 42ms/step - loss: 0.0158 - val_loss: 0.0408
# Epoch 7/50
# 3/3 - 0s - 62ms/step - loss: 0.0173 - val_loss: 0.0346
# Epoch 8/50
# 3/3 - 0s - 47ms/step - loss: 0.0142 - val_loss: 0.0217
# Epoch 9/50
# 3/3 - 0s - 47ms/step - loss: 0.0146 - val_loss: 0.0196
# Epoch 10/50
# 3/3 - 0s - 47ms/step - loss: 0.0147 - val_loss: 0.0261
# Epoch 11/50
# 3/3 - 0s - 47ms/step - loss: 0.0138 - val_loss: 0.0378
# Epoch 12/50
# 3/3 - 0s - 47ms/step - loss: 0.0141 - val_loss: 0.0382
# Epoch 13/50
# 3/3 - 0s - 47ms/step - loss: 0.0134 - val_loss: 0.0295
# Epoch 14/50
# 3/3 - 0s - 50ms/step - loss: 0.0133 - val_loss: 0.0255
# Epoch 15/50
# 3/3 - 0s - 47ms/step - loss: 0.0135 - val_loss: 0.0283
# Epoch 16/50
# 3/3 - 0s - 47ms/step - loss: 0.0133 - val_loss: 0.0329
# Epoch 17/50
# 3/3 - 0s - 42ms/step - loss: 0.0132 - val_loss: 0.0315
# Epoch 18/50
# 3/3 - 0s - 42ms/step - loss: 0.0129 - val_loss: 0.0267
# Epoch 19/50
# 3/3 - 0s - 42ms/step - loss: 0.0129 - val_loss: 0.0247
# Epoch 20/50
# 3/3 - 0s - 47ms/step - loss: 0.0130 - val_loss: 0.0260
# Epoch 21/50
# 3/3 - 0s - 73ms/step - loss: 0.0129 - val_loss: 0.0269
# Epoch 22/50
# 3/3 - 0s - 52ms/step - loss: 0.0128 - val_loss: 0.0251
# Epoch 23/50
# 3/3 - 0s - 31ms/step - loss: 0.0127 - val_loss: 0.0232
# Epoch 24/50
# 3/3 - 0s - 47ms/step - loss: 0.0127 - val_loss: 0.0231
# Epoch 25/50
# 3/3 - 0s - 50ms/step - loss: 0.0126 - val_loss: 0.0238
# Epoch 26/50
# 3/3 - 0s - 52ms/step - loss: 0.0126 - val_loss: 0.0234
# Epoch 27/50
# 3/3 - 0s - 42ms/step - loss: 0.0125 - val_loss: 0.0223
# Epoch 28/50
# 3/3 - 0s - 52ms/step - loss: 0.0124 - val_loss: 0.0220
# Epoch 29/50
# 3/3 - 0s - 52ms/step - loss: 0.0124 - val_loss: 0.0223
# Epoch 30/50
# 3/3 - 0s - 36ms/step - loss: 0.0123 - val_loss: 0.0221
# Epoch 31/50
# 3/3 - 0s - 42ms/step - loss: 0.0123 - val_loss: 0.0215
# Epoch 32/50
# 3/3 - 0s - 42ms/step - loss: 0.0122 - val_loss: 0.0212
# Epoch 33/50
# 3/3 - 0s - 36ms/step - loss: 0.0122 - val_loss: 0.0213
# Epoch 34/50
# 3/3 - 0s - 36ms/step - loss: 0.0121 - val_loss: 0.0210
# Epoch 35/50
# 3/3 - 0s - 36ms/step - loss: 0.0121 - val_loss: 0.0206
# Epoch 36/50
# 3/3 - 0s - 36ms/step - loss: 0.0120 - val_loss: 0.0204
# Epoch 37/50
# 3/3 - 0s - 31ms/step - loss: 0.0120 - val_loss: 0.0203
# Epoch 38/50
# 3/3 - 0s - 31ms/step - loss: 0.0119 - val_loss: 0.0201
# Epoch 39/50
# 3/3 - 0s - 31ms/step - loss: 0.0119 - val_loss: 0.0198
# Epoch 40/50
# 3/3 - 0s - 26ms/step - loss: 0.0119 - val_loss: 0.0197
# Epoch 41/50
# 3/3 - 0s - 31ms/step - loss: 0.0118 - val_loss: 0.0196
# Epoch 42/50
# 3/3 - 0s - 36ms/step - loss: 0.0118 - val_loss: 0.0194
# Epoch 43/50
# 3/3 - 0s - 31ms/step - loss: 0.0117 - val_loss: 0.0193
# Epoch 44/50
# 3/3 - 0s - 42ms/step - loss: 0.0117 - val_loss: 0.0193
# Epoch 45/50
# 3/3 - 0s - 115ms/step - loss: 0.0116 - val_loss: 0.0192
# Epoch 46/50
# 3/3 - 0s - 57ms/step - loss: 0.0116 - val_loss: 0.0191
# Epoch 47/50
# 3/3 - 0s - 52ms/step - loss: 0.0115 - val_loss: 0.0190
# Epoch 48/50
# 3/3 - 0s - 52ms/step - loss: 0.0115 - val_loss: 0.0189
# Epoch 49/50
# 3/3 - 0s - 52ms/step - loss: 0.0115 - val_loss: 0.0188
# Epoch 50/50
# 3/3 - 0s - 52ms/step - loss: 0.0114 - val_loss: 0.0188
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 375ms/step
# <class 'numpy.ndarray'>
# [[0.34664124]
#  [0.36334258]
#  [0.34111953]
#  [0.31771702]
#  [0.3186813 ]
#  [0.3400448 ]
#  [0.34386623]
#  [0.32239932]
#  [0.30115038]
#  [0.27548325]
#  [0.25288016]
#  [0.26898807]
#  [0.2775997 ]
#  [0.27962852]
#  [0.2929237 ]
#  [0.30006123]
#  [0.27982426]
#  [0.26317418]
#  [0.25739884]
#  [0.27687818]
#  [0.2644726 ]
#  [0.27037427]
#  [0.25483912]
#  [0.23043416]
#  [0.21722421]
#  [0.22658335]
#  [0.23248309]
#  [0.23976798]
#  [0.24042067]
#  [0.22139822]
#  [0.18323003]
#  [0.15317999]
#  [0.19990109]
#  [0.25034606]
#  [0.23612559]
#  [0.24013808]
#  [0.2500075 ]
#  [0.2829737 ]
#  [0.23879606]
#  [0.21748117]
#  [0.18180354]
#  [0.16673724]
#  [0.18213055]
#  [0.18460052]
#  [0.14371245]
#  [0.11626282]
#  [0.13312116]
#  [0.14909437]
#  [0.15759824]]
# rmse = 0.13712910680478949
# mae = 0.103339492106451
# mape = 0.6400598493959716
# testY
# testY.shape
# (49,)
# <class 'numpy.ndarray'>
# prediction_val
# (49,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# 20/20 - 5s - 246ms/step - loss: 7.9956e-04 - val_loss: 0.0105
# Epoch 2/50
# 20/20 - 0s - 13ms/step - loss: 0.0014 - val_loss: 0.0174
# Epoch 3/50
# 20/20 - 0s - 16ms/step - loss: 0.0011 - val_loss: 0.0356
# Epoch 4/50
# 20/20 - 0s - 13ms/step - loss: 0.0012 - val_loss: 0.0056
# Epoch 5/50
# 20/20 - 0s - 13ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 6/50
# 20/20 - 0s - 12ms/step - loss: 2.6396e-04 - val_loss: 0.0134
# Epoch 7/50
# 20/20 - 0s - 13ms/step - loss: 2.5928e-04 - val_loss: 0.0057
# Epoch 8/50
# 20/20 - 0s - 14ms/step - loss: 1.3293e-04 - val_loss: 0.0066
# Epoch 9/50
# 20/20 - 0s - 15ms/step - loss: 1.0596e-04 - val_loss: 0.0070
# Epoch 10/50
# 20/20 - 0s - 13ms/step - loss: 9.6090e-05 - val_loss: 0.0063
# Epoch 11/50
# 20/20 - 0s - 14ms/step - loss: 9.1421e-05 - val_loss: 0.0066
# Epoch 12/50
# 20/20 - 0s - 14ms/step - loss: 2.2959e-04 - val_loss: 0.0114
# Epoch 42/50
# 20/20 - 0s - 14ms/step - loss: 3.5441e-04 - val_loss: 0.0052
# Epoch 43/50
# 20/20 - 0s - 14ms/step - loss: 3.4548e-04 - val_loss: 0.0066
# Epoch 44/50
# 20/20 - 0s - 13ms/step - loss: 1.6877e-04 - val_loss: 0.0120
# Epoch 45/50
# 20/20 - 0s - 13ms/step - loss: 2.1682e-04 - val_loss: 0.0058
# Epoch 46/50
# 20/20 - 0s - 13ms/step - loss: 1.3908e-04 - val_loss: 0.0050
# Epoch 47/50
# 20/20 - 0s - 12ms/step - loss: 1.8658e-04 - val_loss: 0.0072
# Epoch 48/50
# 20/20 - 0s - 12ms/step - loss: 1.3444e-04 - val_loss: 0.0087
# Epoch 49/50
# 20/20 - 0s - 13ms/step - loss: 1.5024e-04 - val_loss: 0.0049
# Epoch 50/50
# 20/20 - 0s - 16ms/step - loss: 1.2901e-04 - val_loss: 0.0058
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000029B649BFEC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# <class 'numpy.ndarray'>
# [[0.0116335 ]
#  [0.01578822]
#  [0.01593958]
#  [0.01713405]
#  [0.01728747]
#  [0.02105373]
#  [0.02152434]
#  [0.01723276]
#  [0.01812653]
#  [0.01512454]
#  [0.02093443]
#  [0.01937664]
#  [0.02004779]
#  [0.01979581]
#  [0.01729827]
#  [0.02405123]
#  [0.01993213]
#  [0.02386152]
#  [0.01974847]
#  [0.02020051]
#  [0.02729643]
#  [0.01248948]
#  [0.01978545]
#  [0.01164757]
#  [0.01657178]
#  [0.01748519]
#  [0.01349465]
#  [0.01322619]
#  [0.01792516]
#  [0.01147697]
#  [0.01911967]
#  [0.01480802]
#  [0.0112873 ]
#  [0.01728345]
#  [0.01126595]
#  [0.01688045]
#  [0.01376906]
#  [0.01455972]
#  [0.01666904]
#  [0.01356231]
#  [0.01519261]
#  [0.01515608]
#  [0.0142303 ]
#  [0.0159788 ]
#  [0.01462334]
#  [0.01598058]
#  [0.01838753]
#  [0.0159013 ]
#  [0.01610257]
#  [0.01654911]
#  [0.01245008]
#  [0.01848742]
#  [0.01360185]
#  [0.014726  ]
#  [0.01926779]
#  [0.01653553]
#  [0.01896315]
#  [0.02055264]
#  [0.01517469]
#  [0.01906097]
#  [0.01492522]
#  [0.0178796 ]
#  [0.01903633]
#  [0.01881459]
#  [0.02929364]
#  [0.02339262]
#  [0.01954448]
#  [0.02395495]
#  [0.01656698]
#  [0.03216203]
#  [0.02297633]
#  [0.02925856]
#  [0.03292206]
#  [0.02032023]
#  [0.0304079 ]
#  [0.02062767]
#  [0.03313647]
#  [0.02142796]
#  [0.01606444]
#  [0.03343578]
#  [0.0254755 ]
#  [0.03054643]
#  [0.03309869]
#  [0.02469263]
#  [0.0295188 ]
#  [0.0283505 ]
#  [0.02801055]
#  [0.03094528]
#  [0.03226195]
#  [0.02610095]
#  [0.02643882]
#  [0.02767726]
#  [0.02531077]
#  [0.02981876]
#  [0.02965982]
#  [0.03253924]
#  [0.03124153]
#  [0.03772907]
#  [0.04668833]
#  [0.04023512]
#  [0.04060453]
#  [0.03718292]
#  [0.04488777]
#  [0.04634026]
#  [0.03466487]
#  [0.03656701]
#  [0.03369575]
#  [0.0336513 ]
#  [0.03186703]
#  [0.031169  ]
#  [0.03167987]
#  [0.02944711]
#  [0.02933597]
#  [0.02858366]
#  [0.02765174]
#  [0.02983977]
#  [0.02900047]
#  [0.02888144]
#  [0.02847999]
#  [0.02846066]
#  [0.03093279]
#  [0.03189889]
#  [0.03293069]
#  [0.03380012]
#  [0.03248394]
#  [0.0326463 ]
#  [0.0328038 ]
#  [0.03359978]
#  [0.03389605]
#  [0.03537444]
#  [0.03610779]
#  [0.0372927 ]
#  [0.03772457]
#  [0.03792946]
#  [0.04264167]
#  [0.03995948]
#  [0.04043901]
#  [0.04145358]
#  [0.04751584]
#  [0.04623257]
#  [0.0481299 ]
#  [0.04691468]
#  [0.04237585]
#  [0.04360933]
#  [0.04101115]
#  [0.04762499]
#  [0.04215009]
#  [0.04132469]
#  [0.04308876]
#  [0.04251752]
#  [0.04340153]
#  [0.04204352]
#  [0.04303247]
#  [0.04117965]
#  [0.04239521]
#  [0.0423836 ]
#  [0.04261755]
#  [0.04475501]
#  [0.04471883]
#  [0.04505523]
#  [0.04425106]
#  [0.04785423]
#  [0.0502981 ]
#  [0.0520271 ]
#  [0.05106324]
#  [0.0491696 ]
#  [0.05014533]
#  [0.04484593]]
# rmse = 0.07673653521430605
# mae = 0.03058149463947263
# mape = 0.39819660823888586
# testY
# testY.shape
# (316,)
# <class 'numpy.ndarray'>
# prediction_val
# (316,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# 28/28 - 4s - 156ms/step - loss: 0.0025 - val_loss: 0.0454
# Epoch 2/50
# 28/28 - 0s - 12ms/step - loss: 0.0013 - val_loss: 0.0382
# Epoch 3/50
# 28/28 - 0s - 15ms/step - loss: 0.0031 - val_loss: 0.0759
# Epoch 4/50
# 28/28 - 0s - 13ms/step - loss: 0.0021 - val_loss: 0.0240
# Epoch 5/50
# 28/28 - 0s - 12ms/step - loss: 0.0022 - val_loss: 0.0394
# Epoch 6/50
# 28/28 - 0s - 13ms/step - loss: 0.0023 - val_loss: 0.0203
# Epoch 7/50
# 28/28 - 1s - 27ms/step - loss: 6.8137e-04 - val_loss: 0.0144
# Epoch 8/50
# 28/28 - 0s - 13ms/step - loss: 0.0015 - val_loss: 0.0231
# Epoch 9/50
# 28/28 - 0s - 15ms/step - loss: 9.2390e-04 - val_loss: 0.0254
# Epoch 10/50
# 28/28 - 0s - 12ms/step - loss: 8.3104e-04 - val_loss: 0.0161
# Epoch 11/50
# 28/28 - 0s - 14ms/step - loss: 7.6428e-04 - val_loss: 0.0130
# Epoch 12/50
# 28/28 - 0s - 12ms/step - loss: 6.6114e-04 - val_loss: 0.0133
# Epoch 42/50
# 28/28 - 0s - 11ms/step - loss: 5.1308e-04 - val_loss: 0.0121
# Epoch 43/50
# 28/28 - 0s - 11ms/step - loss: 6.4817e-04 - val_loss: 0.0124
# Epoch 44/50
# 28/28 - 0s - 12ms/step - loss: 6.0181e-04 - val_loss: 0.0165
# Epoch 45/50
# 28/28 - 0s - 12ms/step - loss: 5.3261e-04 - val_loss: 0.0179
# Epoch 46/50
# 28/28 - 0s - 12ms/step - loss: 6.9007e-04 - val_loss: 0.0150
# Epoch 47/50
# 28/28 - 0s - 12ms/step - loss: 5.2354e-04 - val_loss: 0.0120
# Epoch 48/50
# 28/28 - 0s - 12ms/step - loss: 5.7217e-04 - val_loss: 0.0118
# Epoch 49/50
# 28/28 - 0s - 12ms/step - loss: 6.2585e-04 - val_loss: 0.0143
# Epoch 50/50
# 28/28 - 0s - 12ms/step - loss: 5.1494e-04 - val_loss: 0.0166
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# <class 'numpy.ndarray'>
# [[ 1.41569870e-02]
#  [ 1.59415640e-02]
#  [ 1.99465603e-02]
#  [ 1.56956390e-02]
#  [ 9.07108281e-03]
#  [ 1.32818157e-02]
#  [ 1.69357806e-02]
#  [ 1.64926946e-02]
#  [ 1.38960453e-02]
#  [ 1.71160214e-02]
#  [ 1.84553638e-02]
#  [ 1.07401917e-02]
#  [ 9.09647066e-03]
#  [ 1.32849189e-02]
#  [ 1.78903975e-02]
#  [ 1.89781785e-02]
#  [ 2.28881203e-02]
#  [ 1.58783272e-02]
#  [ 1.09767085e-02]
#  [ 1.50926309e-02]
#  [ 1.54707944e-02]
#  [ 2.10784450e-02]
#  [ 1.89929120e-02]
#  [ 1.58519223e-02]
#  [ 1.14146220e-02]
#  [ 7.26339268e-03]
#  [ 1.55008296e-02]
#  [ 1.86381526e-02]
#  [ 1.33413943e-02]
#  [ 1.49649316e-02]
#  [ 1.92618072e-02]
#  [ 1.96675994e-02]
#  [ 1.56116048e-02]
#  [ 2.28383206e-02]
#  [ 2.94573158e-02]
#  [ 2.75403783e-02]
#  [ 2.94525363e-02]
#  [ 2.93543562e-02]
#  [ 2.04418264e-02]
#  [ 1.71427242e-02]
#  [ 2.92209573e-02]
#  [ 3.26696299e-02]
#  [ 2.40292363e-02]
#  [ 2.09188610e-02]
#  [ 2.62667425e-02]
#  [ 2.47719772e-02]
#  [ 2.54885890e-02]
#  [ 2.97562107e-02]
#  [ 3.14006954e-02]
#  [ 2.75533982e-02]
#  [ 2.63080783e-02]
#  [ 3.74307930e-02]
#  [ 4.28709313e-02]
#  [ 3.86135913e-02]
#  [ 3.17015052e-02]
#  [ 2.98941359e-02]
#  [ 3.20437402e-02]
#  [ 4.93356958e-02]
#  [ 4.86703590e-02]
#  [ 2.56990865e-02]
#  [ 8.78142659e-03]
#  [ 1.89548880e-02]
#  [ 3.97771969e-02]
#  [ 3.44895422e-02]
#  [ 1.68995261e-02]
#  [ 1.58611178e-01]
#  [ 1.41950145e-01]
#  [ 1.22472592e-01]
#  [ 1.31580621e-01]
#  [ 1.58820376e-01]
#  [ 1.49927929e-01]
#  [ 1.18616678e-01]
#  [ 1.36633441e-01]
#  [ 1.36183187e-01]
#  [ 1.18827879e-01]
#  [ 1.32941827e-01]
#  [ 1.40850827e-01]
#  [ 1.34550482e-01]
#  [ 1.30347744e-01]
#  [ 1.40538856e-01]
#  [ 1.34174153e-01]
#  [ 1.35501906e-01]
#  [ 1.39290452e-01]
#  [ 1.38034984e-01]
#  [ 1.32930949e-01]
#  [ 1.36086270e-01]
#  [ 1.44131586e-01]
#  [ 1.27849132e-01]
#  [ 1.05396472e-01]
#  [ 1.08124606e-01]
#  [ 1.18957505e-01]
#  [ 1.20425180e-01]
#  [ 1.20993160e-01]
#  [ 1.23620063e-01]
#  [ 1.14193887e-01]
#  [ 1.02508642e-01]
#  [ 1.14490196e-01]
#  [ 1.25056192e-01]
#  [ 1.37335166e-01]
#  [ 1.41487136e-01]
#  [ 1.48047760e-01]
#  [ 1.38109297e-01]
#  [ 1.27379656e-01]
#  [ 1.51459530e-01]
#  [ 1.66340619e-01]
#  [ 1.51585251e-01]
#  [ 1.43910408e-01]
#  [ 1.55716375e-01]
#  [ 1.61131069e-01]
#  [ 1.69598579e-01]
#  [ 1.89462170e-01]
#  [ 1.88482061e-01]
#  [ 1.91065252e-01]
#  [ 1.96827143e-01]
#  [ 2.10656732e-01]
#  [ 2.10163757e-01]
#  [ 1.97071791e-01]
#  [ 1.97936997e-01]
#  [ 2.06669226e-01]
#  [ 2.12768480e-01]
#  [ 2.06538096e-01]
#  [ 2.03386128e-01]
#  [ 1.95955500e-01]
#  [ 1.88163266e-01]
#  [ 2.02218756e-01]
#  [ 2.06226021e-01]
#  [ 2.07700565e-01]
#  [ 2.08371148e-01]
#  [ 2.21537128e-01]
#  [ 2.10032448e-01]
#  [ 1.92863092e-01]
#  [ 2.06871107e-01]
#  [ 2.11419418e-01]
#  [ 2.10413501e-01]
#  [ 2.15380326e-01]
#  [ 2.36307696e-01]
#  [ 2.38011688e-01]
#  [ 2.36376390e-01]
#  [ 2.40087792e-01]
#  [ 2.49032781e-01]
#  [ 2.55246371e-01]
#  [ 2.75577843e-01]
#  [ 2.72301167e-01]
#  [ 2.47305617e-01]
#  [ 2.16555342e-01]
#  [ 2.09824696e-01]]
# rmse = 0.12896255068810344
# mae = 0.0748985224897696
# mape = 0.4703044256954509
# testY
# testY.shape
# (447,)
# <class 'numpy.ndarray'>
# prediction_val
# (447,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# 20/20 - 4s - 205ms/step - loss: 0.0070 - val_loss: 0.0121
# Epoch 2/50
# 20/20 - 1s - 43ms/step - loss: 0.0015 - val_loss: 0.0106
# Epoch 3/50
# 20/20 - 0s - 11ms/step - loss: 0.0012 - val_loss: 0.0130
# Epoch 4/50
# 20/20 - 0s - 13ms/step - loss: 2.5646e-04 - val_loss: 0.0067
# Epoch 34/50
# 20/20 - 0s - 14ms/step - loss: 2.5798e-04 - val_loss: 0.0072
# Epoch 35/50
# 20/20 - 0s - 14ms/step - loss: 2.5325e-04 - val_loss: 0.0064
# Epoch 36/50
# 20/20 - 0s - 13ms/step - loss: 2.4404e-04 - val_loss: 0.0063
# Epoch 37/50
# 20/20 - 0s - 18ms/step - loss: 2.4084e-04 - val_loss: 0.0068
# Epoch 38/50
# 20/20 - 0s - 13ms/step - loss: 2.4493e-04 - val_loss: 0.0066
# Epoch 39/50
# 20/20 - 0s - 14ms/step - loss: 2.4010e-04 - val_loss: 0.0063
# Epoch 40/50
# 20/20 - 0s - 16ms/step - loss: 2.3404e-04 - val_loss: 0.0063
# Epoch 41/50
# 20/20 - 0s - 14ms/step - loss: 2.3579e-04 - val_loss: 0.0066
# Epoch 42/50
# 20/20 - 0s - 14ms/step - loss: 2.3926e-04 - val_loss: 0.0064
# Epoch 43/50
# 20/20 - 0s - 14ms/step - loss: 2.3570e-04 - val_loss: 0.0062
# Epoch 44/50
# 20/20 - 0s - 13ms/step - loss: 2.2987e-04 - val_loss: 0.0063
# Epoch 45/50
# 20/20 - 0s - 15ms/step - loss: 2.3468e-04 - val_loss: 0.0066
# Epoch 46/50
# 20/20 - 0s - 15ms/step - loss: 2.4344e-04 - val_loss: 0.0063
# Epoch 47/50
# 20/20 - 0s - 16ms/step - loss: 2.4134e-04 - val_loss: 0.0063
# Epoch 48/50
# 20/20 - 0s - 16ms/step - loss: 2.4086e-04 - val_loss: 0.0062
# Epoch 49/50
# 20/20 - 0s - 15ms/step - loss: 2.4152e-04 - val_loss: 0.0067
# Epoch 50/50
# 20/20 - 0s - 13ms/step - loss: 2.8314e-04 - val_loss: 0.0065
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# <class 'numpy.ndarray'>
# [[0.07535386]
#  [0.08226658]
#  [0.08870611]
#  [0.09420501]
#  [0.09262567]
#  [0.08296102]
#  [0.08436408]
#  [0.08085928]
#  [0.08325033]
#  [0.08889621]
#  [0.10052495]
#  [0.09859738]
#  [0.09298167]
#  [0.06981872]
#  [0.07005067]
#  [0.07180949]
#  [0.06411416]
#  [0.0666685 ]
#  [0.06631172]
#  [0.06434201]
#  [0.06075354]
#  [0.05966985]
#  [0.06261876]
#  [0.06262883]
#  [0.07159932]
#  [0.07390942]
#  [0.07244282]
#  [0.07923216]
#  [0.08739115]
#  [0.09645925]
#  [0.09731562]
#  [0.0983112 ]
#  [0.10727659]
#  [0.09886285]
#  [0.09519541]
#  [0.10447497]
#  [0.10227228]
#  [0.10778005]
#  [0.10646435]
#  [0.10372707]
#  [0.10093153]
#  [0.09485574]
#  [0.09382788]
#  [0.08825196]
#  [0.08772234]
#  [0.08610984]
#  [0.09817159]
#  [0.10335629]
#  [0.10628168]
#  [0.10919655]
#  [0.10366151]
#  [0.11402319]
#  [0.11531067]
#  [0.12283082]
#  [0.12903194]
#  [0.11807976]
#  [0.1261021 ]
#  [0.11648422]
#  [0.11301397]
#  [0.11915098]
#  [0.12595315]
#  [0.1273066 ]
#  [0.1314445 ]
#  [0.13363291]
#  [0.13641864]
#  [0.14398417]
#  [0.1646408 ]
#  [0.16424368]
#  [0.15502208]
#  [0.15594126]
#  [0.1364929 ]
#  [0.14084314]
#  [0.13978411]
#  [0.13685234]
#  [0.12615027]
#  [0.11860546]
#  [0.1175959 ]
#  [0.11675365]
#  [0.11010259]
#  [0.11719418]
#  [0.11666448]
#  [0.12174145]
#  [0.11892679]
#  [0.12754509]
#  [0.15370958]
#  [0.15727195]
#  [0.19614135]
#  [0.22200964]
#  [0.23608103]
#  [0.20804268]
#  [0.19128746]
#  [0.18217583]
#  [0.17929463]
#  [0.19853769]
#  [0.22549392]
#  [0.2327819 ]
#  [0.2236102 ]
#  [0.19499771]
#  [0.17887042]
#  [0.17774032]
#  [0.17863725]
#  [0.17056088]
#  [0.17544158]
#  [0.16117318]
#  [0.15651497]
#  [0.1480274 ]
#  [0.14143999]
#  [0.1321532 ]
#  [0.11399899]
#  [0.11448183]
#  [0.11952311]
#  [0.1202537 ]
#  [0.1266701 ]
#  [0.1319557 ]
#  [0.12346207]
#  [0.12142516]
#  [0.11259299]
#  [0.11347491]
#  [0.11286228]
#  [0.1096475 ]
#  [0.10367577]
#  [0.09267022]
#  [0.09067993]
#  [0.09103982]
#  [0.08892652]
#  [0.0835951 ]
#  [0.08781688]
#  [0.08737244]
#  [0.08448924]
#  [0.09272756]
#  [0.08895959]
#  [0.08735318]
#  [0.09101749]
#  [0.09033458]
#  [0.08959081]
#  [0.07781203]
#  [0.04993201]
#  [0.03823315]
#  [0.04734564]
#  [0.05891847]
#  [0.07945545]
#  [0.08921565]
#  [0.06361362]
#  [0.04975664]
#  [0.06112343]
#  [0.07641832]
#  [0.08670344]
#  [0.07792483]
#  [0.07779741]
#  [0.07030126]
#  [0.0696013 ]
#  [0.06686261]
#  [0.0624897 ]
#  [0.063309  ]
#  [0.06584167]
#  [0.06695856]
#  [0.05838931]
#  [0.05400466]
#  [0.05303525]
#  [0.05160772]
#  [0.05385653]
#  [0.05372507]
#  [0.05425866]
#  [0.0582319 ]
#  [0.06072218]
#  [0.06423204]
#  [0.06393747]
#  [0.06674527]
#  [0.07221424]
#  [0.06997105]
#  [0.0789467 ]
#  [0.08220569]
#  [0.07924964]
#  [0.08945142]
#  [0.09102453]
#  [0.08707046]
#  [0.09137756]
#  [0.10049327]
#  [0.09880247]
#  [0.10215612]
#  [0.10916923]
#  [0.11052041]
#  [0.11276545]
#  [0.11812697]
#  [0.11650724]
#  [0.11589796]
#  [0.12467457]
#  [0.12626876]
#  [0.12743773]
#  [0.12778069]
#  [0.1201623 ]
#  [0.1196212 ]
#  [0.13209121]
#  [0.14544196]
#  [0.14658476]
#  [0.15120824]
#  [0.13751633]
#  [0.1339073 ]
#  [0.14189655]
#  [0.15322883]
#  [0.1627649 ]
#  [0.17080112]
#  [0.17756675]
#  [0.16482703]
#  [0.161878  ]
#  [0.17242385]
#  [0.17581956]
#  [0.19790952]
#  [0.21541986]
#  [0.20329082]
#  [0.18230675]
#  [0.18257459]
#  [0.18576361]
#  [0.18225951]
#  [0.1832106 ]
#  [0.18221971]
#  [0.1752358 ]
#  [0.17259128]
#  [0.18938582]
#  [0.19983394]
#  [0.1883802 ]
#  [0.16853872]
#  [0.15976883]
#  [0.1669813 ]
#  [0.16555287]
#  [0.17053576]
#  [0.17622271]
#  [0.1468618 ]
#  [0.14808677]
#  [0.146186  ]
#  [0.15417363]
#  [0.14981563]
#  [0.14958237]
#  [0.15045561]
#  [0.16370915]
#  [0.19704726]
#  [0.22638471]
#  [0.22436045]
#  [0.20917828]
#  [0.1928751 ]
#  [0.18716426]
#  [0.19556327]
#  [0.20218633]
#  [0.22029983]
#  [0.21125327]
#  [0.20484258]
#  [0.19531934]
#  [0.18817817]
#  [0.1873395 ]
#  [0.19081342]
#  [0.20106126]
#  [0.22219837]
#  [0.2263088 ]
#  [0.21861406]
#  [0.21784036]
#  [0.22213896]
#  [0.23845302]
#  [0.2662127 ]
#  [0.29175478]
#  [0.3023306 ]
#  [0.28192067]
#  [0.27149153]
#  [0.2800361 ]
#  [0.29649162]
#  [0.30530655]
#  [0.31948504]
#  [0.32368463]
#  [0.2917508 ]
#  [0.28690723]
#  [0.29182255]
#  [0.28991556]
#  [0.29237086]
#  [0.2820871 ]
#  [0.28472793]
#  [0.27757496]
#  [0.27452162]
#  [0.28370625]
#  [0.2959173 ]
#  [0.30055523]
#  [0.285819  ]
#  [0.28468072]
#  [0.26813456]
#  [0.26832962]
#  [0.28492406]
#  [0.28538877]
#  [0.3052463 ]
#  [0.2787488 ]
#  [0.27335387]
#  [0.2831797 ]
#  [0.29560345]
#  [0.30050653]
#  [0.3078487 ]
#  [0.3031645 ]
#  [0.29296148]
#  [0.29347125]
#  [0.28834873]
#  [0.32279032]
#  [0.33042508]
#  [0.33488876]
#  [0.31211215]
#  [0.2893183 ]
#  [0.2724411 ]
#  [0.24548616]
#  [0.25347286]
#  [0.24548526]
#  [0.23895378]
#  [0.193253  ]
#  [0.17811929]
#  [0.16289422]
#  [0.1526108 ]
#  [0.14489888]
#  [0.13885821]]
# rmse = 0.07859811278956438
# mae = 0.04399355979125852
# mape = 0.2639361547140996
# testY
# testY.shape
# (312,)
# <class 'numpy.ndarray'>
# prediction_val
# (312,)
# <class 'numpy.ndarray'>
# binance
# rmse = 0.10390857969662326
# mae = 0.06372553361999683
# mape = 0.35737833943850345
#
# coinbase
# rmse = 0.13712910680478949
# mae = 0.103339492106451
# mape = 0.6400598493959716
#
# huobi
# rmse = 0.07673653521430605
# mae = 0.03058149463947263
# mape = 0.39819660823888586
#
# kraken
# rmse = 0.12896255068810344
# mae = 0.0748985224897696
# mape = 0.4703044256954509
#
# kucoin
# rmse = 0.07859811278956438
# mae = 0.04399355979125852
# mape = 0.2639361547140996
