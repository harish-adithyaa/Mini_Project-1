# %%
import keras
from keras import backend as K
from keras import optimizers
import tensorflow
from keras.models import Sequential, Model
from keras.layers import Lambda, Activation, Input, Dense, Dropout, SimpleRNN, Flatten, \
    LSTM, GRU, Bidirectional, Layer, Permute, Reshape, Multiply, RepeatVector, Dot, Concatenate

import pandas as pd
import numpy as np
import math
from math import sqrt
import os
import csv
from keras.models import Sequential, Model
from keras.layers import Lambda, Activation, Input, Dense, Dropout, SimpleRNN, Flatten, \
    LSTM, GRU, Bidirectional, Layer, Permute, Reshape, Multiply, RepeatVector, Dot, Concatenate

from keras import optimizers
import keras.backend as K
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.vector_ar.var_model import VAR
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import tensorflow as tf
import numpy.linalg as la
import time
import matplotlib.dates as mdates
font1 = {'family': 'Microsoft YaHei',
         'weight': 'normal',
         'size': 13}
plt.style.use('default')
tensorflow.random.set_seed(2)
exchanges = ["binance", "coinbase", "huobi", "kraken", "kucoin"]
beginDates = ['2021-01-30', '2021-11-05', '2020-11-03', '2020-06-25', '2021-02-15']
endDates = ['2021-12-23', '2021-12-24', '2021-09-15', '2021-09-15', '2021-12-24']

li = [] #Save the location of outliers detected using LSTM
li.append([95, 110, 111, 115, 116, 238])
li.append([30])
li.append([153, 190, 241])
li.append([313, 327, 329])
li.append([216, 256, 275, 295])

class attention(Layer):'''This class defines a custom attention layer for neural network architectures,specifically
    designed for sequence-to-sequence models or sequence prediction tasks.'''
    def __init__(self,**kwargs):#This method initializes the attention layer.
        super(attention,self).__init__(**kwargs)

    def build(self,input_shape):#It defines the weights of the layer, specifically the weight matrix (W) and bias vector (b)
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")
        super(attention, self).build(input_shape)

    def call(self, x):
        et = tensorflow.squeeze(keras.activations.sigmoid(tf.matmul(x, self.W) + self.b), axis=-1)

        at = at = tf.keras.activations.softmax(et)

        at = tf.expand_dims(at, axis=-1)
        output = x * at
        return tf.reduce_sum(output, axis=1)


    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()


def model_lstm_att(time_steps, input_dim, n_units, method="LSTM"):
#This function is responsible for creating a recurrent neural network (RNN) model with an attention mechanism
    K.clear_session()  
    model_input = Input(shape=(time_steps, input_dim))
    if method == "LSTM":
        x = LSTM(n_units, return_sequences=True)(model_input)
    elif method == "GRU":
        x = GRU(n_units, return_sequences=True)(model_input)
    elif method == "RNN":
        x = SimpleRNN(n_units, return_sequences=True)(model_input)
    x = attention()(x)
    x = Dense(1)(x)
    model = Model(model_input, x)
    return model
def model_lstm(seq_len, n_features, n_units):
#This function model_lstm creates a simple LSTM (Long Short-Term Memory) neural network model
    model = Sequential()
    model.add(LSTM(n_units, activation="relu", input_shape=(seq_len, n_features)))
    model.add(Dense(1))
    return model

def evaluation(real, pre):
    #This evaluation function computes various evaluation metrics to assess the performance of a predictive model. 
    rmse = mean_squared_error(real, pre, squared=False)
    mae = mean_absolute_error(real, pre)
    mape = mean_absolute_percentage_error(real, pre)
    r2 = r2_score(real, pre)
    var = 1-(np.var(real - pre))/np.var(real)
    F_norm = la.norm(real-pre)/la.norm(real)

    return rmse, mae, mape, r2, var, 1-F_norm

def min_max_scaler(li):
#implementation of min-max scaling
#range between 0 and 1
    min_ = min(li)
    max_ = max(li)
    ret = [(i - min_) / (max_ - min_) for i in li]
    return ret, min_, max_

def data_split(data, train_rate, seq_len, pre_len=1):
    time_len, n_feature = data.shape
    train_size = int(time_len * train_rate)
    train_data = data[0:train_size]
    trainX, trainY, testX, testY = [], [], [], []
    for i in range(train_size-seq_len-pre_len):
        a = train_data[i: i + seq_len + pre_len]
        trainX.append(a[0: seq_len])
        trainY.append(a[seq_len: seq_len + pre_len, 0])
    for i in range(train_size-seq_len-pre_len, time_len-pre_len-seq_len):
        b = data[i: i+seq_len+pre_len,:]
        testX.append(b[0:seq_len])
        testY.append(b[seq_len:seq_len+pre_len, 0])
    trainX1 = np.array(trainX)
    trainY1 = np.array(trainY)
    testX1 = np.array(testX)
    testY1 = np.array(testY)
    return trainX1, trainY1, testX1, testY1

def lstm(n_units=64, seq_len=10, batch_size=64, method="LSTM"):
    error_list = []
    rmse_list = []
    mae_list = []
    mape_list = []
    for i in range(len(exchanges)):
        exchange = exchanges[i]
        important = True
        if important:
            file = open("E:\\MiniProject\\exchange_anomaly_detection-main\\exchange\\feature\\" + exchange + '_ft.csv')
        else:
            file = open("E:\\MiniProject\\exchange_anomaly_detection-main\\exchange\\feature\\" + exchange + '_ft_not_important.csv')
        df = pd.read_csv(file)

        data = df.values
        print("type data")
        print(type(data))
        time_len, n_features = data.shape
        train_rate = 0.8
        train_size = int(time_len*train_rate)
        trainX, trainY, testX, testY = data_split(data, train_rate=train_rate, seq_len=seq_len)
        scaled_data = data.copy()
        #Normalize the features of each column
        scaler = []
        for j in range(n_features):
            temp_scaler = MinMaxScaler(feature_range=(0, 1))
            temp = temp_scaler.fit_transform(np.array(scaled_data[:, j]).reshape(-1,1))
            scaler.append(temp_scaler)
            temp = temp.reshape(-1)
            scaled_data[:, j] = temp
        trainX1, trainY1, testX1, testY1 = data_split(scaled_data, train_rate=train_rate, seq_len=seq_len)

        model_name = method+"_attention"

        if model_name=="LSTM_attention" or model_name=="GRU_attention" or model_name=="RNN_attention":
            model = model_lstm_att(seq_len, n_features, n_units, method=method)
        if model_name=="LSTM":
            model = model_lstm(seq_len, n_features, n_units)

        opt = optimizers.Adam()
        model.compile(optimizer=opt, loss='mse')
        history = model.fit(trainX1, trainY1, epochs=50, batch_size=batch_size, validation_data=(testX1, testY1), verbose=2, shuffle=False)
        if True:
            plt.figure(figsize=(10, 5))
            plt.grid(linestyle="--")
            plt.plot(history.history['loss'], label='train')
            plt.plot(history.history['val_loss'], label='test')
            plt.legend()
            plt.title(exchange)
            plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure/lstm_prediction" + exchange + '_' + model_name + '_loss.png')
            plt.show()
        prediction_val = model.predict(testX1)
        print(type(prediction_val))
        print(prediction_val)

        rmse, mae, mape, r2, var, _ = evaluation(testY1, prediction_val)
        print("rmse = {}\nmae = {}\nmape = {}".format(rmse, mae, mape))
        error_list.append("rmse = {}\nmae = {}\nmape = {}\n".format(rmse, mae, mape))

        rmse_list.append(rmse)
        mae_list.append(mae)
        mape_list.append(mape)

        prediction_val = np.array(scaled_data[0:train_size, 0].tolist()+prediction_val[:, 0].tolist())
        prediction_val = prediction_val.reshape(-1,1)
        prediction_val = scaler[0].inverse_transform(prediction_val)
        prediction_val = prediction_val[train_size:,0]
        print("testY")
        testY = testY[:,0]
        print("testY.shape")
        print(testY.shape)
        print(type(testY))
        print("prediction_val")
        print(prediction_val.shape)
        print(type(prediction_val))

        if True:
            # plt.figure(figsize=(10, 4))
            # plt.grid(linestyle="--")
            # plt.plot(range(time_len-train_size), testY)
            # plt.plot(range(time_len-train_size), np.array(prediction_val))
            upper_bound = [it + 3 * np.std(testY) for it in prediction_val]
            lower_bound = [it - 3 * np.std(testY) for it in prediction_val]

            fig, ax = plt.subplots(figsize=(10, 4),dpi=300)
            beginDate = beginDates[i]
            endDate = endDates[i]

            x = np.arange(mdates.datestr2num(beginDate), mdates.datestr2num(endDate))
            x_range = [np.datetime64(int(c), 'D') for c in x]
            # plt.figure(figsize=(10, 4))
            # plt.grid(linestyle="--")

            abnormal_x = []
            abnormal_y = []
            for j in range(len(upper_bound)):
                if testY[j] > upper_bound[j]:
                    abnormal_x.append(x_range[j])
                    abnormal_y.append(testY[j])

            miss_x = []
            miss_y = []
            for j in range(len(li[i])):
                if x_range[li[i][j]] not in abnormal_x:
                    miss_x.append(x_range[li[i][j]])
                    miss_y.append(testY[li[i][j]])

            fmt_half_year = mdates.MonthLocator(interval=1)
            ax.xaxis.set_major_locator(fmt_half_year)

            fmt_month = mdates.MonthLocator() 
            ax.xaxis.set_minor_locator(fmt_month)

            ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))

            datemin = np.datetime64(x_range[0], 'M')
            # datemax = np.datetime64(x_range[-1], 'Y') + np.timedelta64(1, 'Y')
            datemax = np.datetime64(x_range[-1], 'M') + np.timedelta64(1, 'M')
            ax.set_xlim(datemin, datemax)

            ax.format_xdata = mdates.DateFormatter('%Y-%m')
            ax.format_ydata = lambda x: f'$x:.2f$'
            ax.grid(True)
            fig.autofmt_xdate()

            ax.plot(x_range, testY)
            ax.plot(x_range, np.array(prediction_val))
            ax.plot(x_range, upper_bound, "--")
            ax.plot(x_range, lower_bound, "--")
            ax.scatter(abnormal_x, abnormal_y, c="r", marker="o")
            ax.scatter(miss_x, miss_y, c="dimgrey", marker="o")
            if method=="LSTM":
                plt.legend(("Real", model_name, "Upper bound", "Lower bound", "Anomaly detected"), loc=2)
            else:
                plt.legend(("Real", model_name, "Upper bound", "Lower bound", "Anomaly detected", "Anomaly missed"), loc=2)

            plt.title(exchange.title())
            plt.xlabel("time", font1)
            # plt.ylabel("Transaction Amount(USD)")
            plt.ylabel("Trading volume (USD）", font1)
            plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure"+str.lower(method)+'_prediction_' + exchange + '_' + model_name + '_prediction.png')
            plt.show()
    for i in range(len(exchanges)):
        print(exchanges[i])
        print(error_list[i])
    return rmse_list, mae_list, mape_list

def parameter_sensitivity(parameter, para_range):
    rmse_list = [[] for i in range(len(exchanges))]
    mae_list = [[] for i in range(len(exchanges))]
    mape_list = [[] for i in range(len(exchanges))]
    for it in para_range:
        if parameter=="Number of hidden units":
            temp_rmse, temp_mae, temp_mape = lstm(n_units=it)
        if parameter=="Sequence length":
            temp_rmse, temp_mae, temp_mape = lstm(seq_len=it)
        if parameter == "Batch size":
            temp_rmse, temp_mae, temp_mape = lstm(batch_size=it)
        for jj in range(len(temp_rmse)):
            rmse_list[jj].append(temp_rmse[jj])
            mae_list[jj].append(temp_mae[jj])
            mape_list[jj].append(temp_mape[jj])
    for i in range(len(exchanges)):
        exchange = exchanges[i]
        rmse_list[i],_,_ = min_max_scaler(rmse_list[i])
        mae_list[i],_,_ = min_max_scaler(mae_list[i])
        mape_list[i],_,_ = min_max_scaler(mape_list[i])
        plt.figure(figsize=(5, 4))

        plt.grid(linestyle="--")
        plt.plot(para_range, rmse_list[i])
        plt.plot(para_range, mae_list[i])
        plt.plot(para_range, mape_list[i])
        if i==0:
            plt.legend(("RMSE", "MAE", "MAPE"), loc='lower right')
        else:
            plt.legend(("RMSE", "MAE", "MAPE"))
        plt.xlabel(parameter)
        plt.ylabel("normalized value",font1)
        plt.title(exchange.title())
        plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure\para_" + parameter + '_' + exchange + '.png')
        plt.show()

def cal_date():
    li = []
    li.append([1400, 1415, 1416, 1420, 1421, 1543])
    li.append([222])
    li.append([1413, 1450, 1501])
    li.append([2097, 2111, 2113])
    li.append([1463, 1503, 1522, 1542])
    start_time = [1499212800, 1619481600, 1495497600, 1438905600, 1505606400]
    for i in range(len(li)):
        print(exchanges[i])
        for j in range(len(li[i])):
            temp_time = start_time[i] + li[i][j]*86400
            timeArray = time.localtime(temp_time)
            otherStyleTime = time.strftime("%Y-%m-%d %H:%M:%S", timeArray)
            print(otherStyleTime)
if __name__=='__main__':
    lstm(method="LSTM") #method = LSTM, RNN, GRU
# Out:
# type data
# <class 'numpy.ndarray'>
# WARNING:tensorflow:From C:\Users\kskis\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:73: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/50
# 21/21 - 4s - 179ms/step - loss: 0.0024 - val_loss: 0.0113
# Epoch 2/50
# 21/21 - 0s - 22ms/step - loss: 0.0010 - val_loss: 0.0098
# Epoch 3/50
# 21/21 - 0s - 21ms/step - loss: 7.5916e-04 - val_loss: 0.0101
# Epoch 4/50
# 21/21 - 0s - 20ms/step - loss: 5.0316e-04 - val_loss: 0.0119
# Epoch 5/50
# 21/21 - 0s - 20ms/step - loss: 8.8503e-04 - val_loss: 0.0114
# Epoch 6/50
# 21/21 - 0s - 16ms/step - loss: 5.1664e-04 - val_loss: 0.0098
# Epoch 7/50
# 21/21 - 0s - 21ms/step - loss: 6.6785e-04 - val_loss: 0.0105
# Epoch 8/50
# 21/21 - 0s - 21ms/step - loss: 5.7215e-04 - val_loss: 0.0116
# Epoch 9/50
# 21/21 - 0s - 22ms/step - loss: 4.3951e-04 - val_loss: 0.0099
# Epoch 10/50
# 21/21 - 0s - 20ms/step - loss: 5.3690e-04 - val_loss: 0.0100
# Epoch 11/50
# 21/21 - 0s - 19ms/step - loss: 3.3497e-04 - val_loss: 0.0109
# Epoch 12/50
# 21/21 - 0s - 20ms/step - loss: 4.3789e-04 - val_loss: 0.0103
# Epoch 13/50
# 21/21 - 0s - 19ms/step - loss: 3.4912e-04 - val_loss: 0.0099
# Epoch 14/50
# 21/21 - 0s - 18ms/step - loss: 3.5056e-04 - val_loss: 0.0103
# Epoch 15/50
# 21/21 - 0s - 19ms/step - loss: 3.5304e-04 - val_loss: 0.0104
# Epoch 16/50
# 21/21 - 1s - 25ms/step - loss: 2.8811e-04 - val_loss: 0.0098
# Epoch 17/50
# 21/21 - 0s - 21ms/step - loss: 3.5469e-04 - val_loss: 0.0100
# Epoch 18/50
# 21/21 - 0s - 21ms/step - loss: 2.6669e-04 - val_loss: 0.0102
# Epoch 19/50
# 21/21 - 0s - 20ms/step - loss: 3.1301e-04 - val_loss: 0.0099
# Epoch 20/50
# 21/21 - 0s - 21ms/step - loss: 2.8711e-04 - val_loss: 0.0099
# Epoch 21/50
# 21/21 - 0s - 24ms/step - loss: 2.9255e-04 - val_loss: 0.0101
# Epoch 22/50
# 21/21 - 0s - 22ms/step - loss: 2.8926e-04 - val_loss: 0.0100
# Epoch 23/50
# 21/21 - 0s - 24ms/step - loss: 2.6257e-04 - val_loss: 0.0098
# Epoch 24/50
# 21/21 - 1s - 24ms/step - loss: 3.0739e-04 - val_loss: 0.0100
# Epoch 25/50
# 21/21 - 0s - 22ms/step - loss: 2.4806e-04 - val_loss: 0.0101
# Epoch 26/50
# 21/21 - 0s - 21ms/step - loss: 2.9335e-04 - val_loss: 0.0099
# Epoch 27/50
# 21/21 - 0s - 22ms/step - loss: 2.4985e-04 - val_loss: 0.0099
# Epoch 28/50
# 21/21 - 0s - 24ms/step - loss: 2.9734e-04 - val_loss: 0.0100
# Epoch 29/50
# 21/21 - 0s - 23ms/step - loss: 2.4456e-04 - val_loss: 0.0100
# Epoch 30/50
# 21/21 - 0s - 22ms/step - loss: 2.7274e-04 - val_loss: 0.0098
# Epoch 31/50
# 21/21 - 0s - 17ms/step - loss: 2.5553e-04 - val_loss: 0.0099
# Epoch 32/50
# 21/21 - 0s - 17ms/step - loss: 2.6993e-04 - val_loss: 0.0101
# Epoch 33/50
# 21/21 - 0s - 21ms/step - loss: 2.4942e-04 - val_loss: 0.0100
# Epoch 34/50
# 21/21 - 0s - 22ms/step - loss: 2.4973e-04 - val_loss: 0.0098
# Epoch 35/50
# 21/21 - 0s - 20ms/step - loss: 2.5557e-04 - val_loss: 0.0099
# Epoch 36/50
# 21/21 - 0s - 19ms/step - loss: 2.4649e-04 - val_loss: 0.0101
# Epoch 37/50
# 21/21 - 0s - 18ms/step - loss: 2.4449e-04 - val_loss: 0.0100
# Epoch 38/50
# 21/21 - 0s - 19ms/step - loss: 2.3414e-04 - val_loss: 0.0099
# Epoch 39/50
# 21/21 - 0s - 19ms/step - loss: 2.4400e-04 - val_loss: 0.0100
# Epoch 40/50
# 21/21 - 0s - 21ms/step - loss: 2.3350e-04 - val_loss: 0.0101
# Epoch 41/50
# 21/21 - 0s - 20ms/step - loss: 2.3049e-04 - val_loss: 0.0101
# Epoch 42/50
# 21/21 - 0s - 18ms/step - loss: 2.2610e-04 - val_loss: 0.0099
# Epoch 43/50
# 21/21 - 0s - 19ms/step - loss: 2.2489e-04 - val_loss: 0.0100
# Epoch 44/50
# 21/21 - 0s - 16ms/step - loss: 2.2888e-04 - val_loss: 0.0102
# Epoch 45/50
# 21/21 - 0s - 17ms/step - loss: 2.1412e-04 - val_loss: 0.0102
# Epoch 46/50
# 21/21 - 0s - 20ms/step - loss: 2.2323e-04 - val_loss: 0.0100
# Epoch 47/50
# 21/21 - 0s - 17ms/step - loss: 2.0914e-04 - val_loss: 0.0100
# Epoch 48/50
# 21/21 - 0s - 17ms/step - loss: 2.2267e-04 - val_loss: 0.0101
# Epoch 49/50
# 21/21 - 0s - 17ms/step - loss: 2.1142e-04 - val_loss: 0.0104
# Epoch 50/50
# 21/21 - 0s - 17ms/step - loss: 2.1236e-04 - val_loss: 0.0103
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# <class 'numpy.ndarray'>
# [[0.12792951]
#  [0.12984955]
#  [0.12974662]
#  [0.13276425]
#  [0.13983488]
#  [0.14816864]
#  [0.1586636 ]
#  [0.16799243]
#  [0.1794999 ]
#  [0.18819512]
#  [0.19267401]
#  [0.1975992 ]
#  [0.20919085]
#  [0.21636899]
#  [0.21626149]
#  [0.22118667]
#  [0.22064966]
#  [0.21630967]
#  [0.21679448]
#  [0.21674198]
#  [0.21800002]
#  [0.2171363 ]
#  [0.21338193]
#  [0.2133037 ]
#  [0.21669179]
#  [0.21974933]
#  [0.22670905]
#  [0.23194364]
#  [0.22922552]
#  [0.2228372 ]
#  [0.2132698 ]
#  [0.19984707]
#  [0.189876  ]
#  [0.17867287]
#  [0.16736062]
#  [0.15549964]
#  [0.15215379]
#  [0.14595619]
#  [0.14577428]
#  [0.14856353]
#  [0.15039773]
#  [0.1521277 ]
#  [0.15390623]
#  [0.16062705]
#  [0.1625818 ]
#  [0.16776787]
#  [0.17697908]
#  [0.18747967]
#  [0.19143951]
#  [0.19527759]
#  [0.19839597]
#  [0.20064202]
#  [0.20087536]
#  [0.20219873]
#  [0.2028872 ]
#  [0.20202637]
#  [0.19933018]
#  [0.19752756]
#  [0.19772094]
#  [0.19655462]
#  [0.19478974]
#  [0.19555494]
#  [0.19471724]
#  [0.19316576]
#  [0.20140967]
#  [0.20113905]
#  [0.20043427]
#  [0.20173869]
#  [0.20686896]
#  [0.21147388]
#  [0.21272007]
#  [0.21476695]
#  [0.21239924]
#  [0.20996664]
#  [0.21110356]
#  [0.218933  ]
#  [0.23104295]
#  [0.23417057]
#  [0.2403191 ]
#  [0.24616933]
#  [0.25010702]
#  [0.25776738]
#  [0.27179903]
#  [0.27966207]
#  [0.28514206]
#  [0.28474587]
#  [0.27406043]
#  [0.26743138]
#  [0.25317714]
#  [0.24168919]
#  [0.24022855]
#  [0.23173289]
#  [0.22106762]
#  [0.2182946 ]
#  [0.2167968 ]
#  [0.2243295 ]
#  [0.2385665 ]
#  [0.25219235]
#  [0.26285344]
#  [0.27382314]
#  [0.28370893]
#  [0.29714936]
#  [0.31603202]
#  [0.33815408]
#  [0.35787073]
#  [0.36432076]
#  [0.37163618]
#  [0.36869943]
#  [0.35676074]
#  [0.34412768]
#  [0.32963985]
#  [0.3198231 ]
#  [0.30796134]
#  [0.28059244]
#  [0.26137936]
#  [0.25335035]
#  [0.24486049]
#  [0.23884547]
#  [0.2282728 ]
#  [0.21943414]
#  [0.20298122]
#  [0.19624114]
#  [0.19026543]
#  [0.18674743]
#  [0.18539602]
#  [0.18358041]
#  [0.18278067]
#  [0.18458226]
#  [0.17923158]
#  [0.1705748 ]
#  [0.16901019]
#  [0.17083642]
#  [0.16760923]
#  [0.1629837 ]
#  [0.16158552]
#  [0.15203744]
#  [0.14262515]
#  [0.14143181]
#  [0.14533208]
#  [0.14907783]
#  [0.151999  ]
#  [0.15507784]
#  [0.15321255]
#  [0.15006818]
#  [0.14931488]
#  [0.15393229]
#  [0.15716071]
#  [0.15508658]
#  [0.15001465]
#  [0.14511111]
#  [0.13847548]
#  [0.137831  ]
#  [0.14285795]
#  [0.14799285]
#  [0.14918423]
#  [0.15134439]
#  [0.15009901]
#  [0.15002677]
#  [0.15140516]
#  [0.157364  ]
#  [0.16235621]
#  [0.16746074]
#  [0.16942687]
#  [0.16990234]
#  [0.17033327]
#  [0.17459293]
#  [0.17902598]
#  [0.18414037]
#  [0.1864622 ]
#  [0.1807973 ]
#  [0.17360681]
#  [0.16908045]
#  [0.16596709]
#  [0.16612138]
#  [0.16847862]
#  [0.1641588 ]
#  [0.16078794]
#  [0.15774713]
#  [0.15448949]
#  [0.15733315]
#  [0.1608952 ]
#  [0.16781062]
#  [0.17233984]
#  [0.17829749]
#  [0.18372998]
#  [0.18517701]
#  [0.19117518]
#  [0.19851835]
#  [0.20752238]
#  [0.208065  ]
#  [0.2157767 ]
#  [0.21681355]
#  [0.2189163 ]
#  [0.21870221]
#  [0.22176158]
#  [0.22852844]
#  [0.22862789]
#  [0.22647516]
#  [0.22230743]
#  [0.2249815 ]
#  [0.22196037]
#  [0.22166903]
#  [0.22111773]
#  [0.22334574]
#  [0.22495365]
#  [0.21669552]
#  [0.21741685]
#  [0.22363451]
#  [0.22667973]
#  [0.23308073]
#  [0.23226084]
#  [0.2324487 ]
#  [0.23179352]
#  [0.22515966]
#  [0.22433524]
#  [0.22708035]
#  [0.23025279]
#  [0.23663512]
#  [0.24228713]
#  [0.24179263]
#  [0.24779814]
#  [0.25415683]
#  [0.2663164 ]
#  [0.2770621 ]
#  [0.27824414]
#  [0.27754587]
#  [0.26637313]
#  [0.25204188]
#  [0.24607432]
#  [0.23474318]
#  [0.22410683]
#  [0.21361873]
#  [0.19656706]
#  [0.18341076]
#  [0.17696014]
#  [0.1741454 ]
#  [0.17543551]
#  [0.17879802]
#  [0.17795877]
#  [0.18330948]
#  [0.18179321]
#  [0.17802705]
#  [0.17667262]
#  [0.17499086]
#  [0.17552868]
#  [0.17311318]
#  [0.17202117]
#  [0.16528653]
#  [0.1620662 ]
#  [0.1598608 ]
#  [0.16625144]
#  [0.176535  ]
#  [0.18742882]
#  [0.19500315]
#  [0.19930054]
#  [0.20260686]
#  [0.20936961]
#  [0.21343733]
#  [0.21659905]
#  [0.21704961]
#  [0.21715675]
#  [0.20810659]
#  [0.20228271]
#  [0.20247509]
#  [0.19773099]
#  [0.20335737]
#  [0.19922905]
#  [0.2003298 ]
#  [0.19953948]
#  [0.19887401]
#  [0.19844316]
#  [0.20400071]
#  [0.21174645]
#  [0.22078586]
#  [0.23076524]
#  [0.23330155]
#  [0.24198854]
#  [0.25040126]
#  [0.2614026 ]
#  [0.27166328]
#  [0.27766797]
#  [0.28399238]
#  [0.28296345]
#  [0.27545458]
#  [0.27170488]
#  [0.2725608 ]
#  [0.27381366]
#  [0.2776491 ]
#  [0.2748297 ]
#  [0.2685409 ]
#  [0.2618129 ]
#  [0.25369355]
#  [0.25548998]
#  [0.254342  ]
#  [0.24813181]
#  [0.23388705]
#  [0.23045026]
#  [0.22648951]
#  [0.22663929]
#  [0.22815025]
#  [0.23467562]
#  [0.23652701]
#  [0.23838031]
#  [0.23885092]
#  [0.23874788]
#  [0.24050495]
#  [0.24386415]
#  [0.24227332]
#  [0.2413935 ]
#  [0.2373619 ]
#  [0.22913271]
#  [0.22367367]
#  [0.22263005]
#  [0.22292545]
#  [0.22202472]
#  [0.21665005]
#  [0.20446403]
#  [0.19669314]
#  [0.19280718]
#  [0.18957017]
#  [0.18464649]
#  [0.18317498]
#  [0.1787125 ]
#  [0.17745961]
#  [0.17407362]
#  [0.17225194]
#  [0.17047481]]
# rmse = 0.10797889168143865
# mae = 0.07540931149072695
# mape = 0.4972545290846245
# testY
# testY.shape
# (327,)
# <class 'numpy.ndarray'>
# prediction_val
# (327,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# 3/3 - 3s - 1s/step - loss: 0.0297 - val_loss: 0.0400
# Epoch 2/50
# 3/3 - 0s - 42ms/step - loss: 0.0186 - val_loss: 0.0920
# Epoch 3/50
# 3/3 - 0s - 31ms/step - loss: 0.0190 - val_loss: 0.0557
# Epoch 4/50
# 3/3 - 0s - 42ms/step - loss: 0.0134 - val_loss: 0.0245
# Epoch 5/50
# 3/3 - 0s - 39ms/step - loss: 0.0140 - val_loss: 0.0168
# Epoch 6/50
# 3/3 - 0s - 31ms/step - loss: 0.0156 - val_loss: 0.0187
# Epoch 7/50
# 3/3 - 0s - 31ms/step - loss: 0.0145 - val_loss: 0.0278
# Epoch 8/50
# 3/3 - 0s - 37ms/step - loss: 0.0137 - val_loss: 0.0388
# Epoch 9/50
# 3/3 - 0s - 31ms/step - loss: 0.0140 - val_loss: 0.0406
# Epoch 10/50
# 3/3 - 0s - 40ms/step - loss: 0.0136 - val_loss: 0.0330
# Epoch 11/50
# 3/3 - 0s - 36ms/step - loss: 0.0130 - val_loss: 0.0254
# Epoch 12/50
# 3/3 - 0s - 31ms/step - loss: 0.0132 - val_loss: 0.0224
# Epoch 13/50
# 3/3 - 0s - 36ms/step - loss: 0.0134 - val_loss: 0.0238
# Epoch 14/50
# 3/3 - 0s - 42ms/step - loss: 0.0133 - val_loss: 0.0276
# Epoch 15/50
# 3/3 - 0s - 41ms/step - loss: 0.0132 - val_loss: 0.0304
# Epoch 16/50
# 3/3 - 0s - 42ms/step - loss: 0.0131 - val_loss: 0.0295
# Epoch 17/50
# 3/3 - 0s - 42ms/step - loss: 0.0130 - val_loss: 0.0264
# Epoch 18/50
# 3/3 - 0s - 42ms/step - loss: 0.0129 - val_loss: 0.0240
# Epoch 19/50
# 3/3 - 0s - 47ms/step - loss: 0.0130 - val_loss: 0.0237
# Epoch 20/50
# 3/3 - 0s - 47ms/step - loss: 0.0130 - val_loss: 0.0247
# Epoch 21/50
# 3/3 - 0s - 47ms/step - loss: 0.0130 - val_loss: 0.0256
# Epoch 22/50
# 3/3 - 0s - 42ms/step - loss: 0.0130 - val_loss: 0.0252
# Epoch 23/50
# 3/3 - 0s - 42ms/step - loss: 0.0129 - val_loss: 0.0237
# Epoch 24/50
# 3/3 - 0s - 42ms/step - loss: 0.0129 - val_loss: 0.0225
# Epoch 25/50
# 3/3 - 0s - 36ms/step - loss: 0.0129 - val_loss: 0.0221
# Epoch 26/50
# 3/3 - 0s - 42ms/step - loss: 0.0129 - val_loss: 0.0223
# Epoch 27/50
# 3/3 - 0s - 44ms/step - loss: 0.0129 - val_loss: 0.0221
# Epoch 28/50
# 3/3 - 0s - 46ms/step - loss: 0.0128 - val_loss: 0.0215
# Epoch 29/50
# 3/3 - 0s - 43ms/step - loss: 0.0128 - val_loss: 0.0206
# Epoch 30/50
# 3/3 - 0s - 45ms/step - loss: 0.0128 - val_loss: 0.0200
# Epoch 31/50
# 3/3 - 0s - 39ms/step - loss: 0.0128 - val_loss: 0.0198
# Epoch 32/50
# 3/3 - 0s - 39ms/step - loss: 0.0128 - val_loss: 0.0195
# Epoch 33/50
# 3/3 - 0s - 33ms/step - loss: 0.0128 - val_loss: 0.0191
# Epoch 34/50
# 3/3 - 0s - 54ms/step - loss: 0.0128 - val_loss: 0.0185
# Epoch 35/50
# 3/3 - 0s - 43ms/step - loss: 0.0127 - val_loss: 0.0181
# Epoch 36/50
# 3/3 - 0s - 55ms/step - loss: 0.0127 - val_loss: 0.0178
# Epoch 37/50
# 3/3 - 0s - 50ms/step - loss: 0.0127 - val_loss: 0.0175
# Epoch 38/50
# 3/3 - 0s - 54ms/step - loss: 0.0127 - val_loss: 0.0172
# Epoch 39/50
# 3/3 - 0s - 57ms/step - loss: 0.0127 - val_loss: 0.0169
# Epoch 40/50
# 3/3 - 0s - 52ms/step - loss: 0.0127 - val_loss: 0.0166
# Epoch 41/50
# 3/3 - 0s - 37ms/step - loss: 0.0127 - val_loss: 0.0165
# Epoch 42/50
# 3/3 - 0s - 39ms/step - loss: 0.0126 - val_loss: 0.0163
# Epoch 43/50
# 3/3 - 0s - 36ms/step - loss: 0.0126 - val_loss: 0.0162
# Epoch 44/50
# 3/3 - 0s - 37ms/step - loss: 0.0126 - val_loss: 0.0161
# Epoch 45/50
# 3/3 - 0s - 38ms/step - loss: 0.0126 - val_loss: 0.0161
# Epoch 46/50
# 3/3 - 0s - 43ms/step - loss: 0.0126 - val_loss: 0.0161
# Epoch 47/50
# 3/3 - 0s - 43ms/step - loss: 0.0126 - val_loss: 0.0161
# Epoch 48/50
# 3/3 - 0s - 50ms/step - loss: 0.0126 - val_loss: 0.0162
# Epoch 49/50
# 3/3 - 0s - 48ms/step - loss: 0.0125 - val_loss: 0.0164
# Epoch 50/50
# 3/3 - 0s - 45ms/step - loss: 0.0125 - val_loss: 0.0166
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# <class 'numpy.ndarray'>
# [[0.31343484]
#  [0.31849995]
#  [0.3125248 ]
#  [0.29750735]
#  [0.266887  ]
#  [0.25002548]
#  [0.24315396]
#  [0.24486889]
#  [0.24306484]
#  [0.23299319]
#  [0.22610845]
#  [0.22194557]
#  [0.21826634]
#  [0.21823509]
#  [0.22333269]
#  [0.22431998]
#  [0.22203644]
#  [0.21571617]
#  [0.21109474]
#  [0.20349719]
#  [0.1966113 ]
#  [0.19716427]
#  [0.19447304]
#  [0.19003873]
#  [0.18563579]
#  [0.17723028]
#  [0.17429854]
#  [0.17700495]
#  [0.18153001]
#  [0.17938076]
#  [0.17968364]
#  [0.17095849]
#  [0.1745344 ]
#  [0.17649332]
#  [0.18163957]
#  [0.18665248]
#  [0.18621197]
#  [0.1809511 ]
#  [0.17572862]
#  [0.17178899]
#  [0.1650282 ]
#  [0.14992647]
#  [0.14803071]
#  [0.14348859]
#  [0.14442758]
#  [0.14514393]
#  [0.14362155]
#  [0.13629358]
#  [0.13749628]]
# rmse = 0.12872133508267694
# mae = 0.08684398155082784
# mape = 0.4947785945598113
# testY
# testY.shape
# (49,)
# <class 'numpy.ndarray'>
# prediction_val
# (49,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# 20/20 - 3s - 160ms/step - loss: 1.0285e-04 - val_loss: 0.0064
# Epoch 2/50
# 20/20 - 0s - 16ms/step - loss: 1.4263e-04 - val_loss: 0.0090
# Epoch 3/50
# 20/20 - 0s - 16ms/step - loss: 1.5415e-04 - val_loss: 0.0051
# Epoch 4/50
# 20/20 - 0s - 16ms/step - loss: 2.5912e-04 - val_loss: 0.0064
# Epoch 5/50
# 20/20 - 0s - 14ms/step - loss: 1.0164e-04 - val_loss: 0.0080
# Epoch 6/50
# 20/20 - 0s - 15ms/step - loss: 1.1625e-04 - val_loss: 0.0092
# Epoch 7/50
# 20/20 - 0s - 16ms/step - loss: 1.3498e-04 - val_loss: 0.0070
# Epoch 8/50
# 20/20 - 0s - 16ms/step - loss: 1.0430e-04 - val_loss: 0.0052
# Epoch 9/50
# 20/20 - 0s - 16ms/step - loss: 1.3056e-04 - val_loss: 0.0053
# Epoch 10/50
# 20/20 - 0s - 16ms/step - loss: 1.2617e-04 - val_loss: 0.0076
# Epoch 11/50
# 20/20 - 0s - 17ms/step - loss: 1.2070e-04 - val_loss: 0.0093
# Epoch 12/50
# 20/20 - 0s - 16ms/step - loss: 1.3970e-04 - val_loss: 0.0064
# Epoch 13/50
# 20/20 - 0s - 16ms/step - loss: 1.0417e-04 - val_loss: 0.0050
# Epoch 14/50
# 20/20 - 0s - 16ms/step - loss: 1.3587e-04 - val_loss: 0.0056
# Epoch 15/50
# 20/20 - 0s - 16ms/step - loss: 1.1255e-04 - val_loss: 0.0082
# Epoch 16/50
# 20/20 - 0s - 14ms/step - loss: 1.2051e-04 - val_loss: 0.0077
# Epoch 17/50
# 20/20 - 0s - 14ms/step - loss: 1.0794e-04 - val_loss: 0.0055
# Epoch 18/50
# 20/20 - 0s - 16ms/step - loss: 9.9281e-05 - val_loss: 0.0052
# Epoch 19/50
# 20/20 - 0s - 15ms/step - loss: 1.0867e-04 - val_loss: 0.0066
# Epoch 20/50
# 20/20 - 0s - 14ms/step - loss: 9.2752e-05 - val_loss: 0.0074
# Epoch 21/50
# 20/20 - 0s - 17ms/step - loss: 9.8540e-05 - val_loss: 0.0060
# Epoch 22/50
# 20/20 - 0s - 16ms/step - loss: 8.3876e-05 - val_loss: 0.0053
# Epoch 23/50
# 20/20 - 0s - 16ms/step - loss: 9.3428e-05 - val_loss: 0.0059
# Epoch 24/50
# 20/20 - 0s - 15ms/step - loss: 8.5480e-05 - val_loss: 0.0068
# Epoch 25/50
# 20/20 - 0s - 16ms/step - loss: 8.8099e-05 - val_loss: 0.0063
# Epoch 26/50
# 20/20 - 0s - 16ms/step - loss: 8.2056e-05 - val_loss: 0.0055
# Epoch 27/50
# 20/20 - 0s - 16ms/step - loss: 8.3350e-05 - val_loss: 0.0056
# Epoch 28/50
# 20/20 - 0s - 19ms/step - loss: 8.4295e-05 - val_loss: 0.0062
# Epoch 29/50
# 20/20 - 0s - 15ms/step - loss: 8.2302e-05 - val_loss: 0.0065
# Epoch 30/50
# 20/20 - 0s - 15ms/step - loss: 8.3210e-05 - val_loss: 0.0058
# Epoch 31/50
# 20/20 - 0s - 14ms/step - loss: 7.9016e-05 - val_loss: 0.0055
# Epoch 32/50
# 20/20 - 0s - 14ms/step - loss: 8.2510e-05 - val_loss: 0.0057
# Epoch 33/50
# 20/20 - 0s - 15ms/step - loss: 8.0875e-05 - val_loss: 0.0063
# Epoch 34/50
# 20/20 - 0s - 16ms/step - loss: 8.1818e-05 - val_loss: 0.0062
# Epoch 35/50
# 20/20 - 0s - 16ms/step - loss: 8.1031e-05 - val_loss: 0.0056
# Epoch 36/50
# 20/20 - 0s - 16ms/step - loss: 7.8459e-05 - val_loss: 0.0054
# Epoch 37/50
# 20/20 - 0s - 16ms/step - loss: 8.1820e-05 - val_loss: 0.0057
# Epoch 38/50
# 20/20 - 0s - 17ms/step - loss: 7.9805e-05 - val_loss: 0.0062
# Epoch 39/50
# 20/20 - 0s - 16ms/step - loss: 8.1623e-05 - val_loss: 0.0061
# Epoch 40/50
# 20/20 - 0s - 16ms/step - loss: 8.0982e-05 - val_loss: 0.0056
# Epoch 41/50
# 20/20 - 0s - 16ms/step - loss: 7.7922e-05 - val_loss: 0.0053
# Epoch 42/50
# 20/20 - 0s - 16ms/step - loss: 8.1797e-05 - val_loss: 0.0055
# Epoch 43/50
# 20/20 - 0s - 15ms/step - loss: 7.9712e-05 - val_loss: 0.0061
# Epoch 44/50
# 20/20 - 0s - 15ms/step - loss: 8.0965e-05 - val_loss: 0.0062
# Epoch 45/50
# 20/20 - 0s - 15ms/step - loss: 8.2494e-05 - val_loss: 0.0056
# Epoch 46/50
# 20/20 - 0s - 17ms/step - loss: 7.7521e-05 - val_loss: 0.0052
# Epoch 47/50
# 20/20 - 0s - 17ms/step - loss: 8.1225e-05 - val_loss: 0.0053
# Epoch 48/50
# 20/20 - 0s - 17ms/step - loss: 8.0935e-05 - val_loss: 0.0059
# Epoch 49/50
# 20/20 - 0s - 20ms/step - loss: 7.9070e-05 - val_loss: 0.0062
# Epoch 50/50
# 20/20 - 0s - 17ms/step - loss: 8.3661e-05 - val_loss: 0.0058
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000014DE2799A80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# <class 'numpy.ndarray'>
# [[0.00981309]
#  [0.01176336]
#  [0.01386509]
#  [0.01505942]
#  [0.01576052]
#  [0.01638723]
#  [0.01690398]
#  [0.01652875]
#  [0.01599901]
#  [0.01681766]
#  [0.01766012]
#  [0.01940899]
#  [0.02051064]
#  [0.02048029]
#  [0.01945874]
#  [0.0184364 ]
#  [0.01867504]
#  [0.02075982]
#  [0.02125876]
#  [0.02246223]
#  [0.02330111]
#  [0.01630464]
#  [0.01647995]
#  [0.01758303]
#  [0.01815825]
#  [0.01915124]
#  [0.0182282 ]
#  [0.01614246]
#  [0.0151014 ]
#  [0.01422792]
#  [0.01406867]
#  [0.01338821]
#  [0.01211384]
#  [0.0110388 ]
#  [0.01036993]
#  [0.00848059]
#  [0.00827567]
#  [0.0083881 ]
#  [0.00905926]
#  [0.00812784]
#  [0.00749015]
#  [0.00749643]
#  [0.00735863]
#  [0.00738478]
#  [0.00757787]
#  [0.00848811]
#  [0.01069542]
#  [0.01161657]
#  [0.01175271]
#  [0.01109477]
#  [0.010936  ]
#  [0.01123671]
#  [0.01227002]
#  [0.01310751]
#  [0.01375819]
#  [0.0132575 ]
#  [0.01271702]
#  [0.0137423 ]
#  [0.01387695]
#  [0.01516092]
#  [0.01565545]
#  [0.01541656]
#  [0.01542711]
#  [0.01783779]
#  [0.02387062]
#  [0.02690671]
#  [0.02731655]
#  [0.02751865]
#  [0.0306678 ]
#  [0.03151144]
#  [0.03227606]
#  [0.03617479]
#  [0.03696623]
#  [0.03533569]
#  [0.03138628]
#  [0.03054701]
#  [0.03002567]
#  [0.02925103]
#  [0.02486748]
#  [0.02630198]
#  [0.0269242 ]
#  [0.0245815 ]
#  [0.02619004]
#  [0.02649201]
#  [0.02658608]
#  [0.02746831]
#  [0.02775128]
#  [0.02899698]
#  [0.02935938]
#  [0.02804825]
#  [0.02785503]
#  [0.0275111 ]
#  [0.02644321]
#  [0.02940068]
#  [0.03106557]
#  [0.03198583]
#  [0.03370592]
#  [0.03456553]
#  [0.03522209]
#  [0.03465241]
#  [0.0362829 ]
#  [0.03833181]
#  [0.03901375]
#  [0.03667148]
#  [0.0357006 ]
#  [0.03511664]
#  [0.03437107]
#  [0.03417497]
#  [0.03434731]
#  [0.03428207]
#  [0.0341448 ]
#  [0.03430345]
#  [0.03388258]
#  [0.03519031]
#  [0.03845678]
#  [0.03928381]
#  [0.03875464]
#  [0.03852742]
#  [0.03735109]
#  [0.03610836]
#  [0.03491919]
#  [0.03365757]
#  [0.03354989]
#  [0.03165174]
#  [0.02821399]
#  [0.02660549]
#  [0.02611248]
#  [0.02619807]
#  [0.02757567]
#  [0.02765859]
#  [0.02833536]
#  [0.02891999]
#  [0.0301904 ]
#  [0.03096594]
#  [0.03217378]
#  [0.0330593 ]
#  [0.03292583]
#  [0.03263243]
#  [0.0322301 ]
#  [0.03184281]
#  [0.03077305]
#  [0.03024741]
#  [0.02942175]
#  [0.02951679]
#  [0.02883747]
#  [0.02743653]
#  [0.02703802]
#  [0.02577646]
#  [0.02570648]
#  [0.02669299]
#  [0.02912906]
#  [0.03140321]
#  [0.03401142]
#  [0.03575975]
#  [0.04517445]
#  [0.05027815]
#  [0.05343463]
#  [0.05679011]
#  [0.05852142]
#  [0.05960064]
#  [0.05923714]
#  [0.05799944]
#  [0.05717395]
#  [0.05771369]
#  [0.04375646]
#  [0.04303254]
#  [0.04294831]
#  [0.04343021]
#  [0.04302104]
#  [0.0429698 ]
#  [0.04459275]
#  [0.04739062]
#  [0.04840492]
#  [0.04825937]
#  [0.04678918]
#  [0.04684146]
#  [0.04529383]
#  [0.04494661]
#  [0.04406349]
#  [0.04346548]
#  [0.04190968]
#  [0.03975002]
#  [0.03773489]
#  [0.03615318]
#  [0.03710472]
#  [0.03788036]
#  [0.0388663 ]
#  [0.03954561]
#  [0.04057427]
#  [0.04342034]
#  [0.04727521]
#  [0.06550387]
#  [0.07704663]
#  [0.08333465]
#  [0.08732942]
#  [0.08957039]
#  [0.09020901]
#  [0.09181315]
#  [0.09203041]
#  [0.09361207]
#  [0.09480345]
#  [0.06935696]
#  [0.06531917]
#  [0.05967042]
#  [0.05558036]
#  [0.05440579]
#  [0.05384937]
#  [0.05000205]
#  [0.04814122]
#  [0.04278919]
#  [0.03645752]
#  [0.03395088]
#  [0.03284613]
#  [0.03098148]
#  [0.02960338]
#  [0.02833536]
#  [0.02805042]
#  [0.02798358]
#  [0.02754188]
#  [0.02739888]
#  [0.02717708]
#  [0.02633562]
#  [0.02577056]
#  [0.02530819]
#  [0.02442575]
#  [0.02301815]
#  [0.02212308]
#  [0.02201612]
#  [0.02082416]
#  [0.01909065]
#  [0.01787139]
#  [0.01715849]
#  [0.0172464 ]
#  [0.01860465]
#  [0.01877459]
#  [0.01834718]
#  [0.01849489]
#  [0.01824893]
#  [0.01818927]
#  [0.0180852 ]
#  [0.01862483]
#  [0.01916746]
#  [0.02828074]
#  [0.03114358]
#  [0.03323216]
#  [0.03504547]
#  [0.03539332]
#  [0.03732875]
#  [0.03820833]
#  [0.03944153]
#  [0.04147585]
#  [0.04229711]
#  [0.02469546]
#  [0.02412768]
#  [0.02349356]
#  [0.02281752]
#  [0.0221005 ]
#  [0.02025102]
#  [0.01964898]
#  [0.01781499]
#  [0.01658626]
#  [0.01647049]
#  [0.01717559]
#  [0.01758254]
#  [0.01768525]
#  [0.01822123]
#  [0.01809329]
#  [0.01948234]
#  [0.02094946]
#  [0.02159773]
#  [0.02182326]
#  [0.02189939]
#  [0.02146819]
#  [0.02189674]
#  [0.02285049]
#  [0.02324513]
#  [0.02504231]
#  [0.02456697]
#  [0.02594244]
#  [0.02774084]
#  [0.02877689]
#  [0.03165802]
#  [0.03371734]
#  [0.03442305]
#  [0.03587213]
#  [0.03675374]
#  [0.0364139 ]
#  [0.03558891]
#  [0.03574439]
#  [0.03594634]
#  [0.03587719]
#  [0.03275108]
#  [0.03292692]
#  [0.03233857]
#  [0.03167343]
#  [0.03167932]
#  [0.03251866]
#  [0.03201083]
#  [0.03037985]
#  [0.03008306]
#  [0.03004071]
#  [0.03024561]
#  [0.03089954]
#  [0.03307192]
#  [0.0344283 ]
#  [0.03580628]
#  [0.03812436]
#  [0.04106397]
#  [0.04218607]
#  [0.04384462]
#  [0.04567171]
#  [0.04746221]
#  [0.04667917]
#  [0.04495667]
#  [0.04304269]
#  [0.04065821]]
# rmse = 0.07644167555632818
# mae = 0.030401298872468768
# mape = 0.4018134739178977
# testY
# testY.shape
# (316,)
# <class 'numpy.ndarray'>
# prediction_val
# (316,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# 28/28 - 3s - 119ms/step - loss: 8.3445e-04 - val_loss: 0.0243
# Epoch 2/50
# 28/28 - 1s - 19ms/step - loss: 7.5311e-04 - val_loss: 0.0139
# Epoch 3/50
# 28/28 - 0s - 17ms/step - loss: 8.2747e-04 - val_loss: 0.0211
# Epoch 4/50
# 28/28 - 1s - 20ms/step - loss: 6.8491e-04 - val_loss: 0.0137
# Epoch 5/50
# 28/28 - 0s - 17ms/step - loss: 6.4539e-04 - val_loss: 0.0155
# Epoch 6/50
# 28/28 - 0s - 15ms/step - loss: 6.0209e-04 - val_loss: 0.0150
# Epoch 7/50
# 28/28 - 0s - 16ms/step - loss: 8.1272e-04 - val_loss: 0.0176
# Epoch 8/50
# 28/28 - 0s - 16ms/step - loss: 6.4208e-04 - val_loss: 0.0244
# Epoch 9/50
# 28/28 - 0s - 17ms/step - loss: 5.9491e-04 - val_loss: 0.0249
# Epoch 10/50
# 28/28 - 0s - 17ms/step - loss: 6.0761e-04 - val_loss: 0.0258
# Epoch 11/50
# 28/28 - 0s - 16ms/step - loss: 6.3780e-04 - val_loss: 0.0206
# Epoch 12/50
# 28/28 - 0s - 16ms/step - loss: 5.8482e-04 - val_loss: 0.0184
# Epoch 13/50
# 28/28 - 0s - 16ms/step - loss: 5.3661e-04 - val_loss: 0.0179
# Epoch 14/50
# 28/28 - 0s - 15ms/step - loss: 5.4730e-04 - val_loss: 0.0194
# Epoch 15/50
# 28/28 - 0s - 16ms/step - loss: 5.4113e-04 - val_loss: 0.0216
# Epoch 16/50
# 28/28 - 0s - 16ms/step - loss: 5.3009e-04 - val_loss: 0.0227
# Epoch 17/50
# 28/28 - 0s - 14ms/step - loss: 5.3666e-04 - val_loss: 0.0225
# Epoch 18/50
# 28/28 - 0s - 17ms/step - loss: 5.4558e-04 - val_loss: 0.0210
# Epoch 19/50
# 28/28 - 0s - 17ms/step - loss: 5.4096e-04 - val_loss: 0.0197
# Epoch 20/50
# 28/28 - 1s - 19ms/step - loss: 5.2986e-04 - val_loss: 0.0189
# Epoch 21/50
# 28/28 - 0s - 16ms/step - loss: 5.2390e-04 - val_loss: 0.0190
# Epoch 22/50
# 28/28 - 0s - 15ms/step - loss: 5.2367e-04 - val_loss: 0.0199
# Epoch 23/50
# 28/28 - 0s - 15ms/step - loss: 5.2392e-04 - val_loss: 0.0210
# Epoch 24/50
# 28/28 - 0s - 15ms/step - loss: 5.2276e-04 - val_loss: 0.0221
# Epoch 25/50
# 28/28 - 0s - 16ms/step - loss: 5.2314e-04 - val_loss: 0.0227
# Epoch 26/50
# 28/28 - 0s - 13ms/step - loss: 5.2685e-04 - val_loss: 0.0225
# Epoch 27/50
# 28/28 - 0s - 14ms/step - loss: 5.3177e-04 - val_loss: 0.0215
# Epoch 28/50
# 28/28 - 1s - 20ms/step - loss: 5.3522e-04 - val_loss: 0.0202
# Epoch 29/50
# 28/28 - 0s - 16ms/step - loss: 5.3200e-04 - val_loss: 0.0190
# Epoch 30/50
# 28/28 - 0s - 16ms/step - loss: 5.2494e-04 - val_loss: 0.0183
# Epoch 31/50
# 28/28 - 0s - 17ms/step - loss: 5.1790e-04 - val_loss: 0.0181
# Epoch 32/50
# 28/28 - 0s - 15ms/step - loss: 5.1526e-04 - val_loss: 0.0185
# Epoch 33/50
# 28/28 - 0s - 15ms/step - loss: 5.1736e-04 - val_loss: 0.0193
# Epoch 34/50
# 28/28 - 0s - 15ms/step - loss: 5.2048e-04 - val_loss: 0.0210
# Epoch 35/50
# 28/28 - 0s - 15ms/step - loss: 5.2473e-04 - val_loss: 0.0224
# Epoch 36/50
# 28/28 - 0s - 17ms/step - loss: 5.2655e-04 - val_loss: 0.0237
# Epoch 37/50
# 28/28 - 0s - 17ms/step - loss: 5.2758e-04 - val_loss: 0.0243
# Epoch 38/50
# 28/28 - 1s - 18ms/step - loss: 5.2652e-04 - val_loss: 0.0246
# Epoch 39/50
# 28/28 - 0s - 17ms/step - loss: 5.2497e-04 - val_loss: 0.0238
# Epoch 40/50
# 28/28 - 0s - 17ms/step - loss: 5.4080e-04 - val_loss: 0.0222
# Epoch 41/50
# 28/28 - 0s - 15ms/step - loss: 5.3269e-04 - val_loss: 0.0194
# Epoch 42/50
# 28/28 - 0s - 16ms/step - loss: 5.7000e-04 - val_loss: 0.0171
# Epoch 43/50
# 28/28 - 0s - 17ms/step - loss: 5.2859e-04 - val_loss: 0.0189
# Epoch 44/50
# 28/28 - 0s - 15ms/step - loss: 5.8152e-04 - val_loss: 0.0129
# Epoch 45/50
# 28/28 - 0s - 17ms/step - loss: 6.0897e-04 - val_loss: 0.0248
# Epoch 46/50
# 28/28 - 0s - 16ms/step - loss: 6.7338e-04 - val_loss: 0.0159
# Epoch 47/50
# 28/28 - 0s - 17ms/step - loss: 7.2187e-04 - val_loss: 0.0176
# Epoch 48/50
# 28/28 - 0s - 17ms/step - loss: 6.3347e-04 - val_loss: 0.0202
# Epoch 49/50
# 28/28 - 0s - 15ms/step - loss: 5.4635e-04 - val_loss: 0.0193
# Epoch 50/50
# 28/28 - 0s - 17ms/step - loss: 5.2125e-04 - val_loss: 0.0169
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# <class 'numpy.ndarray'>
# [[0.02172057]
#  [0.02306332]
#  [0.02274303]
#  [0.02258685]
#  [0.02225399]
#  [0.02159018]
#  [0.02164662]
#  [0.02259705]
#  [0.02367583]
#  [0.02396633]
#  [0.02366871]
#  [0.02278467]
#  [0.02180992]
#  [0.02189538]
#  [0.02300382]
#  [0.02515018]
#  [0.02585511]
#  [0.0258647 ]
#  [0.02500461]
#  [0.02431479]
#  [0.02525429]
#  [0.0268236 ]
#  [0.02813692]
#  [0.02842363]
#  [0.0283953 ]
#  [0.02699397]
#  [0.02592043]
#  [0.02628298]
#  [0.02770038]
#  [0.02896134]
#  [0.03004157]
#  [0.03098437]
#  [0.03166603]
#  [0.0324528 ]
#  [0.03500285]
#  [0.03750537]
#  [0.03923871]
#  [0.03945224]
#  [0.039828  ]
#  [0.04029612]
#  [0.04064439]
#  [0.04139396]
#  [0.04250072]
#  [0.0431148 ]
#  [0.0422405 ]
#  [0.04212767]
#  [0.0421381 ]
#  [0.04187759]
#  [0.04301689]
#  [0.04429437]
#  [0.04699332]
#  [0.05017164]
#  [0.05351298]
#  [0.05345945]
#  [0.05266961]
#  [0.05373086]
#  [0.05781114]
#  [0.06006782]
#  [0.05944953]
#  [0.06020177]
#  [0.05932816]
#  [0.05620013]
#  [0.0543856 ]
#  [0.05572865]
#  [0.05666487]
#  [0.05554747]
#  [0.05325758]
#  [0.05080508]
#  [0.05050371]
#  [0.05137613]
#  [0.05954265]
#  [0.06876288]
#  [0.07420908]
#  [0.07659086]
#  [0.07741862]
#  [0.07452082]
#  [0.07112433]
#  [0.06885217]
#  [0.06552806]
#  [0.06233996]
#  [0.05632754]
#  [0.04994293]
#  [0.04515209]
#  [0.04328695]
#  [0.04287977]
#  [0.04351012]
#  [0.0497065 ]
#  [0.05399079]
#  [0.05365896]
#  [0.05127004]
#  [0.05155434]
#  [0.05192868]
#  [0.05196252]
#  [0.050081  ]
#  [0.04800043]
#  [0.04526759]
#  [0.04024909]
#  [0.03780487]
#  [0.03846157]
#  [0.03902011]
#  [0.03839731]
#  [0.03822555]
#  [0.03660189]
#  [0.03500184]
#  [0.03440681]
#  [0.03546141]
#  [0.03717274]
#  [0.03714046]
#  [0.03647027]
#  [0.03553457]
#  [0.03375934]
#  [0.0332083 ]
#  [0.03395937]
#  [0.03496761]
#  [0.03532162]
#  [0.03514532]
#  [0.03276137]
#  [0.03118683]
#  [0.03068062]
#  [0.03177803]
#  [0.03412099]
#  [0.03567479]
#  [0.03631562]
#  [0.03520096]
#  [0.03394958]
#  [0.03408445]
#  [0.03550389]
#  [0.03738428]
#  [0.03797353]
#  [0.03817046]
#  [0.03670915]
#  [0.03483997]
#  [0.03503779]
#  [0.03655045]
#  [0.03778815]
#  [0.03897227]
#  [0.04123466]
#  [0.041889  ]
#  [0.04160325]
#  [0.041854  ]
#  [0.04316554]
#  [0.04476367]
#  [0.04520499]
#  [0.04604461]
#  [0.04511212]
#  [0.04339879]
#  [0.04266918]
#  [0.04516023]
#  [0.04934303]
#  [0.05109988]
#  [0.05375244]
#  [0.05570614]
#  [0.0576572 ]
#  [0.06120358]
#  [0.06722885]
#  [0.07048301]
#  [0.07392451]
#  [0.07261489]
#  [0.06859609]
#  [0.06621014]
#  [0.06697356]
#  [0.0694159 ]
#  [0.0686794 ]
#  [0.06641776]
#  [0.06558544]
#  [0.06374362]
#  [0.06061673]
#  [0.06072979]
#  [0.06225953]
#  [0.06503298]
#  [0.06396039]
#  [0.0622203 ]
#  [0.06033572]
#  [0.05859298]
#  [0.05694288]
#  [0.05776211]
#  [0.06042452]
#  [0.06771456]
#  [0.06988715]
#  [0.06813986]
#  [0.06722327]
#  [0.0682723 ]
#  [0.07040381]
#  [0.07405957]
#  [0.07395946]
#  [0.07147611]
#  [0.06916498]
#  [0.06732596]
#  [0.07203525]
#  [0.07754787]
#  [0.08275302]
#  [0.08458864]
#  [0.08443587]
#  [0.08844962]
#  [0.1068459 ]
#  [0.13596128]
#  [0.15312146]
#  [0.16752347]
#  [0.18258503]
#  [0.19411923]
#  [0.19530703]
#  [0.1969434 ]
#  [0.20684642]
#  [0.20506431]
#  [0.19264366]
#  [0.1813533 ]
#  [0.17546305]
#  [0.16849321]
#  [0.1576285 ]
#  [0.14967255]
#  [0.15496434]
#  [0.15851022]
#  [0.15973134]
#  [0.1622744 ]
#  [0.15937686]
#  [0.15679255]
#  [0.159316  ]
#  [0.15974626]
#  [0.1649462 ]
#  [0.16848348]
#  [0.16649413]
#  [0.16788484]
#  [0.17067693]
#  [0.17599091]
#  [0.18936172]
#  [0.2006582 ]
#  [0.21349913]
#  [0.23110552]
#  [0.23813824]
#  [0.24272583]
#  [0.2535737 ]
#  [0.26393637]
#  [0.27461678]
#  [0.279621  ]
#  [0.2798983 ]
#  [0.27390832]
#  [0.26309964]
#  [0.25496832]
#  [0.2529403 ]
#  [0.25176272]
#  [0.24896388]
#  [0.24900375]
#  [0.2558816 ]
#  [0.25495484]
#  [0.26487336]
#  [0.28654394]
#  [0.2952758 ]
#  [0.29184055]
#  [0.28894427]
#  [0.2790909 ]
#  [0.26716137]
#  [0.25837553]
#  [0.24571519]
#  [0.23823969]
#  [0.22305946]
#  [0.20736147]
#  [0.1947542 ]
#  [0.18743463]
#  [0.18473269]
#  [0.18772705]
#  [0.18992978]
#  [0.18942983]
#  [0.19291806]
#  [0.19796817]
#  [0.19834383]
#  [0.20273615]
#  [0.21122976]
#  [0.21901253]
#  [0.22269677]
#  [0.22039251]
#  [0.21417627]
#  [0.20724185]
#  [0.20544302]
#  [0.20236672]
#  [0.20262505]
#  [0.19919467]
#  [0.19326396]
#  [0.1838041 ]
#  [0.1757227 ]
#  [0.17548385]
#  [0.17980523]
#  [0.1873437 ]
#  [0.19219255]
#  [0.19860193]
#  [0.20065598]
#  [0.19800891]
#  [0.2003174 ]
#  [0.208145  ]
#  [0.21495281]
#  [0.21442205]
#  [0.21065313]
#  [0.20414087]
#  [0.1960101 ]
#  [0.19413595]
#  [0.20024733]
#  [0.21034881]
#  [0.21425223]
#  [0.22643054]
#  [0.22993731]
#  [0.24175492]
#  [0.25296777]
#  [0.26985738]
#  [0.27836558]
#  [0.28417492]
#  [0.28502357]
#  [0.27261606]
#  [0.25896192]
#  [0.24817795]
#  [0.24471179]
#  [0.23710357]
#  [0.23111703]
#  [0.2213736 ]
#  [0.2163437 ]
#  [0.20884542]
#  [0.22128735]
#  [0.24343823]
#  [0.26100165]
#  [0.27230754]
#  [0.27946356]
#  [0.291056  ]
#  [0.30411503]
#  [0.33492094]
#  [0.36333418]
#  [0.38875338]
#  [0.39651966]
#  [0.39637348]
#  [0.38728416]
#  [0.37643552]
#  [0.37400898]
#  [0.3629478 ]
#  [0.3679919 ]
#  [0.3516556 ]
#  [0.3342305 ]
#  [0.30936417]
#  [0.29936978]
#  [0.29272792]
#  [0.28862736]
#  [0.28136444]
#  [0.26290008]
#  [0.24737242]
#  [0.22153413]
#  [0.2018939 ]
#  [0.18911828]
#  [0.18482982]
#  [0.17447715]
#  [0.16557358]
#  [0.1574808 ]
#  [0.146389  ]
#  [0.1390451 ]
#  [0.13570373]
#  [0.13957016]
#  [0.14054795]
#  [0.13835819]
#  [0.13481031]
#  [0.12917465]
#  [0.12310877]
#  [0.12276356]
#  [0.12411233]
#  [0.12394448]
#  [0.1222619 ]
#  [0.11834908]
#  [0.11395403]
#  [0.11120287]
#  [0.11317833]
#  [0.12195806]
#  [0.1239251 ]
#  [0.1208305 ]
#  [0.11864806]
#  [0.11512329]
#  [0.11229529]
#  [0.11488225]
#  [0.11607918]
#  [0.1168318 ]
#  [0.11349888]
#  [0.10737401]
#  [0.10403176]
#  [0.10088109]
#  [0.09896202]
#  [0.1009308 ]
#  [0.10305919]
#  [0.10280205]
#  [0.10421836]
#  [0.10160555]
#  [0.09852258]
#  [0.09732617]
#  [0.09909459]
#  [0.10098661]
#  [0.10181038]
#  [0.10086226]
#  [0.09703813]
#  [0.09180905]
#  [0.08954009]
#  [0.09208293]
#  [0.09497694]
#  [0.09497333]
#  [0.09370337]
#  [0.0914204 ]
#  [0.08885891]
#  [0.09401884]
#  [0.10067037]
#  [0.10587055]
#  [0.10705306]
#  [0.10729387]
#  [0.10644998]
#  [0.10761227]
#  [0.11083099]
#  [0.11391551]
#  [0.11795372]
#  [0.11775994]
#  [0.12088599]
#  [0.12497149]
#  [0.12776168]
#  [0.13249227]
#  [0.13729517]
#  [0.14262238]
#  [0.14522567]
#  [0.14758669]
#  [0.147399  ]
#  [0.14595133]
#  [0.14722686]
#  [0.14749494]
#  [0.14824416]
#  [0.14623962]
#  [0.14639775]
#  [0.14300352]
#  [0.14077622]
#  [0.14471075]
#  [0.1492192 ]
#  [0.15324374]
#  [0.15360738]
#  [0.15449803]
#  [0.1525665 ]
#  [0.15104331]
#  [0.15285262]
#  [0.15902482]
#  [0.16903843]
#  [0.1745189 ]
#  [0.18129916]
#  [0.1804792 ]
#  [0.18058564]
#  [0.18472946]
#  [0.19635373]
#  [0.20322046]
#  [0.20499556]
#  [0.20274906]
#  [0.1931434 ]
#  [0.18416768]]
# rmse = 0.1302479443043598
# mae = 0.07280345457833864
# mape = 0.5600693908555446
# testY
# testY.shape
# (447,)
# <class 'numpy.ndarray'>
# prediction_val
# (447,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# 20/20 - 3s - 168ms/step - loss: 0.0016 - val_loss: 0.0116
# Epoch 2/50
# 20/20 - 0s - 18ms/step - loss: 3.6270e-04 - val_loss: 0.0066
# Epoch 3/50
# 20/20 - 0s - 19ms/step - loss: 4.4752e-04 - val_loss: 0.0081
# Epoch 4/50
# 20/20 - 0s - 16ms/step - loss: 4.3122e-04 - val_loss: 0.0078
# Epoch 5/50
# 20/20 - 0s - 22ms/step - loss: 3.6240e-04 - val_loss: 0.0067
# Epoch 6/50
# 20/20 - 0s - 22ms/step - loss: 3.2928e-04 - val_loss: 0.0067
# Epoch 7/50
# 20/20 - 0s - 18ms/step - loss: 3.2776e-04 - val_loss: 0.0076
# Epoch 8/50
# 20/20 - 0s - 21ms/step - loss: 3.7076e-04 - val_loss: 0.0077
# Epoch 9/50
# 20/20 - 0s - 16ms/step - loss: 3.5727e-04 - val_loss: 0.0069
# Epoch 10/50
# 20/20 - 0s - 16ms/step - loss: 3.2357e-04 - val_loss: 0.0068
# Epoch 11/50
# 20/20 - 0s - 15ms/step - loss: 3.0912e-04 - val_loss: 0.0070
# Epoch 12/50
# 20/20 - 0s - 16ms/step - loss: 3.1253e-04 - val_loss: 0.0075
# Epoch 13/50
# 20/20 - 0s - 17ms/step - loss: 3.5538e-04 - val_loss: 0.0074
# Epoch 14/50
# 20/20 - 0s - 16ms/step - loss: 3.5738e-04 - val_loss: 0.0069
# Epoch 15/50
# 20/20 - 0s - 19ms/step - loss: 3.2366e-04 - val_loss: 0.0068
# Epoch 16/50
# 20/20 - 0s - 15ms/step - loss: 3.1233e-04 - val_loss: 0.0067
# Epoch 17/50
# 20/20 - 0s - 14ms/step - loss: 2.9796e-04 - val_loss: 0.0072
# Epoch 18/50
# 20/20 - 0s - 16ms/step - loss: 3.4273e-04 - val_loss: 0.0074
# Epoch 19/50
# 20/20 - 0s - 19ms/step - loss: 3.9973e-04 - val_loss: 0.0069
# Epoch 20/50
# 20/20 - 0s - 23ms/step - loss: 3.5320e-04 - val_loss: 0.0069
# Epoch 21/50
# 20/20 - 0s - 21ms/step - loss: 3.3896e-04 - val_loss: 0.0067
# Epoch 22/50
# 20/20 - 0s - 24ms/step - loss: 3.1973e-04 - val_loss: 0.0069
# Epoch 23/50
# 20/20 - 0s - 15ms/step - loss: 3.3165e-04 - val_loss: 0.0079
# Epoch 24/50
# 20/20 - 0s - 18ms/step - loss: 4.3015e-04 - val_loss: 0.0072
# Epoch 25/50
# 20/20 - 0s - 15ms/step - loss: 3.7088e-04 - val_loss: 0.0069
# Epoch 26/50
# 20/20 - 0s - 17ms/step - loss: 3.4749e-04 - val_loss: 0.0068
# Epoch 27/50
# 20/20 - 0s - 16ms/step - loss: 3.1541e-04 - val_loss: 0.0068
# Epoch 28/50
# 20/20 - 0s - 17ms/step - loss: 3.3379e-04 - val_loss: 0.0080
# Epoch 29/50
# 20/20 - 0s - 16ms/step - loss: 3.7591e-04 - val_loss: 0.0069
# Epoch 30/50
# 20/20 - 0s - 18ms/step - loss: 3.1552e-04 - val_loss: 0.0068
# Epoch 31/50
# 20/20 - 0s - 16ms/step - loss: 3.0272e-04 - val_loss: 0.0065
# Epoch 32/50
# 20/20 - 0s - 19ms/step - loss: 2.8247e-04 - val_loss: 0.0070
# Epoch 33/50
# 20/20 - 0s - 16ms/step - loss: 3.1723e-04 - val_loss: 0.0070
# Epoch 34/50
# 20/20 - 0s - 18ms/step - loss: 3.0006e-04 - val_loss: 0.0065
# Epoch 35/50
# 20/20 - 0s - 19ms/step - loss: 2.7975e-04 - val_loss: 0.0065
# Epoch 36/50
# 20/20 - 0s - 15ms/step - loss: 2.6842e-04 - val_loss: 0.0065
# Epoch 37/50
# 20/20 - 0s - 17ms/step - loss: 2.7902e-04 - val_loss: 0.0067
# Epoch 38/50
# 20/20 - 0s - 21ms/step - loss: 2.8924e-04 - val_loss: 0.0065
# Epoch 39/50
# 20/20 - 0s - 16ms/step - loss: 2.7286e-04 - val_loss: 0.0065
# Epoch 40/50
# 20/20 - 0s - 16ms/step - loss: 2.6349e-04 - val_loss: 0.0064
# Epoch 41/50
# 20/20 - 0s - 16ms/step - loss: 2.5917e-04 - val_loss: 0.0064
# Epoch 42/50
# 20/20 - 0s - 16ms/step - loss: 2.7306e-04 - val_loss: 0.0065
# Epoch 43/50
# 20/20 - 0s - 15ms/step - loss: 2.7756e-04 - val_loss: 0.0065
# Epoch 44/50
# 20/20 - 0s - 15ms/step - loss: 2.6490e-04 - val_loss: 0.0065
# Epoch 45/50
# 20/20 - 0s - 16ms/step - loss: 2.5637e-04 - val_loss: 0.0064
# Epoch 46/50
# 20/20 - 0s - 16ms/step - loss: 2.5094e-04 - val_loss: 0.0064
# Epoch 47/50
# 20/20 - 0s - 16ms/step - loss: 2.6761e-04 - val_loss: 0.0064
# Epoch 48/50
# 20/20 - 0s - 15ms/step - loss: 2.8463e-04 - val_loss: 0.0065
# Epoch 49/50
# 20/20 - 0s - 16ms/step - loss: 2.7190e-04 - val_loss: 0.0067
# Epoch 50/50
# 20/20 - 0s - 16ms/step - loss: 2.6225e-04 - val_loss: 0.0065
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# <class 'numpy.ndarray'>
# [[0.09478267]
#  [0.09279514]
#  [0.09644752]
#  [0.09517109]
#  [0.09788153]
#  [0.10188799]
#  [0.09981656]
#  [0.09853996]
#  [0.10075478]
#  [0.1007616 ]
#  [0.10577866]
#  [0.10799621]
#  [0.10367659]
#  [0.10010464]
#  [0.09490087]
#  [0.08886243]
#  [0.08412335]
#  [0.07896445]
#  [0.0755875 ]
#  [0.07135983]
#  [0.07016357]
#  [0.06704184]
#  [0.0669928 ]
#  [0.06885067]
#  [0.0730598 ]
#  [0.07827459]
#  [0.08252225]
#  [0.0882983 ]
#  [0.09526224]
#  [0.10126798]
#  [0.10754786]
#  [0.11588026]
#  [0.12174963]
#  [0.12444285]
#  [0.12525962]
#  [0.12686113]
#  [0.12567131]
#  [0.12660557]
#  [0.12704934]
#  [0.12785192]
#  [0.12669982]
#  [0.1228629 ]
#  [0.11710481]
#  [0.11300484]
#  [0.11037788]
#  [0.10908965]
#  [0.1137915 ]
#  [0.12110335]
#  [0.12684406]
#  [0.13032843]
#  [0.1303853 ]
#  [0.13348487]
#  [0.13896587]
#  [0.14311542]
#  [0.14597851]
#  [0.14709722]
#  [0.1473868 ]
#  [0.14179467]
#  [0.13937394]
#  [0.14123307]
#  [0.1456862 ]
#  [0.14423242]
#  [0.14699589]
#  [0.15272382]
#  [0.15918168]
#  [0.16728093]
#  [0.18471678]
#  [0.19667386]
#  [0.20209275]
#  [0.20029263]
#  [0.1902902 ]
#  [0.17883389]
#  [0.16511787]
#  [0.15466526]
#  [0.14609344]
#  [0.14338456]
#  [0.1344871 ]
#  [0.12746625]
#  [0.11932031]
#  [0.12010258]
#  [0.12378124]
#  [0.1304097 ]
#  [0.13783483]
#  [0.14455333]
#  [0.15680076]
#  [0.1727589 ]
#  [0.19842704]
#  [0.24482892]
#  [0.27289394]
#  [0.28097233]
#  [0.2754474 ]
#  [0.26140365]
#  [0.24599914]
#  [0.240038  ]
#  [0.23581292]
#  [0.23458089]
#  [0.23206384]
#  [0.21394403]
#  [0.20500673]
#  [0.19451009]
#  [0.1852923 ]
#  [0.17932399]
#  [0.17543775]
#  [0.16394062]
#  [0.15525006]
#  [0.1467501 ]
#  [0.1356241 ]
#  [0.12677394]
#  [0.1209682 ]
#  [0.11802515]
#  [0.12609838]
#  [0.12796906]
#  [0.13090833]
#  [0.13178898]
#  [0.12954672]
#  [0.12698558]
#  [0.12469339]
#  [0.11976948]
#  [0.11720922]
#  [0.10806834]
#  [0.09694008]
#  [0.08938762]
#  [0.0878888 ]
#  [0.08940969]
#  [0.08917131]
#  [0.08639552]
#  [0.08581614]
#  [0.08447439]
#  [0.09089915]
#  [0.0997652 ]
#  [0.10362949]
#  [0.10240566]
#  [0.10151968]
#  [0.10024404]
#  [0.09769442]
#  [0.09212383]
#  [0.08024665]
#  [0.07242846]
#  [0.06205747]
#  [0.05619331]
#  [0.05495837]
#  [0.05786359]
#  [0.05887524]
#  [0.06009113]
#  [0.06525496]
#  [0.06925344]
#  [0.07402939]
#  [0.07223398]
#  [0.0715501 ]
#  [0.07009539]
#  [0.07149603]
#  [0.07227394]
#  [0.07411394]
#  [0.0726982 ]
#  [0.0716038 ]
#  [0.07045452]
#  [0.06338858]
#  [0.06244358]
#  [0.06214593]
#  [0.06146507]
#  [0.06096685]
#  [0.0606755 ]
#  [0.06089877]
#  [0.06492927]
#  [0.07008418]
#  [0.0757319 ]
#  [0.08084679]
#  [0.08461357]
#  [0.08714706]
#  [0.09055155]
#  [0.09479915]
#  [0.09903126]
#  [0.10073886]
#  [0.10008764]
#  [0.10071217]
#  [0.10241373]
#  [0.10383009]
#  [0.10587291]
#  [0.10903163]
#  [0.11005591]
#  [0.11231957]
#  [0.1141251 ]
#  [0.11476384]
#  [0.11631849]
#  [0.1163109 ]
#  [0.11917486]
#  [0.12304113]
#  [0.12598465]
#  [0.12809627]
#  [0.12847687]
#  [0.12758376]
#  [0.12844113]
#  [0.13623329]
#  [0.14655094]
#  [0.15029195]
#  [0.15471214]
#  [0.15310365]
#  [0.15541875]
#  [0.15970561]
#  [0.16821522]
#  [0.17767382]
#  [0.18459986]
#  [0.18972716]
#  [0.19180132]
#  [0.19310616]
#  [0.1962951 ]
#  [0.20403038]
#  [0.21423689]
#  [0.22141664]
#  [0.2215038 ]
#  [0.21684664]
#  [0.21241786]
#  [0.20978875]
#  [0.20360619]
#  [0.19931583]
#  [0.1978609 ]
#  [0.19537194]
#  [0.1899745 ]
#  [0.19299543]
#  [0.19063339]
#  [0.18945356]
#  [0.18612869]
#  [0.18615878]
#  [0.1886416 ]
#  [0.18565732]
#  [0.17973077]
#  [0.17526306]
#  [0.15895449]
#  [0.15981539]
#  [0.15764172]
#  [0.16191283]
#  [0.16025831]
#  [0.159833  ]
#  [0.16004173]
#  [0.1711651 ]
#  [0.19543388]
#  [0.22057681]
#  [0.23361404]
#  [0.23560506]
#  [0.23294604]
#  [0.22743489]
#  [0.22419283]
#  [0.2249737 ]
#  [0.22955948]
#  [0.22544537]
#  [0.21793555]
#  [0.2089539 ]
#  [0.2049951 ]
#  [0.20542553]
#  [0.21054946]
#  [0.21731193]
#  [0.22744264]
#  [0.22851124]
#  [0.22381696]
#  [0.22622205]
#  [0.23553464]
#  [0.2564716 ]
#  [0.2928641 ]
#  [0.319006  ]
#  [0.33609006]
#  [0.3392295 ]
#  [0.34082767]
#  [0.35887447]
#  [0.3752258 ]
#  [0.38383272]
#  [0.39099   ]
#  [0.38474482]
#  [0.35874808]
#  [0.35405293]
#  [0.3551858 ]
#  [0.35561278]
#  [0.35597622]
#  [0.34348634]
#  [0.3359572 ]
#  [0.32664013]
#  [0.32092634]
#  [0.33274752]
#  [0.33854088]
#  [0.3392962 ]
#  [0.3343428 ]
#  [0.32341328]
#  [0.3118361 ]
#  [0.3136209 ]
#  [0.31961754]
#  [0.32480997]
#  [0.3360578 ]
#  [0.31942418]
#  [0.31851295]
#  [0.32189962]
#  [0.32903478]
#  [0.3381895 ]
#  [0.34753692]
#  [0.35002476]
#  [0.34255567]
#  [0.33950207]
#  [0.33375618]
#  [0.34871185]
#  [0.35310248]
#  [0.3479975 ]
#  [0.33847028]
#  [0.3293025 ]
#  [0.31246537]
#  [0.29335284]
#  [0.2853234 ]
#  [0.2728365 ]
#  [0.26346996]
#  [0.22298081]
#  [0.20849243]
#  [0.19282669]
#  [0.18051845]
#  [0.16691075]
#  [0.15513773]]
# rmse = 0.07842705054282861
# mae = 0.04821050033605924
# mape = 0.31822607907421596
# testY
# testY.shape
# (312,)
# <class 'numpy.ndarray'>
# prediction_val
# (312,)
# <class 'numpy.ndarray'>
# binance
# rmse = 0.10797889168143865
# mae = 0.07540931149072695
# mape = 0.4972545290846245
#
# coinbase
# rmse = 0.12872133508267694
# mae = 0.08684398155082784
# mape = 0.4947785945598113
#
# huobi
# rmse = 0.07644167555632818
# mae = 0.030401298872468768
# mape = 0.4018134739178977
#
# kraken
# rmse = 0.1302479443043598
# mae = 0.07280345457833864
# mape = 0.5600693908555446
#
# kucoin
# rmse = 0.07842705054282861
# mae = 0.04821050033605924
# mape = 0.31822607907421596
