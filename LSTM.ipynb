# %%
import keras
from keras import backend as K
from keras import optimizers
import tensorflow
from keras.models import Sequential, Model
from keras.layers import Lambda, Activation, Input, Dense, Dropout, SimpleRNN, Flatten, \
    LSTM, GRU, Bidirectional, Layer, Permute, Reshape, Multiply, RepeatVector, Dot, Concatenate

import pandas as pd
import numpy as np
import math
from math import sqrt
import os
import csv
from keras.models import Sequential, Model
from keras.layers import Lambda, Activation, Input, Dense, Dropout, SimpleRNN, Flatten, \
    LSTM, GRU, Bidirectional, Layer, Permute, Reshape, Multiply, RepeatVector, Dot, Concatenate

from keras import optimizers
import keras.backend as K
from sklearn.preprocessing import MinMaxScaler
from matplotlib import pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.vector_ar.var_model import VAR
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
import tensorflow as tf
import numpy.linalg as la
import time
import matplotlib.dates as mdates
font1 = {'family': 'Microsoft YaHei',
         'weight': 'normal',
         'size': 13}
plt.style.use('default')
tensorflow.random.set_seed(2)
exchanges = ["binance", "coinbase", "huobi", "kraken", "kucoin"]
beginDates = ['2021-01-30', '2021-11-05', '2020-11-03', '2020-06-25', '2021-02-15']
endDates = ['2021-12-23', '2021-12-24', '2021-09-15', '2021-09-15', '2021-12-24']

li = [] #Save the location of outliers detected using LSTM
li.append([95, 110, 111, 115, 116, 238])
li.append([30])
li.append([153, 190, 241])
li.append([313, 327, 329])
li.append([216, 256, 275, 295])

class attention(Layer):
    def __init__(self,**kwargs):
        super(attention,self).__init__(**kwargs)

    def build(self,input_shape):
        self.W=self.add_weight(name="att_weight",shape=(input_shape[-1],1),initializer="normal")
        self.b=self.add_weight(name="att_bias",shape=(input_shape[1],1),initializer="zeros")
        super(attention, self).build(input_shape)

    def call(self, x):
        et = tensorflow.squeeze(keras.activations.sigmoid(tf.matmul(x, self.W) + self.b), axis=-1)

        at = at = tf.keras.activations.softmax(et)

        at = tf.expand_dims(at, axis=-1)
        output = x * at
        return tf.reduce_sum(output, axis=1)


    def compute_output_shape(self,input_shape):
        return (input_shape[0],input_shape[-1])

    def get_config(self):
        return super(attention,self).get_config()


def model_lstm_att(time_steps, input_dim, n_units, method="LSTM"):
    K.clear_session()  
    model_input = Input(shape=(time_steps, input_dim))
    if method == "LSTM":
        x = LSTM(n_units, return_sequences=True)(model_input)
    elif method == "GRU":
        x = GRU(n_units, return_sequences=True)(model_input)
    elif method == "RNN":
        x = SimpleRNN(n_units, return_sequences=True)(model_input)
    x = attention()(x)
    x = Dense(1)(x)
    model = Model(model_input, x)
    return model
def model_lstm(seq_len, n_features, n_units):
    model = Sequential()
    model.add(LSTM(n_units, activation="relu", input_shape=(seq_len, n_features)))
    model.add(Dense(1))
    return model

def evaluation(real, pre):
    rmse = mean_squared_error(real, pre, squared=False)
    mae = mean_absolute_error(real, pre)
    mape = mean_absolute_percentage_error(real, pre)
    r2 = r2_score(real, pre)
    var = 1-(np.var(real - pre))/np.var(real)
    F_norm = la.norm(real-pre)/la.norm(real)

    return rmse, mae, mape, r2, var, 1-F_norm

def min_max_scaler(li):
    min_ = min(li)
    max_ = max(li)
    ret = [(i - min_) / (max_ - min_) for i in li]
    return ret, min_, max_

def data_split(data, train_rate, seq_len, pre_len=1):
    time_len, n_feature = data.shape
    train_size = int(time_len * train_rate)
    train_data = data[0:train_size]
    trainX, trainY, testX, testY = [], [], [], []
    for i in range(train_size-seq_len-pre_len):
        a = train_data[i: i + seq_len + pre_len]
        trainX.append(a[0: seq_len])
        trainY.append(a[seq_len: seq_len + pre_len, 0])
    for i in range(train_size-seq_len-pre_len, time_len-pre_len-seq_len):
        b = data[i: i+seq_len+pre_len,:]
        testX.append(b[0:seq_len])
        testY.append(b[seq_len:seq_len+pre_len, 0])
    trainX1 = np.array(trainX)
    trainY1 = np.array(trainY)
    testX1 = np.array(testX)
    testY1 = np.array(testY)
    return trainX1, trainY1, testX1, testY1

def lstm(n_units=64, seq_len=10, batch_size=64, method="LSTM"):
    error_list = []
    rmse_list = []
    mae_list = []
    mape_list = []
    for i in range(len(exchanges)):
        exchange = exchanges[i]
        important = True
        if important:
            file = open("E:\\MiniProject\\exchange_anomaly_detection-main\\exchange\\feature\\" + exchange + '_ft.csv')
        else:
            file = open("E:\\MiniProject\\exchange_anomaly_detection-main\\exchange\\feature\\" + exchange + '_ft_not_important.csv')
        df = pd.read_csv(file)
        data = df.values
        print("type data")
        print(type(data))
        time_len, n_features = data.shape
        train_rate = 0.8
        train_size = int(time_len*train_rate)
        trainX, trainY, testX, testY = data_split(data, train_rate=train_rate, seq_len=seq_len)
        scaled_data = data.copy()
        #Normalize the features of each column
        scaler = []
        for j in range(n_features):
            temp_scaler = MinMaxScaler(feature_range=(0, 1))
            temp = temp_scaler.fit_transform(np.array(scaled_data[:, j]).reshape(-1,1))
            scaler.append(temp_scaler)
            temp = temp.reshape(-1)
            scaled_data[:, j] = temp
        trainX1, trainY1, testX1, testY1 = data_split(scaled_data, train_rate=train_rate, seq_len=seq_len)
        model_name=method
        #model_name = method+"_attention"
        #model_name="LSTM"
        # print("model_name--------------")
        # print(model_name

        if model_name=="LSTM_attention" or model_name=="GRU_attention" or model_name=="RNN_attention":
            model = model_lstm_att(seq_len, n_features, n_units, method=method)
        if model_name=="LSTM":
            model = model_lstm(seq_len, n_features, n_units)

        opt = optimizers.Adam()
        model.compile(optimizer=opt, loss='mse')
        history = model.fit(trainX1, trainY1, epochs=50, batch_size=batch_size, validation_data=(testX1, testY1), verbose=2, shuffle=False)
        if True:
            plt.figure(figsize=(10, 5))
            plt.grid(linestyle="--")
            plt.plot(history.history['loss'], label='train')
            plt.plot(history.history['val_loss'], label='test')
            plt.legend()
            plt.title(exchange)
            plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure/lstm_prediction" + exchange + '_' + model_name + '_loss.png')
            plt.show()
        prediction_val = model.predict(testX1)
        print(type(prediction_val))
        print(prediction_val)

        rmse, mae, mape, r2, var, _ = evaluation(testY1, prediction_val)
        print("rmse = {}\nmae = {}\nmape = {}".format(rmse, mae, mape))
        error_list.append("rmse = {}\nmae = {}\nmape = {}\n".format(rmse, mae, mape))

        rmse_list.append(rmse)
        mae_list.append(mae)
        mape_list.append(mape)

        prediction_val = np.array(scaled_data[0:train_size, 0].tolist()+prediction_val[:, 0].tolist())
        prediction_val = prediction_val.reshape(-1,1)
        prediction_val = scaler[0].inverse_transform(prediction_val)
        prediction_val = prediction_val[train_size:,0]
        print("testY")
        testY = testY[:,0]
        print("testY.shape")
        print(testY.shape)
        print(type(testY))
        print("prediction_val")
        print(prediction_val.shape)
        print(type(prediction_val))

        if True:
            # plt.figure(figsize=(10, 4))
            # plt.grid(linestyle="--")
            # plt.plot(range(time_len-train_size), testY)
            # plt.plot(range(time_len-train_size), np.array(prediction_val))
            upper_bound = [it + 3 * np.std(testY) for it in prediction_val]
            lower_bound = [it - 3 * np.std(testY) for it in prediction_val]

            fig, ax = plt.subplots(figsize=(10, 4),dpi=300)
            beginDate = beginDates[i]
            endDate = endDates[i]

            x = np.arange(mdates.datestr2num(beginDate), mdates.datestr2num(endDate))
            x_range = [np.datetime64(int(c), 'D') for c in x]
            # plt.figure(figsize=(10, 4))
            # plt.grid(linestyle="--")

            abnormal_x = []
            abnormal_y = []
            for j in range(len(upper_bound)):
                if testY[j] > upper_bound[j]:
                    abnormal_x.append(x_range[j])
                    abnormal_y.append(testY[j])

            miss_x = []
            miss_y = []
            for j in range(len(li[i])):
                if x_range[li[i][j]] not in abnormal_x:
                    miss_x.append(x_range[li[i][j]])
                    miss_y.append(testY[li[i][j]])

            fmt_half_year = mdates.MonthLocator(interval=1)
            ax.xaxis.set_major_locator(fmt_half_year)

            fmt_month = mdates.MonthLocator() 
            ax.xaxis.set_minor_locator(fmt_month)

            ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))

            datemin = np.datetime64(x_range[0], 'M')
            # datemax = np.datetime64(x_range[-1], 'Y') + np.timedelta64(1, 'Y')
            datemax = np.datetime64(x_range[-1], 'M') + np.timedelta64(1, 'M')
            ax.set_xlim(datemin, datemax)

            ax.format_xdata = mdates.DateFormatter('%Y-%m')
            ax.format_ydata = lambda x: f'$x:.2f$'
            ax.grid(True)
            fig.autofmt_xdate()

            ax.plot(x_range, testY)
            ax.plot(x_range, np.array(prediction_val))
            ax.plot(x_range, upper_bound, "--")
            ax.plot(x_range, lower_bound, "--")
            ax.scatter(abnormal_x, abnormal_y, c="r", marker="o")
            ax.scatter(miss_x, miss_y, c="dimgrey", marker="o")
            if method=="LSTM":
                plt.legend(("Real", model_name, "Upper bound", "Lower bound", "Anomaly detected"), loc=2)
            else:
                plt.legend(("Real", model_name, "Upper bound", "Lower bound", "Anomaly detected", "Anomaly missed"), loc=2)

            plt.title(exchange.title())
            plt.xlabel("time", font1)
            # plt.ylabel("Transaction Amount(USD)")
            plt.ylabel("Trading volume (USD）", font1)
            plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure"+str.lower(method)+'_prediction_' + exchange + '_' + model_name + '_prediction.png')
            plt.show()
    for i in range(len(exchanges)):
        print(exchanges[i])
        print(error_list[i])
    return rmse_list, mae_list, mape_list

def parameter_sensitivity(parameter, para_range):
    rmse_list = [[] for i in range(len(exchanges))]
    mae_list = [[] for i in range(len(exchanges))]
    mape_list = [[] for i in range(len(exchanges))]
    for it in para_range:
        if parameter=="Number of hidden units":
            temp_rmse, temp_mae, temp_mape = lstm(n_units=it)
        if parameter=="Sequence length":
            temp_rmse, temp_mae, temp_mape = lstm(seq_len=it)
        if parameter == "Batch size":
            temp_rmse, temp_mae, temp_mape = lstm(batch_size=it)
        for jj in range(len(temp_rmse)):
            rmse_list[jj].append(temp_rmse[jj])
            mae_list[jj].append(temp_mae[jj])
            mape_list[jj].append(temp_mape[jj])
    for i in range(len(exchanges)):
        exchange = exchanges[i]
        rmse_list[i],_,_ = min_max_scaler(rmse_list[i])
        mae_list[i],_,_ = min_max_scaler(mae_list[i])
        mape_list[i],_,_ = min_max_scaler(mape_list[i])
        plt.figure(figsize=(5, 4))

        plt.grid(linestyle="--")
        plt.plot(para_range, rmse_list[i])
        plt.plot(para_range, mae_list[i])
        plt.plot(para_range, mape_list[i])
        if i==0:
            plt.legend(("RMSE", "MAE", "MAPE"), loc='lower right')
        else:
            plt.legend(("RMSE", "MAE", "MAPE"))
        plt.xlabel(parameter)
        plt.ylabel("normalized value",font1)
        plt.title(exchange.title())
        plt.savefig(r"E:\MiniProject\exchange_anomaly_detection-main\exchange\figure\para_" + parameter + '_' + exchange + '.png')
        plt.show()

def cal_date():
    li = []
    li.append([1400, 1415, 1416, 1420, 1421, 1543])
    li.append([222])
    li.append([1413, 1450, 1501])
    li.append([2097, 2111, 2113])
    li.append([1463, 1503, 1522, 1542])
    start_time = [1499212800, 1619481600, 1495497600, 1438905600, 1505606400]
    for i in range(len(li)):
        print(exchanges[i])
        for j in range(len(li[i])):
            temp_time = start_time[i] + li[i][j]*86400
            timeArray = time.localtime(temp_time)
            otherStyleTime = time.strftime("%Y-%m-%d %H:%M:%S", timeArray)
            print(otherStyleTime)
if __name__=='__main__':
    lstm(method="LSTM") #method = LSTM, RNN, GRU
# Out:
# type data
# <class 'numpy.ndarray'>
# C:\Users\kskis\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 21/21 - 5s - 217ms/step - loss: 5.7105e-04 - val_loss: 0.0214
# Epoch 2/50
# 21/21 - 0s - 16ms/step - loss: 5.1084e-04 - val_loss: 0.0161
# Epoch 3/50
# 21/21 - 0s - 16ms/step - loss: 8.8174e-04 - val_loss: 0.0136
# Epoch 4/50
# 21/21 - 0s - 16ms/step - loss: 4.9053e-04 - val_loss: 0.0147
# Epoch 5/50
# 21/21 - 0s - 16ms/step - loss: 7.1474e-04 - val_loss: 0.0152
# Epoch 6/50
# 21/21 - 0s - 14ms/step - loss: 5.8507e-04 - val_loss: 0.0119
# Epoch 7/50
# 21/21 - 0s - 14ms/step - loss: 5.3989e-04 - val_loss: 0.0159
# Epoch 8/50
# 21/21 - 0s - 16ms/step - loss: 4.7731e-04 - val_loss: 0.0134
# Epoch 9/50
# 21/21 - 0s - 16ms/step - loss: 3.0556e-04 - val_loss: 0.0120
# Epoch 10/50
# 21/21 - 0s - 16ms/step - loss: 2.1757e-04 - val_loss: 0.0119
# Epoch 11/50
# 21/21 - 0s - 16ms/step - loss: 2.0445e-04 - val_loss: 0.0113
# Epoch 12/50
# 21/21 - 0s - 17ms/step - loss: 1.9576e-04 - val_loss: 0.0109
# Epoch 13/50
# 21/21 - 0s - 16ms/step - loss: 1.8721e-04 - val_loss: 0.0107
# Epoch 14/50
# 21/21 - 0s - 18ms/step - loss: 1.8453e-04 - val_loss: 0.0106
# Epoch 15/50
# 21/21 - 0s - 17ms/step - loss: 1.8241e-04 - val_loss: 0.0105
# Epoch 16/50
# 21/21 - 0s - 16ms/step - loss: 1.7893e-04 - val_loss: 0.0104
# Epoch 17/50
# 21/21 - 0s - 16ms/step - loss: 1.7830e-04 - val_loss: 0.0104
# Epoch 18/50
# 21/21 - 0s - 17ms/step - loss: 1.7835e-04 - val_loss: 0.0104
# Epoch 19/50
# 21/21 - 0s - 16ms/step - loss: 1.7558e-04 - val_loss: 0.0103
# Epoch 20/50
# 21/21 - 0s - 18ms/step - loss: 1.7485e-04 - val_loss: 0.0104
# Epoch 21/50
# 21/21 - 0s - 16ms/step - loss: 1.7578e-04 - val_loss: 0.0104
# Epoch 22/50
# 21/21 - 0s - 16ms/step - loss: 1.7340e-04 - val_loss: 0.0103
# Epoch 23/50
# 21/21 - 0s - 15ms/step - loss: 1.7267e-04 - val_loss: 0.0103
# Epoch 24/50
# 21/21 - 0s - 15ms/step - loss: 1.7209e-04 - val_loss: 0.0103
# Epoch 25/50
# 21/21 - 0s - 16ms/step - loss: 1.7214e-04 - val_loss: 0.0104
# Epoch 26/50
# 21/21 - 0s - 16ms/step - loss: 1.7060e-04 - val_loss: 0.0104
# Epoch 27/50
# 21/21 - 0s - 15ms/step - loss: 1.6999e-04 - val_loss: 0.0104
# Epoch 28/50
# 21/21 - 0s - 16ms/step - loss: 1.6913e-04 - val_loss: 0.0104
# Epoch 29/50
# 21/21 - 0s - 17ms/step - loss: 1.6909e-04 - val_loss: 0.0104
# Epoch 30/50
# 21/21 - 0s - 16ms/step - loss: 1.6828e-04 - val_loss: 0.0105
# Epoch 31/50
# 21/21 - 0s - 16ms/step - loss: 1.6767e-04 - val_loss: 0.0105
# Epoch 32/50
# 21/21 - 0s - 16ms/step - loss: 1.6697e-04 - val_loss: 0.0104
# Epoch 33/50
# 21/21 - 0s - 15ms/step - loss: 1.6623e-04 - val_loss: 0.0105
# Epoch 34/50
# 21/21 - 0s - 16ms/step - loss: 1.6671e-04 - val_loss: 0.0106
# Epoch 35/50
# 21/21 - 0s - 17ms/step - loss: 1.6567e-04 - val_loss: 0.0106
# Epoch 36/50
# 21/21 - 0s - 16ms/step - loss: 1.6565e-04 - val_loss: 0.0105
# Epoch 37/50
# 21/21 - 0s - 16ms/step - loss: 1.6619e-04 - val_loss: 0.0105
# Epoch 38/50
# 21/21 - 0s - 17ms/step - loss: 1.6404e-04 - val_loss: 0.0106
# Epoch 39/50
# 21/21 - 0s - 16ms/step - loss: 1.6672e-04 - val_loss: 0.0107
# Epoch 40/50
# 21/21 - 0s - 16ms/step - loss: 1.6909e-04 - val_loss: 0.0114
# Epoch 41/50
# 21/21 - 0s - 16ms/step - loss: 1.7769e-04 - val_loss: 0.0105
# Epoch 42/50
# 21/21 - 1s - 31ms/step - loss: 1.7935e-04 - val_loss: 0.0104
# Epoch 43/50
# 21/21 - 0s - 15ms/step - loss: 1.8802e-04 - val_loss: 0.0107
# Epoch 44/50
# 21/21 - 0s - 15ms/step - loss: 1.7815e-04 - val_loss: 0.0107
# Epoch 45/50
# 21/21 - 0s - 14ms/step - loss: 2.2143e-04 - val_loss: 0.0112
# Epoch 46/50
# 21/21 - 0s - 14ms/step - loss: 2.0790e-04 - val_loss: 0.0106
# Epoch 47/50
# 21/21 - 0s - 16ms/step - loss: 1.7296e-04 - val_loss: 0.0106
# Epoch 48/50
# 21/21 - 0s - 13ms/step - loss: 1.9802e-04 - val_loss: 0.0106
# Epoch 49/50
# 21/21 - 0s - 14ms/step - loss: 2.4797e-04 - val_loss: 0.0106
# Epoch 50/50
# 21/21 - 0s - 15ms/step - loss: 1.7136e-04 - val_loss: 0.0109
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# <class 'numpy.ndarray'>
# [[0.13115501]
#  [0.14617877]
#  [0.13438734]
#  [0.14884982]
#  [0.16594282]
#  [0.17316145]
#  [0.19509268]
#  [0.21163909]
#  [0.21679565]
#  [0.21274298]
#  [0.19930652]
#  [0.21601507]
#  [0.23487875]
#  [0.23925063]
#  [0.2208522 ]
#  [0.23341817]
#  [0.2321638 ]
#  [0.21096468]
#  [0.2188403 ]
#  [0.20878664]
#  [0.21153915]
#  [0.22612673]
#  [0.2194927 ]
#  [0.22485575]
#  [0.22679439]
#  [0.24611287]
#  [0.24022159]
#  [0.21632406]
#  [0.19243293]
#  [0.17025569]
#  [0.1569578 ]
#  [0.14724568]
#  [0.14822513]
#  [0.1415642 ]
#  [0.15172033]
#  [0.14957389]
#  [0.14375924]
#  [0.12984645]
#  [0.13619158]
#  [0.1391883 ]
#  [0.1528478 ]
#  [0.15558748]
#  [0.16761503]
#  [0.17537689]
#  [0.18057108]
#  [0.18302985]
#  [0.20417407]
#  [0.20737043]
#  [0.19725052]
#  [0.20311075]
#  [0.20949395]
#  [0.19871521]
#  [0.20405325]
#  [0.22259414]
#  [0.20748062]
#  [0.2185624 ]
#  [0.20879796]
#  [0.19342025]
#  [0.17913437]
#  [0.17496786]
#  [0.18399674]
#  [0.18972135]
#  [0.20451683]
#  [0.21091934]
#  [0.215664  ]
#  [0.19485551]
#  [0.18233344]
#  [0.20329909]
#  [0.22170562]
#  [0.22769147]
#  [0.22813088]
#  [0.226012  ]
#  [0.21288942]
#  [0.21616673]
#  [0.2353962 ]
#  [0.26030472]
#  [0.26136315]
#  [0.24108198]
#  [0.26515174]
#  [0.2630311 ]
#  [0.25890437]
#  [0.28775206]
#  [0.31543174]
#  [0.30832267]
#  [0.30266044]
#  [0.27188373]
#  [0.22554767]
#  [0.19971076]
#  [0.2065221 ]
#  [0.21149716]
#  [0.23019648]
#  [0.22934696]
#  [0.23037589]
#  [0.23807687]
#  [0.22210483]
#  [0.253275  ]
#  [0.2699406 ]
#  [0.27561355]
#  [0.29998508]
#  [0.3169416 ]
#  [0.34314507]
#  [0.35878354]
#  [0.39736187]
#  [0.43252847]
#  [0.41174278]
#  [0.3695092 ]
#  [0.34944066]
#  [0.31145015]
#  [0.29060426]
#  [0.28000227]
#  [0.27434143]
#  [0.27113286]
#  [0.2597265 ]
#  [0.22802983]
#  [0.1974661 ]
#  [0.20409629]
#  [0.21860915]
#  [0.2043876 ]
#  [0.19501758]
#  [0.20170766]
#  [0.17487049]
#  [0.15914874]
#  [0.15394582]
#  [0.157181  ]
#  [0.15254724]
#  [0.17139226]
#  [0.18430334]
#  [0.17916422]
#  [0.15582164]
#  [0.14463608]
#  [0.15604939]
#  [0.15688132]
#  [0.15824956]
#  [0.1570425 ]
#  [0.15939893]
#  [0.14565066]
#  [0.13820317]
#  [0.15385246]
#  [0.16307878]
#  [0.16595253]
#  [0.18777393]
#  [0.17733216]
#  [0.15286735]
#  [0.14505175]
#  [0.15366283]
#  [0.16230495]
#  [0.15331568]
#  [0.15159924]
#  [0.14378136]
#  [0.13587628]
#  [0.14345802]
#  [0.15615831]
#  [0.16652635]
#  [0.16972426]
#  [0.16159827]
#  [0.15207198]
#  [0.1449865 ]
#  [0.14786595]
#  [0.15256034]
#  [0.18811971]
#  [0.19853964]
#  [0.20320906]
#  [0.19636157]
#  [0.1810981 ]
#  [0.16899215]
#  [0.18486181]
#  [0.186178  ]
#  [0.19616023]
#  [0.19246858]
#  [0.18777135]
#  [0.17162196]
#  [0.16016945]
#  [0.16025066]
#  [0.16173159]
#  [0.1606591 ]
#  [0.15914206]
#  [0.15507782]
#  [0.15089066]
#  [0.14770764]
#  [0.17150536]
#  [0.16687074]
#  [0.18243596]
#  [0.1823378 ]
#  [0.19702023]
#  [0.19945537]
#  [0.19880304]
#  [0.20300287]
#  [0.21762803]
#  [0.2276543 ]
#  [0.20867941]
#  [0.22422262]
#  [0.22135207]
#  [0.21768776]
#  [0.22157586]
#  [0.21954569]
#  [0.24342899]
#  [0.2373078 ]
#  [0.21813029]
#  [0.21673818]
#  [0.21375346]
#  [0.2254454 ]
#  [0.22615753]
#  [0.219848  ]
#  [0.2322725 ]
#  [0.23571473]
#  [0.22266144]
#  [0.22388679]
#  [0.23468077]
#  [0.24385777]
#  [0.24945846]
#  [0.23707531]
#  [0.2311514 ]
#  [0.21447061]
#  [0.20892382]
#  [0.22302318]
#  [0.22502825]
#  [0.24823177]
#  [0.25915456]
#  [0.2516121 ]
#  [0.24896765]
#  [0.25040722]
#  [0.26023388]
#  [0.29104504]
#  [0.28444812]
#  [0.26876885]
#  [0.25054684]
#  [0.22001526]
#  [0.20505957]
#  [0.21245357]
#  [0.2013441 ]
#  [0.19968115]
#  [0.20000279]
#  [0.19227043]
#  [0.17822337]
#  [0.1673856 ]
#  [0.1795331 ]
#  [0.17013222]
#  [0.17703333]
#  [0.17602327]
#  [0.18634899]
#  [0.1590612 ]
#  [0.15958877]
#  [0.16872922]
#  [0.16578943]
#  [0.16362193]
#  [0.16173816]
#  [0.16995247]
#  [0.16450842]
#  [0.16088107]
#  [0.17017387]
#  [0.18843372]
#  [0.21956679]
#  [0.22577003]
#  [0.21763575]
#  [0.21146819]
#  [0.19478902]
#  [0.20954314]
#  [0.20077434]
#  [0.20502882]
#  [0.2116108 ]
#  [0.2218441 ]
#  [0.20660466]
#  [0.19601494]
#  [0.2007494 ]
#  [0.19707583]
#  [0.21338895]
#  [0.2038578 ]
#  [0.19887233]
#  [0.19157527]
#  [0.1972722 ]
#  [0.2113229 ]
#  [0.22926167]
#  [0.25224543]
#  [0.27379212]
#  [0.28409258]
#  [0.29482186]
#  [0.29194883]
#  [0.2919158 ]
#  [0.3054039 ]
#  [0.30789357]
#  [0.30977142]
#  [0.31083313]
#  [0.27160874]
#  [0.26137653]
#  [0.27256992]
#  [0.29017535]
#  [0.28629634]
#  [0.2906522 ]
#  [0.27327642]
#  [0.25675076]
#  [0.24485841]
#  [0.25120038]
#  [0.25434685]
#  [0.24425843]
#  [0.24163215]
#  [0.22802232]
#  [0.22419979]
#  [0.22949868]
#  [0.22618055]
#  [0.23878366]
#  [0.26831844]
#  [0.2653335 ]
#  [0.25890657]
#  [0.24156445]
#  [0.23109448]
#  [0.23410593]
#  [0.24835649]
#  [0.24286254]
#  [0.23549968]
#  [0.2273759 ]
#  [0.23773773]
#  [0.21731594]
#  [0.22583908]
#  [0.21523267]
#  [0.20769659]
#  [0.19304088]
#  [0.18766016]
#  [0.17516714]
#  [0.17728977]
#  [0.16978599]
#  [0.16981065]
#  [0.17228074]
#  [0.17031452]
#  [0.16993424]
#  [0.15891668]
#  [0.15393016]
#  [0.1563457 ]]
# rmse = 0.11187774727535164
# mae = 0.07748085184602647
# mape = 0.5064473802869719
# testY
# testY.shape
# (327,)
# <class 'numpy.ndarray'>
# prediction_val
# (327,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# C:\Users\kskis\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 3/3 - 4s - 1s/step - loss: 0.0229 - val_loss: 0.0189
# Epoch 2/50
# 3/3 - 0s - 52ms/step - loss: 0.0163 - val_loss: 0.0427
# Epoch 3/50
# 3/3 - 0s - 48ms/step - loss: 0.0164 - val_loss: 0.0365
# Epoch 4/50
# 3/3 - 0s - 47ms/step - loss: 0.0142 - val_loss: 0.0237
# Epoch 5/50
# 3/3 - 0s - 52ms/step - loss: 0.0133 - val_loss: 0.0175
# Epoch 6/50
# 3/3 - 0s - 47ms/step - loss: 0.0139 - val_loss: 0.0161
# Epoch 7/50
# 3/3 - 0s - 52ms/step - loss: 0.0142 - val_loss: 0.0172
# Epoch 8/50
# 3/3 - 0s - 47ms/step - loss: 0.0138 - val_loss: 0.0203
# Epoch 9/50
# 3/3 - 0s - 47ms/step - loss: 0.0136 - val_loss: 0.0231
# Epoch 10/50
# 3/3 - 0s - 47ms/step - loss: 0.0135 - val_loss: 0.0228
# Epoch 11/50
# 3/3 - 0s - 48ms/step - loss: 0.0133 - val_loss: 0.0201
# Epoch 12/50
# 3/3 - 0s - 47ms/step - loss: 0.0131 - val_loss: 0.0177
# Epoch 13/50
# 3/3 - 0s - 47ms/step - loss: 0.0131 - val_loss: 0.0167
# Epoch 14/50
# 3/3 - 0s - 47ms/step - loss: 0.0132 - val_loss: 0.0167
# Epoch 15/50
# 3/3 - 0s - 47ms/step - loss: 0.0131 - val_loss: 0.0173
# Epoch 16/50
# 3/3 - 0s - 42ms/step - loss: 0.0130 - val_loss: 0.0176
# Epoch 17/50
# 3/3 - 0s - 47ms/step - loss: 0.0130 - val_loss: 0.0169
# Epoch 18/50
# 3/3 - 0s - 42ms/step - loss: 0.0129 - val_loss: 0.0157
# Epoch 19/50
# 3/3 - 0s - 42ms/step - loss: 0.0128 - val_loss: 0.0149
# Epoch 20/50
# 3/3 - 0s - 42ms/step - loss: 0.0128 - val_loss: 0.0146
# Epoch 21/50
# 3/3 - 0s - 47ms/step - loss: 0.0128 - val_loss: 0.0148
# Epoch 22/50
# 3/3 - 0s - 42ms/step - loss: 0.0127 - val_loss: 0.0148
# Epoch 23/50
# 3/3 - 0s - 47ms/step - loss: 0.0127 - val_loss: 0.0146
# Epoch 24/50
# 3/3 - 0s - 52ms/step - loss: 0.0126 - val_loss: 0.0145
# Epoch 25/50
# 3/3 - 0s - 57ms/step - loss: 0.0126 - val_loss: 0.0150
# Epoch 26/50
# 3/3 - 0s - 47ms/step - loss: 0.0126 - val_loss: 0.0156
# Epoch 27/50
# 3/3 - 0s - 52ms/step - loss: 0.0125 - val_loss: 0.0155
# Epoch 28/50
# 3/3 - 0s - 47ms/step - loss: 0.0125 - val_loss: 0.0156
# Epoch 29/50
# 3/3 - 0s - 47ms/step - loss: 0.0124 - val_loss: 0.0159
# Epoch 30/50
# 3/3 - 0s - 47ms/step - loss: 0.0124 - val_loss: 0.0164
# Epoch 31/50
# 3/3 - 0s - 47ms/step - loss: 0.0123 - val_loss: 0.0169
# Epoch 32/50
# 3/3 - 0s - 45ms/step - loss: 0.0122 - val_loss: 0.0167
# Epoch 33/50
# 3/3 - 0s - 57ms/step - loss: 0.0122 - val_loss: 0.0173
# Epoch 34/50
# 3/3 - 0s - 47ms/step - loss: 0.0121 - val_loss: 0.0175
# Epoch 35/50
# 3/3 - 0s - 42ms/step - loss: 0.0120 - val_loss: 0.0175
# Epoch 36/50
# 3/3 - 0s - 47ms/step - loss: 0.0119 - val_loss: 0.0184
# Epoch 37/50
# 3/3 - 0s - 47ms/step - loss: 0.0118 - val_loss: 0.0187
# Epoch 38/50
# 3/3 - 0s - 47ms/step - loss: 0.0117 - val_loss: 0.0196
# Epoch 39/50
# 3/3 - 0s - 47ms/step - loss: 0.0115 - val_loss: 0.0208
# Epoch 40/50
# 3/3 - 0s - 47ms/step - loss: 0.0114 - val_loss: 0.0217
# Epoch 41/50
# 3/3 - 0s - 58ms/step - loss: 0.0112 - val_loss: 0.0236
# Epoch 42/50
# 3/3 - 0s - 52ms/step - loss: 0.0111 - val_loss: 0.0257
# Epoch 43/50
# 3/3 - 0s - 47ms/step - loss: 0.0109 - val_loss: 0.0278
# Epoch 44/50
# 3/3 - 0s - 63ms/step - loss: 0.0108 - val_loss: 0.0332
# Epoch 45/50
# 3/3 - 0s - 52ms/step - loss: 0.0106 - val_loss: 0.0313
# Epoch 46/50
# 3/3 - 0s - 47ms/step - loss: 0.0105 - val_loss: 0.0378
# Epoch 47/50
# 3/3 - 0s - 63ms/step - loss: 0.0104 - val_loss: 0.0267
# Epoch 48/50
# 3/3 - 0s - 52ms/step - loss: 0.0103 - val_loss: 0.0380
# Epoch 49/50
# 3/3 - 0s - 47ms/step - loss: 0.0102 - val_loss: 0.0273
# Epoch 50/50
# 3/3 - 0s - 47ms/step - loss: 0.0102 - val_loss: 0.0392
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# <class 'numpy.ndarray'>
# [[0.44007802]
#  [0.49033317]
#  [0.5648051 ]
#  [0.5517378 ]
#  [0.3949905 ]
#  [0.40902358]
#  [0.42145917]
#  [0.46084678]
#  [0.48293266]
#  [0.44370094]
#  [0.38137537]
#  [0.3260493 ]
#  [0.32467577]
#  [0.4155115 ]
#  [0.37816334]
#  [0.41223836]
#  [0.39918724]
#  [0.3437342 ]
#  [0.31019744]
#  [0.31184933]
#  [0.40493432]
#  [0.44596198]
#  [0.42477956]
#  [0.38028154]
#  [0.2949409 ]
#  [0.26211712]
#  [0.34196252]
#  [0.41064456]
#  [0.41535518]
#  [0.43393567]
#  [0.43017465]
#  [0.36981794]
#  [0.207927  ]
#  [0.21023256]
#  [0.2309687 ]
#  [0.2750487 ]
#  [0.32366678]
#  [0.3258778 ]
#  [0.28840655]
#  [0.2867253 ]
#  [0.29588696]
#  [0.27699777]
#  [0.30682957]
#  [0.33784944]
#  [0.32385468]
#  [0.25123146]
#  [0.23506229]
#  [0.27862749]
#  [0.29305133]]
# rmse = 0.19795626239653769
# mae = 0.17300331122443266
# mape = 1.2147654293969616
# testY
# testY.shape
# (49,)
# <class 'numpy.ndarray'>
# prediction_val
# (49,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# C:\Users\kskis\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 - 4s - 210ms/step - loss: 2.3197e-04 - val_loss: 0.0052
# Epoch 2/50
# 20/20 - 1s - 38ms/step - loss: 1.2150e-04 - val_loss: 0.0072
# Epoch 3/50
# 20/20 - 0s - 14ms/step - loss: 1.0671e-04 - val_loss: 0.0060
# Epoch 4/50
# 20/20 - 0s - 14ms/step - loss: 9.1415e-05 - val_loss: 0.0048
# Epoch 5/50
# 20/20 - 0s - 15ms/step - loss: 1.0107e-04 - val_loss: 0.0052
# Epoch 6/50
# 20/20 - 0s - 13ms/step - loss: 7.6879e-05 - val_loss: 0.0056
# Epoch 7/50
# 20/20 - 0s - 13ms/step - loss: 8.1263e-05 - val_loss: 0.0048
# Epoch 8/50
# 20/20 - 0s - 14ms/step - loss: 7.2964e-05 - val_loss: 0.0048
# Epoch 9/50
# 20/20 - 0s - 13ms/step - loss: 7.0422e-05 - val_loss: 0.0051
# Epoch 10/50
# 20/20 - 0s - 13ms/step - loss: 6.9945e-05 - val_loss: 0.0049
# Epoch 11/50
# 20/20 - 0s - 16ms/step - loss: 6.6823e-05 - val_loss: 0.0047
# Epoch 12/50
# 20/20 - 0s - 16ms/step - loss: 6.8438e-05 - val_loss: 0.0050
# Epoch 13/50
# 20/20 - 0s - 12ms/step - loss: 6.6138e-05 - val_loss: 0.0050
# Epoch 14/50
# 20/20 - 0s - 16ms/step - loss: 6.7445e-05 - val_loss: 0.0047
# Epoch 15/50
# 20/20 - 0s - 15ms/step - loss: 7.0641e-05 - val_loss: 0.0048
# Epoch 16/50
# 20/20 - 0s - 14ms/step - loss: 6.6494e-05 - val_loss: 0.0052
# Epoch 17/50
# 20/20 - 0s - 17ms/step - loss: 7.2073e-05 - val_loss: 0.0047
# Epoch 18/50
# 20/20 - 0s - 14ms/step - loss: 6.6519e-05 - val_loss: 0.0047
# Epoch 19/50
# 20/20 - 0s - 16ms/step - loss: 7.4747e-05 - val_loss: 0.0049
# Epoch 20/50
# 20/20 - 0s - 16ms/step - loss: 6.7918e-05 - val_loss: 0.0055
# Epoch 21/50
# 20/20 - 1s - 29ms/step - loss: 8.0710e-05 - val_loss: 0.0047
# Epoch 22/50
# 20/20 - 0s - 13ms/step - loss: 7.8610e-05 - val_loss: 0.0047
# Epoch 23/50
# 20/20 - 0s - 15ms/step - loss: 8.0196e-05 - val_loss: 0.0052
# Epoch 24/50
# 20/20 - 0s - 15ms/step - loss: 7.2614e-05 - val_loss: 0.0051
# Epoch 25/50
# 20/20 - 0s - 15ms/step - loss: 7.1987e-05 - val_loss: 0.0046
# Epoch 26/50
# 20/20 - 0s - 14ms/step - loss: 8.1898e-05 - val_loss: 0.0048
# Epoch 27/50
# 20/20 - 0s - 15ms/step - loss: 7.3518e-05 - val_loss: 0.0054
# Epoch 28/50
# 20/20 - 0s - 14ms/step - loss: 7.3580e-05 - val_loss: 0.0048
# Epoch 29/50
# 20/20 - 0s - 15ms/step - loss: 6.3985e-05 - val_loss: 0.0047
# Epoch 30/50
# 20/20 - 0s - 13ms/step - loss: 6.7309e-05 - val_loss: 0.0050
# Epoch 31/50
# 20/20 - 0s - 14ms/step - loss: 6.2004e-05 - val_loss: 0.0050
# Epoch 32/50
# 20/20 - 0s - 16ms/step - loss: 6.2759e-05 - val_loss: 0.0047
# Epoch 33/50
# 20/20 - 0s - 16ms/step - loss: 6.3866e-05 - val_loss: 0.0048
# Epoch 34/50
# 20/20 - 0s - 14ms/step - loss: 6.1118e-05 - val_loss: 0.0051
# Epoch 35/50
# 20/20 - 0s - 17ms/step - loss: 6.2196e-05 - val_loss: 0.0048
# Epoch 36/50
# 20/20 - 0s - 15ms/step - loss: 5.9421e-05 - val_loss: 0.0047
# Epoch 37/50
# 20/20 - 0s - 14ms/step - loss: 6.3042e-05 - val_loss: 0.0049
# Epoch 38/50
# 20/20 - 0s - 16ms/step - loss: 6.0293e-05 - val_loss: 0.0052
# Epoch 39/50
# 20/20 - 0s - 14ms/step - loss: 6.3932e-05 - val_loss: 0.0047
# Epoch 40/50
# 20/20 - 0s - 16ms/step - loss: 6.4785e-05 - val_loss: 0.0047
# Epoch 41/50
# 20/20 - 0s - 16ms/step - loss: 6.3113e-05 - val_loss: 0.0050
# Epoch 42/50
# 20/20 - 0s - 15ms/step - loss: 6.7504e-05 - val_loss: 0.0053
# Epoch 43/50
# 20/20 - 0s - 17ms/step - loss: 7.0736e-05 - val_loss: 0.0046
# Epoch 44/50
# 20/20 - 0s - 16ms/step - loss: 8.2103e-05 - val_loss: 0.0047
# Epoch 45/50
# 20/20 - 0s - 16ms/step - loss: 6.9728e-05 - val_loss: 0.0053
# Epoch 46/50
# 20/20 - 0s - 15ms/step - loss: 6.6664e-05 - val_loss: 0.0050
# Epoch 47/50
# 20/20 - 0s - 16ms/step - loss: 6.2082e-05 - val_loss: 0.0047
# Epoch 48/50
# 20/20 - 0s - 16ms/step - loss: 6.7372e-05 - val_loss: 0.0049
# Epoch 49/50
# 20/20 - 0s - 17ms/step - loss: 6.2751e-05 - val_loss: 0.0054
# Epoch 50/50
# 20/20 - 0s - 17ms/step - loss: 6.5658e-05 - val_loss: 0.0048
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000279D0259D00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# <class 'numpy.ndarray'>
# [[0.01142645]
#  [0.01293033]
#  [0.01625025]
#  [0.01593187]
#  [0.01839039]
#  [0.02373839]
#  [0.02268392]
#  [0.01801529]
#  [0.01678679]
#  [0.01802157]
#  [0.0189647 ]
#  [0.01890596]
#  [0.0165005 ]
#  [0.01356881]
#  [0.01210065]
#  [0.01405353]
#  [0.01960297]
#  [0.02635115]
#  [0.02244874]
#  [0.02861302]
#  [0.02751985]
#  [0.02625363]
#  [0.02571532]
#  [0.02540808]
#  [0.02215606]
#  [0.0266124 ]
#  [0.02093928]
#  [0.01749166]
#  [0.01455774]
#  [0.0177206 ]
#  [0.01912569]
#  [0.01693286]
#  [0.01592188]
#  [0.01435183]
#  [0.01391337]
#  [0.01328563]
#  [0.01234462]
#  [0.01185146]
#  [0.01284962]
#  [0.01384315]
#  [0.01408163]
#  [0.013826  ]
#  [0.01374875]
#  [0.01328089]
#  [0.01326854]
#  [0.01557416]
#  [0.02351336]
#  [0.02096581]
#  [0.02043956]
#  [0.01719546]
#  [0.01671872]
#  [0.01724757]
#  [0.01727324]
#  [0.01742845]
#  [0.01714907]
#  [0.01610671]
#  [0.02065503]
#  [0.02379263]
#  [0.02180791]
#  [0.02357325]
#  [0.02328958]
#  [0.02069053]
#  [0.02230139]
#  [0.03703855]
#  [0.06156678]
#  [0.0487311 ]
#  [0.04474548]
#  [0.04387434]
#  [0.05000158]
#  [0.04528803]
#  [0.04293415]
#  [0.05416455]
#  [0.0428178 ]
#  [0.03769654]
#  [0.03770723]
#  [0.03706624]
#  [0.03802373]
#  [0.03257711]
#  [0.03293419]
#  [0.04236204]
#  [0.04232704]
#  [0.03937326]
#  [0.04332564]
#  [0.03835832]
#  [0.0409894 ]
#  [0.04499518]
#  [0.04453307]
#  [0.04334721]
#  [0.04105746]
#  [0.04657357]
#  [0.04390388]
#  [0.04154296]
#  [0.04260762]
#  [0.05398934]
#  [0.0586362 ]
#  [0.06032774]
#  [0.06378719]
#  [0.06010143]
#  [0.05494333]
#  [0.05834984]
#  [0.06129074]
#  [0.06277674]
#  [0.05956776]
#  [0.05712681]
#  [0.05660834]
#  [0.05749704]
#  [0.0588164 ]
#  [0.05658728]
#  [0.05648628]
#  [0.06076588]
#  [0.06229877]
#  [0.06484607]
#  [0.06019463]
#  [0.0641736 ]
#  [0.07642662]
#  [0.0679975 ]
#  [0.05911938]
#  [0.05493043]
#  [0.04825869]
#  [0.04810746]
#  [0.04721421]
#  [0.04686316]
#  [0.04610046]
#  [0.04471426]
#  [0.04378077]
#  [0.04590973]
#  [0.05072018]
#  [0.05648899]
#  [0.05985486]
#  [0.05924227]
#  [0.05867799]
#  [0.05942041]
#  [0.06226854]
#  [0.05872552]
#  [0.06066788]
#  [0.06336421]
#  [0.06235999]
#  [0.06146049]
#  [0.05982829]
#  [0.05761695]
#  [0.05282133]
#  [0.0535939 ]
#  [0.05256577]
#  [0.05113325]
#  [0.05142785]
#  [0.05280475]
#  [0.05376015]
#  [0.04799179]
#  [0.05367043]
#  [0.05932242]
#  [0.06725013]
#  [0.07335103]
#  [0.07800761]
#  [0.07587676]
#  [0.0734702 ]
#  [0.06585476]
#  [0.06605624]
#  [0.06313746]
#  [0.06711327]
#  [0.06801907]
#  [0.06652202]
#  [0.06070697]
#  [0.06265159]
#  [0.06950623]
#  [0.07746892]
#  [0.07261643]
#  [0.07704422]
#  [0.07701822]
#  [0.0801807 ]
#  [0.07899296]
#  [0.08441158]
#  [0.08814583]
#  [0.0877988 ]
#  [0.08874801]
#  [0.0755334 ]
#  [0.06829193]
#  [0.0643988 ]
#  [0.06318239]
#  [0.06480472]
#  [0.06274674]
#  [0.05919861]
#  [0.05896573]
#  [0.05562698]
#  [0.06444653]
#  [0.06791425]
#  [0.0692535 ]
#  [0.06979565]
#  [0.06903657]
#  [0.07909317]
#  [0.09210812]
#  [0.10338136]
#  [0.14848323]
#  [0.12553549]
#  [0.12392664]
#  [0.12070628]
#  [0.10558163]
#  [0.09351414]
#  [0.09582883]
#  [0.08932206]
#  [0.09710874]
#  [0.10764191]
#  [0.09292509]
#  [0.07788858]
#  [0.07179615]
#  [0.06989759]
#  [0.06856028]
#  [0.06567617]
#  [0.05857477]
#  [0.05277486]
#  [0.04829357]
#  [0.04546746]
#  [0.04701165]
#  [0.0447693 ]
#  [0.04259219]
#  [0.04455848]
#  [0.04630055]
#  [0.04542642]
#  [0.0421121 ]
#  [0.04217083]
#  [0.04331068]
#  [0.04196757]
#  [0.03848499]
#  [0.03497095]
#  [0.03226807]
#  [0.03315991]
#  [0.03419737]
#  [0.03448859]
#  [0.03246791]
#  [0.03105018]
#  [0.0300059 ]
#  [0.02674511]
#  [0.02608747]
#  [0.02899061]
#  [0.03832418]
#  [0.03597343]
#  [0.03176543]
#  [0.03469026]
#  [0.0297389 ]
#  [0.02946394]
#  [0.03056757]
#  [0.0292649 ]
#  [0.03053846]
#  [0.05882383]
#  [0.04655706]
#  [0.04371962]
#  [0.04316386]
#  [0.04203768]
#  [0.04598862]
#  [0.04398091]
#  [0.04512947]
#  [0.04474358]
#  [0.0412427 ]
#  [0.0376747 ]
#  [0.03495326]
#  [0.03326512]
#  [0.03241878]
#  [0.03200079]
#  [0.0311257 ]
#  [0.03021093]
#  [0.03009568]
#  [0.03078874]
#  [0.03131736]
#  [0.03353831]
#  [0.0338215 ]
#  [0.03384399]
#  [0.03549418]
#  [0.03315081]
#  [0.04095452]
#  [0.04068559]
#  [0.03921013]
#  [0.03931367]
#  [0.03848943]
#  [0.03710438]
#  [0.03959411]
#  [0.04182758]
#  [0.04216845]
#  [0.04599977]
#  [0.05227672]
#  [0.05583529]
#  [0.05866217]
#  [0.05768812]
#  [0.06686032]
#  [0.06232026]
#  [0.06106525]
#  [0.0618698 ]
#  [0.06295505]
#  [0.059085  ]
#  [0.05927477]
#  [0.06330284]
#  [0.05936689]
#  [0.0561479 ]
#  [0.05384283]
#  [0.05443328]
#  [0.05185795]
#  [0.05243003]
#  [0.05496706]
#  [0.05631362]
#  [0.05540759]
#  [0.05595316]
#  [0.05618811]
#  [0.05584768]
#  [0.0535639 ]
#  [0.05933979]
#  [0.06882185]
#  [0.07503605]
#  [0.07857144]
#  [0.0875013 ]
#  [0.08837858]
#  [0.08160452]
#  [0.08126694]
#  [0.08099937]
#  [0.07803479]
#  [0.06998079]
#  [0.06440376]
#  [0.0576093 ]
#  [0.05453597]]
# rmse = 0.0693378686849182
# mae = 0.022111570708022298
# mape = 0.3260643544146072
# testY
# testY.shape
# (316,)
# <class 'numpy.ndarray'>
# prediction_val
# (316,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# C:\Users\kskis\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 28/28 - 4s - 152ms/step - loss: 0.0016 - val_loss: 0.0378
# Epoch 2/50
# 28/28 - 0s - 15ms/step - loss: 7.3852e-04 - val_loss: 0.0494
# Epoch 3/50
# 28/28 - 0s - 16ms/step - loss: 6.5510e-04 - val_loss: 0.0441
# Epoch 4/50
# 28/28 - 0s - 15ms/step - loss: 6.3477e-04 - val_loss: 0.0270
# Epoch 5/50
# 28/28 - 0s - 15ms/step - loss: 5.2391e-04 - val_loss: 0.0319
# Epoch 6/50
# 28/28 - 0s - 14ms/step - loss: 5.2681e-04 - val_loss: 0.0335
# Epoch 7/50
# 28/28 - 0s - 16ms/step - loss: 5.2622e-04 - val_loss: 0.0253
# Epoch 8/50
# 28/28 - 0s - 16ms/step - loss: 5.0526e-04 - val_loss: 0.0270
# Epoch 9/50
# 28/28 - 0s - 16ms/step - loss: 5.1157e-04 - val_loss: 0.0307
# Epoch 10/50
# 28/28 - 0s - 16ms/step - loss: 5.1338e-04 - val_loss: 0.0236
# Epoch 11/50
# 28/28 - 0s - 15ms/step - loss: 4.9795e-04 - val_loss: 0.0243
# Epoch 12/50
# 28/28 - 0s - 16ms/step - loss: 5.0368e-04 - val_loss: 0.0283
# Epoch 13/50
# 28/28 - 0s - 15ms/step - loss: 5.0528e-04 - val_loss: 0.0220
# Epoch 14/50
# 28/28 - 0s - 15ms/step - loss: 4.9560e-04 - val_loss: 0.0240
# Epoch 15/50
# 28/28 - 0s - 16ms/step - loss: 4.9260e-04 - val_loss: 0.0238
# Epoch 16/50
# 28/28 - 0s - 17ms/step - loss: 4.8952e-04 - val_loss: 0.0247
# Epoch 17/50
# 28/28 - 0s - 16ms/step - loss: 4.9158e-04 - val_loss: 0.0208
# Epoch 18/50
# 28/28 - 0s - 16ms/step - loss: 4.9151e-04 - val_loss: 0.0277
# Epoch 19/50
# 28/28 - 0s - 16ms/step - loss: 4.9766e-04 - val_loss: 0.0218
# Epoch 20/50
# 28/28 - 0s - 15ms/step - loss: 4.9197e-04 - val_loss: 0.0261
# Epoch 21/50
# 28/28 - 0s - 16ms/step - loss: 4.9266e-04 - val_loss: 0.0222
# Epoch 22/50
# 28/28 - 1s - 22ms/step - loss: 4.9055e-04 - val_loss: 0.0294
# Epoch 23/50
# 28/28 - 0s - 14ms/step - loss: 5.0293e-04 - val_loss: 0.0218
# Epoch 24/50
# 28/28 - 0s - 12ms/step - loss: 4.8917e-04 - val_loss: 0.0259
# Epoch 25/50
# 28/28 - 0s - 13ms/step - loss: 4.8635e-04 - val_loss: 0.0215
# Epoch 26/50
# 28/28 - 0s - 12ms/step - loss: 5.0395e-04 - val_loss: 0.0354
# Epoch 27/50
# 28/28 - 0s - 13ms/step - loss: 5.3660e-04 - val_loss: 0.0182
# Epoch 28/50
# 28/28 - 0s - 15ms/step - loss: 4.9295e-04 - val_loss: 0.0186
# Epoch 29/50
# 28/28 - 0s - 15ms/step - loss: 4.9679e-04 - val_loss: 0.0217
# Epoch 30/50
# 28/28 - 0s - 12ms/step - loss: 4.8051e-04 - val_loss: 0.0253
# Epoch 31/50
# 28/28 - 0s - 16ms/step - loss: 4.8233e-04 - val_loss: 0.0207
# Epoch 32/50
# 28/28 - 0s - 15ms/step - loss: 4.8930e-04 - val_loss: 0.0285
# Epoch 33/50
# 28/28 - 0s - 16ms/step - loss: 4.8695e-04 - val_loss: 0.0203
# Epoch 34/50
# 28/28 - 0s - 16ms/step - loss: 4.7980e-04 - val_loss: 0.0313
# Epoch 35/50
# 28/28 - 0s - 17ms/step - loss: 4.8100e-04 - val_loss: 0.0209
# Epoch 36/50
# 28/28 - 0s - 15ms/step - loss: 4.8863e-04 - val_loss: 0.0322
# Epoch 37/50
# 28/28 - 0s - 14ms/step - loss: 5.0149e-04 - val_loss: 0.0263
# Epoch 38/50
# 28/28 - 0s - 17ms/step - loss: 4.7638e-04 - val_loss: 0.0308
# Epoch 39/50
# 28/28 - 0s - 16ms/step - loss: 4.6995e-04 - val_loss: 0.0310
# Epoch 40/50
# 28/28 - 0s - 17ms/step - loss: 4.6598e-04 - val_loss: 0.0402
# Epoch 41/50
# 28/28 - 0s - 16ms/step - loss: 4.7004e-04 - val_loss: 0.0273
# Epoch 42/50
# 28/28 - 0s - 16ms/step - loss: 4.7276e-04 - val_loss: 0.0439
# Epoch 43/50
# 28/28 - 0s - 16ms/step - loss: 4.9535e-04 - val_loss: 0.0295
# Epoch 44/50
# 28/28 - 0s - 15ms/step - loss: 4.7734e-04 - val_loss: 0.0389
# Epoch 45/50
# 28/28 - 0s - 16ms/step - loss: 4.7604e-04 - val_loss: 0.0370
# Epoch 46/50
# 28/28 - 0s - 16ms/step - loss: 4.6650e-04 - val_loss: 0.0538
# Epoch 47/50
# 28/28 - 0s - 17ms/step - loss: 4.9080e-04 - val_loss: 0.0332
# Epoch 48/50
# 28/28 - 0s - 16ms/step - loss: 4.8598e-04 - val_loss: 0.0447
# Epoch 49/50
# 28/28 - 0s - 17ms/step - loss: 5.0589e-04 - val_loss: 0.0377
# Epoch 50/50
# 28/28 - 0s - 15ms/step - loss: 4.6399e-04 - val_loss: 0.0388
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# <class 'numpy.ndarray'>
# [[0.01968542]
#  [0.0197627 ]
#  [0.01917622]
#  [0.01881368]
#  [0.01791527]
#  [0.0174879 ]
#  [0.01835566]
#  [0.01873147]
#  [0.01919147]
#  [0.01909118]
#  [0.01873165]
#  [0.01852366]
#  [0.01786168]
#  [0.0192667 ]
#  [0.02026651]
#  [0.02188112]
#  [0.02117766]
#  [0.02005504]
#  [0.01928802]
#  [0.01860829]
#  [0.01862544]
#  [0.01768978]
#  [0.01692579]
#  [0.0161137 ]
#  [0.01706136]
#  [0.01667151]
#  [0.01691573]
#  [0.01870457]
#  [0.01983891]
#  [0.02119345]
#  [0.02508218]
#  [0.02715895]
#  [0.02821213]
#  [0.02898238]
#  [0.03389363]
#  [0.03475944]
#  [0.03326846]
#  [0.03264511]
#  [0.03323981]
#  [0.03319761]
#  [0.03375449]
#  [0.0340218 ]
#  [0.03256325]
#  [0.03245721]
#  [0.03306055]
#  [0.03255073]
#  [0.03124282]
#  [0.02966593]
#  [0.03038604]
#  [0.03067973]
#  [0.03402581]
#  [0.03861867]
#  [0.04270995]
#  [0.03614889]
#  [0.03238082]
#  [0.03586731]
#  [0.04028394]
#  [0.03567498]
#  [0.03186611]
#  [0.03193718]
#  [0.02926815]
#  [0.02649267]
#  [0.02816035]
#  [0.02950456]
#  [0.02944525]
#  [0.02895885]
#  [0.03094172]
#  [0.02916669]
#  [0.0351725 ]
#  [0.04313099]
#  [0.06809597]
#  [0.07491717]
#  [0.0689543 ]
#  [0.05446866]
#  [0.04441376]
#  [0.02933221]
#  [0.02097879]
#  [0.01700207]
#  [0.01459114]
#  [0.01811942]
#  [0.02065242]
#  [0.02216531]
#  [0.0254075 ]
#  [0.03044523]
#  [0.03178595]
#  [0.02863648]
#  [0.05397167]
#  [0.0514599 ]
#  [0.03969667]
#  [0.0318682 ]
#  [0.03024188]
#  [0.02568338]
#  [0.0219734 ]
#  [0.01873198]
#  [0.01772642]
#  [0.01590554]
#  [0.01975456]
#  [0.02295548]
#  [0.02549852]
#  [0.02512498]
#  [0.02476822]
#  [0.02423431]
#  [0.02199773]
#  [0.02257284]
#  [0.02332236]
#  [0.02407159]
#  [0.02199173]
#  [0.02075314]
#  [0.01961795]
#  [0.01913417]
#  [0.01911348]
#  [0.02105593]
#  [0.01961506]
#  [0.01947783]
#  [0.02046539]
#  [0.02161825]
#  [0.01972305]
#  [0.01877672]
#  [0.0194252 ]
#  [0.02016047]
#  [0.02245129]
#  [0.0238012 ]
#  [0.02235917]
#  [0.02075684]
#  [0.02132562]
#  [0.0221639 ]
#  [0.02289424]
#  [0.02290643]
#  [0.02227475]
#  [0.02335053]
#  [0.02212942]
#  [0.02306875]
#  [0.02439623]
#  [0.02355103]
#  [0.02301152]
#  [0.02503528]
#  [0.03021871]
#  [0.02887682]
#  [0.02783379]
#  [0.02746603]
#  [0.0259647 ]
#  [0.02658489]
#  [0.02695637]
#  [0.02943419]
#  [0.02723129]
#  [0.02632111]
#  [0.02783675]
#  [0.03061603]
#  [0.03226645]
#  [0.03163838]
#  [0.03317722]
#  [0.03618417]
#  [0.0401402 ]
#  [0.04795688]
#  [0.05447921]
#  [0.04600477]
#  [0.04732832]
#  [0.03669396]
#  [0.03102914]
#  [0.02872154]
#  [0.03661139]
#  [0.0392613 ]
#  [0.03136264]
#  [0.02781548]
#  [0.03710302]
#  [0.0395777 ]
#  [0.03974334]
#  [0.03904456]
#  [0.03857081]
#  [0.03892929]
#  [0.0364567 ]
#  [0.03518473]
#  [0.03221637]
#  [0.03414952]
#  [0.03351519]
#  [0.03571291]
#  [0.03889763]
#  [0.05542817]
#  [0.04510957]
#  [0.03751894]
#  [0.03397506]
#  [0.03854113]
#  [0.03623944]
#  [0.0362166 ]
#  [0.03062532]
#  [0.02670338]
#  [0.02683675]
#  [0.04091869]
#  [0.05527905]
#  [0.05670064]
#  [0.0609125 ]
#  [0.05824619]
#  [0.04861981]
#  [0.0612251 ]
#  [0.11438186]
#  [0.16834149]
#  [0.15264197]
#  [0.15300341]
#  [0.15585901]
#  [0.14582656]
#  [0.11113213]
#  [0.09753102]
#  [0.11031589]
#  [0.07455957]
#  [0.05672899]
#  [0.06646312]
#  [0.05955387]
#  [0.06452704]
#  [0.06461892]
#  [0.06766209]
#  [0.09610194]
#  [0.08994219]
#  [0.09571127]
#  [0.09293434]
#  [0.07225456]
#  [0.0765993 ]
#  [0.08853318]
#  [0.07897799]
#  [0.06817329]
#  [0.07254558]
#  [0.08099307]
#  [0.09776461]
#  [0.09483038]
#  [0.09808724]
#  [0.11687285]
#  [0.12767603]
#  [0.14447264]
#  [0.16563895]
#  [0.13771522]
#  [0.12849416]
#  [0.13774055]
#  [0.13833824]
#  [0.13028544]
#  [0.10754907]
#  [0.09589384]
#  [0.07637176]
#  [0.0563552 ]
#  [0.06315146]
#  [0.06545845]
#  [0.07475977]
#  [0.08925538]
#  [0.10050631]
#  [0.12787119]
#  [0.10370503]
#  [0.13515422]
#  [0.15016411]
#  [0.09234183]
#  [0.05217334]
#  [0.03649376]
#  [0.02253817]
#  [0.01723876]
#  [0.0270636 ]
#  [0.03731736]
#  [0.04038594]
#  [0.04041597]
#  [0.05211599]
#  [0.05122553]
#  [0.06160066]
#  [0.07773052]
#  [0.09022579]
#  [0.08705926]
#  [0.09072185]
#  [0.09162851]
#  [0.10303733]
#  [0.09449903]
#  [0.09933003]
#  [0.09654413]
#  [0.092843  ]
#  [0.09305   ]
#  [0.07597846]
#  [0.06426863]
#  [0.06057664]
#  [0.07131606]
#  [0.06261671]
#  [0.06082365]
#  [0.05884508]
#  [0.05355464]
#  [0.04880759]
#  [0.05295107]
#  [0.06679142]
#  [0.07680949]
#  [0.09300375]
#  [0.10165494]
#  [0.10862498]
#  [0.09826358]
#  [0.08578706]
#  [0.09363873]
#  [0.09677395]
#  [0.08177885]
#  [0.06803626]
#  [0.057833  ]
#  [0.05784012]
#  [0.05618568]
#  [0.06597248]
#  [0.08012929]
#  [0.09060009]
#  [0.08010548]
#  [0.12133338]
#  [0.10438407]
#  [0.10678165]
#  [0.11023191]
#  [0.12357308]
#  [0.08253869]
#  [0.07528542]
#  [0.06541611]
#  [0.03069643]
#  [0.02707945]
#  [0.0436654 ]
#  [0.05558781]
#  [0.07380927]
#  [0.08365275]
#  [0.08759204]
#  [0.09279808]
#  [0.1004157 ]
#  [0.14465246]
#  [0.1747202 ]
#  [0.17793298]
#  [0.16245794]
#  [0.14715263]
#  [0.1642484 ]
#  [0.16068625]
#  [0.2240678 ]
#  [0.22653106]
#  [0.18403925]
#  [0.1583341 ]
#  [0.12221404]
#  [0.08024601]
#  [0.07295779]
#  [0.07010288]
#  [0.07805886]
#  [0.12998287]
#  [0.11266896]
#  [0.08344225]
#  [0.05762621]
#  [0.06302606]
#  [0.06400662]
#  [0.05733167]
#  [0.05684449]
#  [0.05669828]
#  [0.05331866]
#  [0.05319747]
#  [0.05644568]
#  [0.07014567]
#  [0.06861089]
#  [0.07524541]
#  [0.07984304]
#  [0.07891092]
#  [0.07532302]
#  [0.07552427]
#  [0.08240198]
#  [0.08038114]
#  [0.07776988]
#  [0.07476048]
#  [0.07159328]
#  [0.06860723]
#  [0.07253316]
#  [0.07978432]
#  [0.08109283]
#  [0.07635992]
#  [0.0746132 ]
#  [0.0724346 ]
#  [0.06607304]
#  [0.06908759]
#  [0.07027487]
#  [0.07871826]
#  [0.06636996]
#  [0.0610706 ]
#  [0.05718651]
#  [0.05274493]
#  [0.05750673]
#  [0.07890363]
#  [0.07625185]
#  [0.07755045]
#  [0.07545084]
#  [0.07555373]
#  [0.07500564]
#  [0.07901897]
#  [0.08013107]
#  [0.08570796]
#  [0.08716797]
#  [0.08578049]
#  [0.08578794]
#  [0.08234741]
#  [0.08024068]
#  [0.08141153]
#  [0.07914767]
#  [0.07873461]
#  [0.07565534]
#  [0.07144564]
#  [0.06834435]
#  [0.06899623]
#  [0.06840534]
#  [0.06588919]
#  [0.06715184]
#  [0.0699768 ]
#  [0.0731456 ]
#  [0.0765316 ]
#  [0.07817007]
#  [0.08932851]
#  [0.09919227]
#  [0.1014165 ]
#  [0.09816745]
#  [0.09734638]
#  [0.09620795]
#  [0.0982565 ]
#  [0.10118627]
#  [0.09846413]
#  [0.10058773]
#  [0.10584899]
#  [0.1085335 ]
#  [0.11658473]
#  [0.11819284]
#  [0.12420037]
#  [0.12455956]
#  [0.12453996]
#  [0.11746226]
#  [0.11841422]
#  [0.11100458]
#  [0.11189938]
#  [0.11765274]
#  [0.1142363 ]
#  [0.10929454]
#  [0.10982923]
#  [0.11454234]
#  [0.10957748]
#  [0.11037055]
#  [0.1244712 ]
#  [0.12632567]
#  [0.12488656]
#  [0.12195314]
#  [0.12273456]
#  [0.11563918]
#  [0.11497422]
#  [0.12680921]
#  [0.13738352]
#  [0.15431547]
#  [0.16188994]
#  [0.16730511]
#  [0.14967766]
#  [0.14516026]
#  [0.15029617]
#  [0.1506432 ]
#  [0.13770409]
#  [0.12863459]
#  [0.11286248]
#  [0.09488006]
#  [0.09556092]]
# rmse = 0.1972052214207747
# mae = 0.1172495780216414
# mape = 0.5374603493944885
# testY
# testY.shape
# (447,)
# <class 'numpy.ndarray'>
# prediction_val
# (447,)
# <class 'numpy.ndarray'>
# type data
# <class 'numpy.ndarray'>
# Epoch 1/50
# C:\Users\kskis\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 20/20 - 4s - 222ms/step - loss: 4.4610e-04 - val_loss: 0.0084
# Epoch 2/50
# 20/20 - 0s - 18ms/step - loss: 3.8888e-04 - val_loss: 0.0070
# Epoch 3/50
# 20/20 - 0s - 17ms/step - loss: 3.3095e-04 - val_loss: 0.0063
# Epoch 4/50
# 20/20 - 0s - 19ms/step - loss: 2.6018e-04 - val_loss: 0.0082
# Epoch 5/50
# 20/20 - 0s - 18ms/step - loss: 2.8619e-04 - val_loss: 0.0089
# Epoch 6/50
# 20/20 - 0s - 18ms/step - loss: 2.4224e-04 - val_loss: 0.0065
# Epoch 7/50
# 20/20 - 0s - 20ms/step - loss: 2.2444e-04 - val_loss: 0.0066
# Epoch 8/50
# 20/20 - 0s - 16ms/step - loss: 2.2360e-04 - val_loss: 0.0074
# Epoch 9/50
# 20/20 - 0s - 18ms/step - loss: 2.2417e-04 - val_loss: 0.0067
# Epoch 10/50
# 20/20 - 0s - 17ms/step - loss: 2.1302e-04 - val_loss: 0.0064
# Epoch 11/50
# 20/20 - 0s - 16ms/step - loss: 2.0496e-04 - val_loss: 0.0069
# Epoch 12/50
# 20/20 - 0s - 16ms/step - loss: 2.1512e-04 - val_loss: 0.0071
# Epoch 13/50
# 20/20 - 0s - 16ms/step - loss: 2.1054e-04 - val_loss: 0.0063
# Epoch 14/50
# 20/20 - 0s - 16ms/step - loss: 2.0667e-04 - val_loss: 0.0063
# Epoch 15/50
# 20/20 - 0s - 19ms/step - loss: 2.0311e-04 - val_loss: 0.0071
# Epoch 16/50
# 20/20 - 0s - 19ms/step - loss: 2.1768e-04 - val_loss: 0.0074
# Epoch 17/50
# 20/20 - 0s - 19ms/step - loss: 2.2090e-04 - val_loss: 0.0063
# Epoch 18/50
# 20/20 - 0s - 18ms/step - loss: 2.1888e-04 - val_loss: 0.0062
# Epoch 19/50
# 20/20 - 0s - 17ms/step - loss: 2.1145e-04 - val_loss: 0.0071
# Epoch 20/50
# 20/20 - 0s - 17ms/step - loss: 2.4071e-04 - val_loss: 0.0091
# Epoch 21/50
# 20/20 - 0s - 20ms/step - loss: 2.6233e-04 - val_loss: 0.0064
# Epoch 22/50
# 20/20 - 0s - 19ms/step - loss: 2.4017e-04 - val_loss: 0.0062
# Epoch 23/50
# 20/20 - 0s - 19ms/step - loss: 2.2700e-04 - val_loss: 0.0070
# Epoch 24/50
# 20/20 - 0s - 17ms/step - loss: 2.6091e-04 - val_loss: 0.0098
# Epoch 25/50
# 20/20 - 0s - 18ms/step - loss: 2.6245e-04 - val_loss: 0.0068
# Epoch 26/50
# 20/20 - 0s - 20ms/step - loss: 2.2546e-04 - val_loss: 0.0062
# Epoch 27/50
# 20/20 - 0s - 18ms/step - loss: 2.1932e-04 - val_loss: 0.0081
# Epoch 28/50
# 20/20 - 0s - 18ms/step - loss: 2.2857e-04 - val_loss: 0.0082
# Epoch 29/50
# 20/20 - 0s - 19ms/step - loss: 2.0924e-04 - val_loss: 0.0062
# Epoch 30/50
# 20/20 - 0s - 18ms/step - loss: 2.0136e-04 - val_loss: 0.0070
# Epoch 31/50
# 20/20 - 0s - 17ms/step - loss: 1.9662e-04 - val_loss: 0.0079
# Epoch 32/50
# 20/20 - 0s - 17ms/step - loss: 2.0330e-04 - val_loss: 0.0062
# Epoch 33/50
# 20/20 - 0s - 17ms/step - loss: 1.9107e-04 - val_loss: 0.0065
# Epoch 34/50
# 20/20 - 0s - 16ms/step - loss: 1.9279e-04 - val_loss: 0.0083
# Epoch 35/50
# 20/20 - 0s - 16ms/step - loss: 2.0720e-04 - val_loss: 0.0066
# Epoch 36/50
# 20/20 - 0s - 17ms/step - loss: 1.9195e-04 - val_loss: 0.0062
# Epoch 37/50
# 20/20 - 0s - 17ms/step - loss: 1.9581e-04 - val_loss: 0.0083
# Epoch 38/50
# 20/20 - 0s - 19ms/step - loss: 2.0443e-04 - val_loss: 0.0073
# Epoch 39/50
# 20/20 - 0s - 16ms/step - loss: 1.9654e-04 - val_loss: 0.0062
# Epoch 40/50
# 20/20 - 0s - 15ms/step - loss: 1.9788e-04 - val_loss: 0.0079
# Epoch 41/50
# 20/20 - 0s - 16ms/step - loss: 1.9940e-04 - val_loss: 0.0084
# Epoch 42/50
# 20/20 - 0s - 17ms/step - loss: 2.0474e-04 - val_loss: 0.0062
# Epoch 43/50
# 20/20 - 0s - 15ms/step - loss: 1.9418e-04 - val_loss: 0.0070
# Epoch 44/50
# 20/20 - 0s - 10ms/step - loss: 1.9366e-04 - val_loss: 0.0087
# Epoch 45/50
# 20/20 - 0s - 13ms/step - loss: 2.1082e-04 - val_loss: 0.0064
# Epoch 46/50
# 20/20 - 0s - 18ms/step - loss: 1.9250e-04 - val_loss: 0.0063
# Epoch 47/50
# 20/20 - 0s - 17ms/step - loss: 1.8744e-04 - val_loss: 0.0084
# Epoch 48/50
# 20/20 - 0s - 17ms/step - loss: 1.9358e-04 - val_loss: 0.0069
# Epoch 49/50
# 20/20 - 0s - 16ms/step - loss: 1.8855e-04 - val_loss: 0.0061
# Epoch 50/50
# 20/20 - 0s - 17ms/step - loss: 1.9644e-04 - val_loss: 0.0086
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# <class 'numpy.ndarray'>
# [[0.07365845]
#  [0.06760933]
#  [0.07675059]
#  [0.07192567]
#  [0.07838596]
#  [0.08491652]
#  [0.06743853]
#  [0.07998972]
#  [0.07363744]
#  [0.08624896]
#  [0.0924    ]
#  [0.07777286]
#  [0.07310764]
#  [0.06638303]
#  [0.0620563 ]
#  [0.058696  ]
#  [0.05982418]
#  [0.05920571]
#  [0.06182243]
#  [0.06080023]
#  [0.05422291]
#  [0.0538883 ]
#  [0.0584517 ]
#  [0.06366264]
#  [0.06734399]
#  [0.07580122]
#  [0.07687102]
#  [0.0796289 ]
#  [0.08241862]
#  [0.08468635]
#  [0.09534906]
#  [0.09697269]
#  [0.09183402]
#  [0.09427314]
#  [0.09146072]
#  [0.10027595]
#  [0.09924117]
#  [0.11072522]
#  [0.09925352]
#  [0.10483554]
#  [0.09853643]
#  [0.09343429]
#  [0.0884265 ]
#  [0.08835545]
#  [0.09152383]
#  [0.09007834]
#  [0.11476873]
#  [0.10593526]
#  [0.11151861]
#  [0.10734928]
#  [0.10193121]
#  [0.10708041]
#  [0.10890868]
#  [0.11227235]
#  [0.11382739]
#  [0.10212122]
#  [0.10254338]
#  [0.09976603]
#  [0.10900244]
#  [0.11071402]
#  [0.11664224]
#  [0.10930122]
#  [0.13140155]
#  [0.12138054]
#  [0.13032109]
#  [0.15288506]
#  [0.18944724]
#  [0.14810646]
#  [0.12282886]
#  [0.12291113]
#  [0.11505245]
#  [0.10615139]
#  [0.09962372]
#  [0.09849818]
#  [0.10080874]
#  [0.09841025]
#  [0.09546287]
#  [0.09414612]
#  [0.09685488]
#  [0.10313675]
#  [0.10327335]
#  [0.10509929]
#  [0.10098818]
#  [0.10650232]
#  [0.15298027]
#  [0.14318933]
#  [0.20845336]
#  [0.24017791]
#  [0.24718355]
#  [0.15965286]
#  [0.09213637]
#  [0.07564995]
#  [0.11311385]
#  [0.12808448]
#  [0.13084492]
#  [0.15258087]
#  [0.12475055]
#  [0.13355151]
#  [0.10448174]
#  [0.12257163]
#  [0.11287966]
#  [0.11545645]
#  [0.10737988]
#  [0.10143214]
#  [0.09582062]
#  [0.08761698]
#  [0.07867129]
#  [0.07849599]
#  [0.07411519]
#  [0.07836205]
#  [0.08698617]
#  [0.06837171]
#  [0.06424327]
#  [0.05538936]
#  [0.05909945]
#  [0.06561939]
#  [0.06464083]
#  [0.06599472]
#  [0.0661998 ]
#  [0.06823428]
#  [0.06730704]
#  [0.07025984]
#  [0.06943156]
#  [0.06905985]
#  [0.07086736]
#  [0.06455223]
#  [0.06415796]
#  [0.05989583]
#  [0.06677845]
#  [0.07008946]
#  [0.06828912]
#  [0.0642653 ]
#  [0.06085292]
#  [0.06079052]
#  [0.05821319]
#  [0.04026583]
#  [0.00197861]
#  [0.00778281]
#  [0.04836884]
#  [0.06160862]
#  [0.06212821]
#  [0.06308973]
#  [0.06243856]
#  [0.06962031]
#  [0.0712437 ]
#  [0.06957527]
#  [0.07031442]
#  [0.06322929]
#  [0.06034383]
#  [0.06101542]
#  [0.06297108]
#  [0.06629419]
#  [0.06878203]
#  [0.0688695 ]
#  [0.06429623]
#  [0.06185972]
#  [0.06133261]
#  [0.06401369]
#  [0.06244143]
#  [0.06298766]
#  [0.06270911]
#  [0.06274232]
#  [0.06425115]
#  [0.06988075]
#  [0.06351712]
#  [0.06195086]
#  [0.06719573]
#  [0.06717041]
#  [0.06331731]
#  [0.06784487]
#  [0.06895073]
#  [0.07225548]
#  [0.07732818]
#  [0.07645956]
#  [0.08205085]
#  [0.08153595]
#  [0.08091836]
#  [0.0879472 ]
#  [0.08735046]
#  [0.08773944]
#  [0.09061231]
#  [0.09258625]
#  [0.08781184]
#  [0.08862586]
#  [0.09330735]
#  [0.09446041]
#  [0.09998308]
#  [0.10118237]
#  [0.10086215]
#  [0.09537475]
#  [0.09467426]
#  [0.10268103]
#  [0.11636865]
#  [0.128068  ]
#  [0.12386897]
#  [0.12540068]
#  [0.1161596 ]
#  [0.12305041]
#  [0.13631798]
#  [0.1495846 ]
#  [0.15381363]
#  [0.16199675]
#  [0.1679099 ]
#  [0.13720778]
#  [0.12991044]
#  [0.14857413]
#  [0.16195635]
#  [0.18690866]
#  [0.18098581]
#  [0.15490237]
#  [0.12314793]
#  [0.13560286]
#  [0.13789643]
#  [0.13109718]
#  [0.12931198]
#  [0.13932683]
#  [0.13417168]
#  [0.14900416]
#  [0.13799062]
#  [0.13943331]
#  [0.13115175]
#  [0.12766486]
#  [0.12396628]
#  [0.12879641]
#  [0.12382086]
#  [0.11915201]
#  [0.1183046 ]
#  [0.11439739]
#  [0.11831848]
#  [0.12401706]
#  [0.12859996]
#  [0.12250853]
#  [0.11884364]
#  [0.13524194]
#  [0.15558834]
#  [0.2215946 ]
#  [0.20460327]
#  [0.17172343]
#  [0.15337862]
#  [0.14834236]
#  [0.15316707]
#  [0.14448394]
#  [0.1482236 ]
#  [0.159523  ]
#  [0.15983957]
#  [0.14980604]
#  [0.14449784]
#  [0.1432919 ]
#  [0.152167  ]
#  [0.1520545 ]
#  [0.16060133]
#  [0.15356994]
#  [0.14913765]
#  [0.14333442]
#  [0.1608071 ]
#  [0.1900064 ]
#  [0.2348531 ]
#  [0.25575262]
#  [0.26670694]
#  [0.2693773 ]
#  [0.22373194]
#  [0.23241971]
#  [0.22110009]
#  [0.24475737]
#  [0.22184743]
#  [0.24467197]
#  [0.24590035]
#  [0.22282757]
#  [0.21823965]
#  [0.23041978]
#  [0.2322924 ]
#  [0.23947735]
#  [0.21290672]
#  [0.22389445]
#  [0.22148861]
#  [0.25145662]
#  [0.20782106]
#  [0.22631676]
#  [0.22567739]
#  [0.19456354]
#  [0.1928471 ]
#  [0.1962322 ]
#  [0.22643812]
#  [0.24582173]
#  [0.24695897]
#  [0.24241635]
#  [0.24104293]
#  [0.23816085]
#  [0.24782613]
#  [0.25057724]
#  [0.24649575]
#  [0.26051924]
#  [0.24389915]
#  [0.22502723]
#  [0.21226928]
#  [0.21891074]
#  [0.27826977]
#  [0.25270107]
#  [0.22910655]
#  [0.20540874]
#  [0.20054926]
#  [0.18869467]
#  [0.17011254]
#  [0.17216761]
#  [0.16158171]
#  [0.16877571]
#  [0.15491325]
#  [0.12783855]
#  [0.11582996]
#  [0.09967296]
#  [0.09291314]
#  [0.0889542 ]]
# rmse = 0.09084924607115089
# mae = 0.05335544522699706
# mape = 0.2783365418800986
# testY
# testY.shape
# (312,)
# <class 'numpy.ndarray'>
# prediction_val
# (312,)
# <class 'numpy.ndarray'>
# binance
# rmse = 0.11187774727535164
# mae = 0.07748085184602647
# mape = 0.5064473802869719
#
# coinbase
# rmse = 0.19795626239653769
# mae = 0.17300331122443266
# mape = 1.2147654293969616
#
# huobi
# rmse = 0.0693378686849182
# mae = 0.022111570708022298
# mape = 0.3260643544146072
#
# kraken
# rmse = 0.1972052214207747
# mae = 0.1172495780216414
# mape = 0.5374603493944885
#
# kucoin
# rmse = 0.09084924607115089
# mae = 0.05335544522699706
# mape = 0.2783365418800986
